# %%
backup_dir = '/root/datos/maestria/netopaas/luca_explore/surgeries'
name = 'Zuani'
cell_key = 'cell_type_tumor'
integ_features = 3000

# %% [markdown]
# Based on SCTransform [v2 vignette](https://satijalab.org/seurat/archive/v4.3/sctransform_v2_vignette)

# %%
import anndata as ad
import pandas as pd
import anndata2ri
anndata2ri.activate()
# %load_ext rpy2.ipython
# Out:
# /tmp/ipykernel_26616/3724497324.py:4: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
adata  = ad.read_h5ad(f'{backup_dir}/{name}_99acc/query.h5ad')

# %%
preds = pd.read_csv(f'{backup_dir}/zuani_predicted.csv')
preds.index = adata.obs.index
adata.obs[cell_key] = preds[cell_key]
adata.obs
# Out:
#                           sample             barcode Source Name  \
# index
# Zuani_AAACCCAAGCAACTTC-1  P16_T2  AAACCCAAGCAACTTC-1      P16_T2
# Zuani_AAACCCAAGCGCTTCG-1  P16_T2  AAACCCAAGCGCTTCG-1      P16_T2
# Zuani_AAACCCAAGGCTAACG-1  P16_T2  AAACCCAAGGCTAACG-1      P16_T2
# Zuani_AAACCCACATAGGTTC-1  P16_T2  AAACCCACATAGGTTC-1      P16_T2
# Zuani_AAACCCACATCCTTGC-1  P16_T2  AAACCCACATCCTTGC-1      P16_T2
# ...                          ...                 ...         ...
# Zuani_TTTGATCAGTTGAATG-1  P20_T2  TTTGATCAGTTGAATG-1      P20_T2
# Zuani_TTTGATCGTCAGCTTA-1  P20_T2  TTTGATCGTCAGCTTA-1      P20_T2
# Zuani_TTTGGAGGTCACCCTT-1  P20_T2  TTTGGAGGTCACCCTT-1      P20_T2
# Zuani_TTTGTTGAGTATGGAT-1  P20_T2  TTTGTTGAGTATGGAT-1      P20_T2
# Zuani_TTTGTTGGTTGCATCA-1  P20_T2  TTTGTTGGTTGCATCA-1      P20_T2
#
#                          Characteristics[tumor grading]  n_counts  n_genes  \
# index
# Zuani_AAACCCAAGCAACTTC-1                        T2bN0M0    2498.0     1009
# Zuani_AAACCCAAGCGCTTCG-1                        T2bN0M0    1586.0      800
# Zuani_AAACCCAAGGCTAACG-1                        T2bN0M0    4772.0     1754
# Zuani_AAACCCACATAGGTTC-1                        T2bN0M0    5139.0     1662
# Zuani_AAACCCACATCCTTGC-1                        T2bN0M0    1666.0      713
# ...                                                 ...       ...      ...
# Zuani_TTTGATCAGTTGAATG-1                         T4N2M0   28995.0     2657
# Zuani_TTTGATCGTCAGCTTA-1                         T4N2M0    8029.0     2397
# Zuani_TTTGGAGGTCACCCTT-1                         T4N2M0   26494.0     5149
# Zuani_TTTGTTGAGTATGGAT-1                         T4N2M0   40721.0     5717
# Zuani_TTTGTTGGTTGCATCA-1                         T4N2M0    8252.0     2486
#
#                           n_genes_by_counts  total_counts  total_counts_mito  \
# index
# Zuani_AAACCCAAGCAACTTC-1               1009        2498.0              222.0
# Zuani_AAACCCAAGCGCTTCG-1                800        1586.0              182.0
# Zuani_AAACCCAAGGCTAACG-1               1754        4772.0              107.0
# Zuani_AAACCCACATAGGTTC-1               1662        5139.0              119.0
# Zuani_AAACCCACATCCTTGC-1                713        1666.0              164.0
# ...                                     ...           ...                ...
# Zuani_TTTGATCAGTTGAATG-1               2657       28995.0              499.0
# Zuani_TTTGATCGTCAGCTTA-1               2397        8029.0              250.0
# Zuani_TTTGGAGGTCACCCTT-1               5149       26494.0              948.0
# Zuani_TTTGTTGAGTATGGAT-1               5717       40721.0             5159.0
# Zuani_TTTGTTGGTTGCATCA-1               2486        8252.0              260.0
#
#                           pct_counts_mito stage             cell_type_tumor  \
# index
# Zuani_AAACCCAAGCAACTTC-1         8.887110    II        T cell CD8 activated
# Zuani_AAACCCAAGCGCTTCG-1        11.475410    II        T cell CD8 activated
# Zuani_AAACCCAAGGCTAACG-1         2.242246    II                  T cell CD4
# Zuani_AAACCCACATAGGTTC-1         2.315626    II                  T cell CD4
# Zuani_AAACCCACATCCTTGC-1         9.843937    II  T cell CD8 effector memory
# ...                                   ...   ...                         ...
# Zuani_TTTGATCAGTTGAATG-1         1.720986   III                 Plasma cell
# Zuani_TTTGATCGTCAGCTTA-1         3.113713   III          Monocyte classical
# Zuani_TTTGGAGGTCACCCTT-1         3.578169   III       transitional club/AT2
# Zuani_TTTGTTGAGTATGGAT-1        12.669139   III        Tumor cells LUAD EMT
# Zuani_TTTGTTGGTTGCATCA-1         3.150751   III           T cell regulatory
#
#                          dataset  _scvi_batch  _scvi_labels
# index
# Zuani_AAACCCAAGCAACTTC-1   Zuani           12            51
# Zuani_AAACCCAAGCGCTTCG-1   Zuani           12            51
# Zuani_AAACCCAAGGCTAACG-1   Zuani           12            51
# Zuani_AAACCCACATAGGTTC-1   Zuani           12            51
# Zuani_AAACCCACATCCTTGC-1   Zuani           12            51
# ...                          ...          ...           ...
# Zuani_TTTGATCAGTTGAATG-1   Zuani           12            51
# Zuani_TTTGATCGTCAGCTTA-1   Zuani           12            51
# Zuani_TTTGGAGGTCACCCTT-1   Zuani           12            51
# Zuani_TTTGTTGAGTATGGAT-1   Zuani           12            51
# Zuani_TTTGTTGGTTGCATCA-1   Zuani           12            51
#
# [220866 rows x 15 columns]

# %%
# %Rdevice svg

# %%
# %%R -i adata -i backup_dir -i name
# library(Seurat)
# adata.seurat <- as.Seurat(adata, data = "X", counts='X')
# SaveSeuratRds(adata.seurat, file.path(backup_dir,name,"query.rds"))
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# Loading required package: SeuratObject
# Loading required package: sp
#
# Attaching package: ‘sp’
#
# The following object is masked from ‘package:IRanges’:
#
#     %over%
#
#
# Attaching package: ‘SeuratObject’
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays
#
# The following object is masked from ‘package:GenomicRanges’:
#
#     intersect
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
# The following object is masked from ‘package:IRanges’:
#
#     intersect
#
# The following object is masked from ‘package:S4Vectors’:
#
#     intersect
#
# The following object is masked from ‘package:BiocGenerics’:
#
#     intersect
#
# The following objects are masked from ‘package:base’:
#
#     intersect, t
#
#
# Attaching package: ‘Seurat’
#
# The following object is masked from ‘package:SummarizedExperiment’:
#
#     Assays

# %% [markdown]
# SCTransform processing: 2008.358 sec elapsed

# %%
2+2
# Out:
# 4

# %%
# %%R
# SaveSeuratRds(integrated_data, file.path(backup_dir,name,"integ.rds"))

# %%
# %%R -i integ_features
# library(Seurat)
# library(dplyr)
# library(purrr)
# library(tictoc)
#
# # Start the timer
# tic("Total execution time")
#
# # Split and transform the Seurat objects
# tic("SCTransform processing")
# adata.seurat.list <- adata.seurat %>%
#   SplitObject(split.by = "sample") %>%
#   map(~ SCTransform(.x, vst.flavor = "v2", verbose = FALSE, assay='originalexp', return.only.var.genes = FALSE)) # Important to return all genes or else integration does not work
# toc()  # Ends SCTransform timing
#
# # Proceed with further analysis (e.g., integration)
# tic("Integration processing")
# features <- SelectIntegrationFeatures(object.list = adata.seurat.list, nfeatures = integ_features)
#
# adata.seurat.list <- PrepSCTIntegration(object.list = adata.seurat.list, anchor.features = features)
# anchors <- FindIntegrationAnchors(
#   object.list = adata.seurat.list,
#   normalization.method = "SCT",
#   anchor.features = features
# )
# integrated_data <- IntegrateData(
#   anchorset = anchors,
#   normalization.method = "SCT"
# )
# toc()  # Ends Integration timing
#
# toc()  # Ends total execution timing
# integrated_data
# Out:
# SCTransform processing: 525.636 sec elapsed
#   |                                                  | 0 % ~calculating   |++++                                              | 8 % ~06s           |++++++++                                          | 15% ~13s           |++++++++++++                                      | 23% ~13s           |++++++++++++++++                                  | 31% ~12s           |++++++++++++++++++++                              | 38% ~09s           |++++++++++++++++++++++++                          | 46% ~08s           |+++++++++++++++++++++++++++                       | 54% ~06s           |+++++++++++++++++++++++++++++++                   | 62% ~04s           |+++++++++++++++++++++++++++++++++++               | 69% ~05s           |+++++++++++++++++++++++++++++++++++++++           | 77% ~04s           |+++++++++++++++++++++++++++++++++++++++++++       | 85% ~02s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 92% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=15s
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~01d 01h 15m 02s |++                                                | 3 % ~23h 44m 59s   |++                                                | 4 % ~01d 19h 26m 05s |+++                                               | 5 % ~01d 12h 32m 30s |++++                                              | 6 % ~01d 15h 48m 40s |++++                                              | 8 % ~01d 18h 09m 36s |+++++                                             | 9 % ~01d 12h 09m 20s |++++++                                            | 10% ~01d 08h 41m 02s |++++++                                            | 12% ~01d 05h 49m 53s |+++++++                                           | 13% ~01d 03h 14m 05s |++++++++                                          | 14% ~01d 01h 53m 49s |++++++++                                          | 15% ~01d 04h 31m 58s |+++++++++                                         | 17% ~01d 05h 54m 02s

# %% [markdown]
# ### Import new annots

# %%
preds = pd.read_csv(f'{backup_dir}/{name}_predicted_leiden.csv')

# %%
# %%R -i preds
# integrated_data@meta.data$cell_type_adjusted <- preds$cell_type_adjusted

# %% [markdown]
# ## Markers

# %%
# %%R
# tic()
# integrated_data <- PrepSCTFindMarkers(integrated_data)
# integrated_data@meta.data$cell_type_adjusted <- as.factor(integrated_data@meta.data$cell_type_adjusted)
# Idents(object=integrated_data) <- 'cell_type_adjusted'
# markers <- FindMarkers(object = integrated_data, ident.1 = "Tumor LUAD_mixed", assay='SCT', recorrect_umi=F) # We dont recollect UMI because we use UMI counts the SCRAssay method
# print(head(x = markers, n=15))
# toc()
