# %%
id_ = 'Zilionis_Klein_2019_NSCLC'
name = 'zilionis'
# id = 'Lambrechts_2018_LUAD_6149v1'
backup_dir = '/root/datos/maestria/netopaas/luca/data/atlas/'
load_wilcoxon = False
load_gsea = False
load_gsea_heatmap = False

# %%
id_ = 'extended_tumor_hvg'
name = 'extended_tumor_hvg'

# %% [markdown]
# # Cell Type Markers and GO

# %% [markdown]
# ## Libraries and Data

# %% [markdown]
# We want to assign a cell type to our unsupervised clusters for tumor cells. For that we take the follwoing approach
#
# 1. Marker genes plots for these comparisons per cell type: (**TypeTumorPred** vs **REST**)
# 2. Heatmaps With the above group as  cell labels and hierarchical clustering in the genes. With genes chosen from the marker genes.
# 3. Prevalent gene ontologies for the group above, considering also hallmark ontologies

# %%
import os
from pathlib import Path
import gdown

import sys
# This makes the working dir change apparently
sys.path.append("..")
import utils.functions as ut

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from scipy.sparse import csr_matrix

import anndata as ad
import scanpy as sc

# %%
# adata = sc.read_h5ad(f'{backup_dir}/combTumor_{id_}.h5ad')
time = 'I-IV'
# adata = sc.read_h5ad(f'{backup_dir}/filtered_{id_}.h5ad')
adata = sc.read_h5ad(f'{backup_dir}/{id_}.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 402634 × 5989
#     obs: 'sample', 'uicc_stage', 'ever_smoker', 'age', 'donor_id', 'origin', 'dataset', 'ann_fine', 'cell_type_predicted', 'doublet_status', 'leiden', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito', 'ann_coarse', 'cell_type_tumor', 'tumor_stage', 'EGFR_mutation', 'TP53_mutation', 'ALK_mutation', 'BRAF_mutation', 'ERBB2_mutation', 'KRAS_mutation', 'ROS_mutation', 'origin_fine', 'study', 'platform', 'cell_type_major', 'cell_type_neutro', 'cell_type_neutro_coarse', 'suspension_type', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'is_highly_variable', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length'
#     uns: '_scvi', 'ann_fine_colors', 'batch_condition', 'cell_type_major_colors', 'cell_type_tumor_colors', 'citation', 'dataset_colors', 'default_embedding', 'hvg', 'neighbors', 'origin_colors', 'platform_colors', 'schema_reference', 'schema_version', 'title', 'umap'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     layers: 'count'
#     obsp: 'connectivities', 'distances'

# %%
# preds = pd.read_csv(f'{backup_dir}/{name}_predicted.csv')
preds = pd.read_csv('/root/datos/maestria/netopaas/luca_explore/surgeries/Atlas_predicted_leiden.csv')
preds.index = adata.obs.index
adata.obs['cell_type_adjusted'] = preds['cell_type_adjusted']
adata.obs
# Out:
#                                             sample uicc_stage ever_smoker  \
# AAACCCAAGAGCCATG-1_0-1    Chen_Zhang_2020_NSCLC-10        III         NaN
# AAACCCAAGATTAGAC-1_0-1    Chen_Zhang_2020_NSCLC-10        III         NaN
# AAACCCAAGGTCGCCT-1_0-1    Chen_Zhang_2020_NSCLC-10        III         NaN
# AAACCCAAGTCATTGC-1_0-1    Chen_Zhang_2020_NSCLC-10        III         NaN
# AAACCCACACGGATCC-1_0-1    Chen_Zhang_2020_NSCLC-10        III         NaN
# ...                                            ...        ...         ...
# 811511_27-3             UKIM-V-2_P17_tumor_primary          I         yes
# 468397_27-3             UKIM-V-2_P17_tumor_primary          I         yes
# 115884_27-3             UKIM-V-2_P17_tumor_primary          I         yes
# 201201_27-3             UKIM-V-2_P17_tumor_primary          I         yes
# 194204_27-3             UKIM-V-2_P17_tumor_primary          I         yes
#
#                          age                  donor_id         origin  \
# AAACCCAAGAGCCATG-1_0-1   NaN  Chen_Zhang_2020_NSCLC-10  tumor_primary
# AAACCCAAGATTAGAC-1_0-1   NaN  Chen_Zhang_2020_NSCLC-10  tumor_primary
# AAACCCAAGGTCGCCT-1_0-1   NaN  Chen_Zhang_2020_NSCLC-10  tumor_primary
# AAACCCAAGTCATTGC-1_0-1   NaN  Chen_Zhang_2020_NSCLC-10  tumor_primary
# AAACCCACACGGATCC-1_0-1   NaN  Chen_Zhang_2020_NSCLC-10  tumor_primary
# ...                      ...                       ...            ...
# 811511_27-3             60.0              UKIM-V-2_P17  tumor_primary
# 468397_27-3             60.0              UKIM-V-2_P17  tumor_primary
# 115884_27-3             60.0              UKIM-V-2_P17  tumor_primary
# 201201_27-3             60.0              UKIM-V-2_P17  tumor_primary
# 194204_27-3             60.0              UKIM-V-2_P17  tumor_primary
#
#                                 dataset                    ann_fine  \
# AAACCCAAGAGCCATG-1_0-1  Chen_Zhang_2020  T cell CD8 effector memory
# AAACCCAAGATTAGAC-1_0-1  Chen_Zhang_2020                Cancer cells
# AAACCCAAGGTCGCCT-1_0-1  Chen_Zhang_2020                      B cell
# AAACCCAAGTCATTGC-1_0-1  Chen_Zhang_2020                      B cell
# AAACCCACACGGATCC-1_0-1  Chen_Zhang_2020                 Plasma cell
# ...                                 ...                         ...
# 811511_27-3                    UKIM-V-2                 Neutrophils
# 468397_27-3                    UKIM-V-2                 Neutrophils
# 115884_27-3                    UKIM-V-2                 Neutrophils
# 201201_27-3                    UKIM-V-2                 Neutrophils
# 194204_27-3                    UKIM-V-2                 Neutrophils
#
#                               cell_type_predicted doublet_status  ...  \
# AAACCCAAGAGCCATG-1_0-1                 T cell CD8        singlet  ...
# AAACCCAAGATTAGAC-1_0-1  Epithelial cell malignant        singlet  ...
# AAACCCAAGGTCGCCT-1_0-1                     B cell        singlet  ...
# AAACCCAAGTCATTGC-1_0-1                     B cell        singlet  ...
# AAACCCACACGGATCC-1_0-1                Plasma cell        singlet  ...
# ...                                           ...            ...  ...
# 811511_27-3                                   NaN        singlet  ...
# 468397_27-3                                   NaN        singlet  ...
# 115884_27-3                                   NaN        singlet  ...
# 201201_27-3                                   NaN        singlet  ...
# 194204_27-3                                   NaN        singlet  ...
#
#                                               cell_type  \
# AAACCCAAGAGCCATG-1_0-1  CD8-positive, alpha-beta T cell
# AAACCCAAGATTAGAC-1_0-1                   malignant cell
# AAACCCAAGGTCGCCT-1_0-1                           B cell
# AAACCCAAGTCATTGC-1_0-1                           B cell
# AAACCCACACGGATCC-1_0-1                      plasma cell
# ...                                                 ...
# 811511_27-3                                  neutrophil
# 468397_27-3                                  neutrophil
# 115884_27-3                                  neutrophil
# 201201_27-3                                  neutrophil
# 194204_27-3                                  neutrophil
#
#                                                            assay  \
# AAACCCAAGAGCCATG-1_0-1                                 10x 3' v3
# AAACCCAAGATTAGAC-1_0-1                                 10x 3' v3
# AAACCCAAGGTCGCCT-1_0-1                                 10x 3' v3
# AAACCCAAGTCATTGC-1_0-1                                 10x 3' v3
# AAACCCACACGGATCC-1_0-1                                 10x 3' v3
# ...                                                          ...
# 811511_27-3             BD Rhapsody Whole Transcriptome Analysis
# 468397_27-3             BD Rhapsody Whole Transcriptome Analysis
# 115884_27-3             BD Rhapsody Whole Transcriptome Analysis
# 201201_27-3             BD Rhapsody Whole Transcriptome Analysis
# 194204_27-3             BD Rhapsody Whole Transcriptome Analysis
#
#                                               disease      organism     sex  \
# AAACCCAAGAGCCATG-1_0-1  non-small cell lung carcinoma  Homo sapiens    male
# AAACCCAAGATTAGAC-1_0-1  non-small cell lung carcinoma  Homo sapiens    male
# AAACCCAAGGTCGCCT-1_0-1  non-small cell lung carcinoma  Homo sapiens    male
# AAACCCAAGTCATTGC-1_0-1  non-small cell lung carcinoma  Homo sapiens    male
# AAACCCACACGGATCC-1_0-1  non-small cell lung carcinoma  Homo sapiens    male
# ...                                               ...           ...     ...
# 811511_27-3              squamous cell lung carcinoma  Homo sapiens  female
# 468397_27-3              squamous cell lung carcinoma  Homo sapiens  female
# 115884_27-3              squamous cell lung carcinoma  Homo sapiens  female
# 201201_27-3              squamous cell lung carcinoma  Homo sapiens  female
# 194204_27-3              squamous cell lung carcinoma  Homo sapiens  female
#
#                        tissue self_reported_ethnicity  \
# AAACCCAAGAGCCATG-1_0-1   lung                 unknown
# AAACCCAAGATTAGAC-1_0-1   lung                 unknown
# AAACCCAAGGTCGCCT-1_0-1   lung                 unknown
# AAACCCAAGTCATTGC-1_0-1   lung                 unknown
# AAACCCACACGGATCC-1_0-1   lung                 unknown
# ...                       ...                     ...
# 811511_27-3              lung                 unknown
# 468397_27-3              lung                 unknown
# 115884_27-3              lung                 unknown
# 201201_27-3              lung                 unknown
# 194204_27-3              lung                 unknown
#
#                               development_stage observation_joinid  \
# AAACCCAAGAGCCATG-1_0-1                  unknown         bgE9FM<wVD
# AAACCCAAGATTAGAC-1_0-1                  unknown         JM(E_OK4-8
# AAACCCAAGGTCGCCT-1_0-1                  unknown         `Pg;`Co(CV
# AAACCCAAGTCATTGC-1_0-1                  unknown         bmUWpje(CT
# AAACCCACACGGATCC-1_0-1                  unknown         eCKfW>mBo$
# ...                                         ...                ...
# 811511_27-3             60-year-old human stage         3(g6vJNO@o
# 468397_27-3             60-year-old human stage         jR%lZ``FtE
# 115884_27-3             60-year-old human stage         HsX>>5FRv|
# 201201_27-3             60-year-old human stage         BV1<+6rUgg
# 194204_27-3             60-year-old human stage         (5&|)tL$bA
#
#                                 cell_type_adjusted
# AAACCCAAGAGCCATG-1_0-1  T cell CD8 effector memory
# AAACCCAAGATTAGAC-1_0-1             Tumor LUAD_Club
# AAACCCAAGGTCGCCT-1_0-1                      B cell
# AAACCCAAGTCATTGC-1_0-1                      B cell
# AAACCCACACGGATCC-1_0-1                 Plasma cell
# ...                                            ...
# 811511_27-3                            Neutrophils
# 468397_27-3                            Neutrophils
# 115884_27-3                            Neutrophils
# 201201_27-3                            Neutrophils
# 194204_27-3                            Neutrophils
#
# [402634 rows x 52 columns]

# %% [markdown]
# We confirm that we have counts and wilcoxon expects lognromalization so we normalize

# %%
adata[:20,10:20].to_df()
# Out:
# gene_id                 ENSG00000165029  ENSG00000179869  ENSG00000107331  \
# AAACCCAAGAGCCATG-1_0-1         0.000000              0.0              0.0
# AAACCCAAGATTAGAC-1_0-1         1.098612              0.0              0.0
# AAACCCAAGGTCGCCT-1_0-1         0.000000              0.0              0.0
# AAACCCAAGTCATTGC-1_0-1         0.000000              0.0              0.0
# AAACCCACACGGATCC-1_0-1         0.000000              0.0              0.0
# AAACCCACACTCCTTG-1_0-1         0.000000              0.0              0.0
# AAACCCACATCTATCT-1_0-1         0.000000              0.0              0.0
# AAACCCAGTACGATTC-1_0-1         0.000000              0.0              0.0
# AAACCCAGTGATAGTA-1_0-1         0.000000              0.0              0.0
# AAACCCAGTGTATTGC-1_0-1         0.000000              0.0              0.0
# AAACCCATCAGGACAG-1_0-1         0.000000              0.0              0.0
# AAACCCATCTAAGGAA-1_0-1         0.000000              0.0              0.0
# AAACCCATCTTTGCGC-1_0-1         0.000000              0.0              0.0
# AAACGAAAGCGGACAT-1_0-1         0.000000              0.0              0.0
# AAACGAAAGGGCTAAC-1_0-1         1.386294              0.0              0.0
# AAACGAAAGGTAGCCA-1_0-1         0.000000              0.0              0.0
# AAACGAAAGTTGCCTA-1_0-1         0.000000              0.0              0.0
# AAACGAACACATGAAA-1_0-1         0.000000              0.0              0.0
# AAACGAACACTATGTG-1_0-1         0.000000              0.0              0.0
# AAACGAACAGCCTATA-1_0-1         0.000000              0.0              0.0
#
# gene_id                 ENSG00000167972  ENSG00000154262  ENSG00000064687  \
# AAACCCAAGAGCCATG-1_0-1         0.000000              0.0         0.000000
# AAACCCAAGATTAGAC-1_0-1         1.609438              0.0         0.000000
# AAACCCAAGGTCGCCT-1_0-1         0.000000              0.0         0.000000
# AAACCCAAGTCATTGC-1_0-1         0.000000              0.0         0.000000
# AAACCCACACGGATCC-1_0-1         0.000000              0.0         0.000000
# AAACCCACACTCCTTG-1_0-1         0.000000              0.0         0.000000
# AAACCCACATCTATCT-1_0-1         0.000000              0.0         0.000000
# AAACCCAGTACGATTC-1_0-1         0.693147              0.0         0.000000
# AAACCCAGTGATAGTA-1_0-1         0.000000              0.0         0.000000
# AAACCCAGTGTATTGC-1_0-1         0.000000              0.0         0.000000
# AAACCCATCAGGACAG-1_0-1         0.000000              0.0         0.000000
# AAACCCATCTAAGGAA-1_0-1         0.000000              0.0         0.000000
# AAACCCATCTTTGCGC-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGCGGACAT-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGGGCTAAC-1_0-1         1.791759              0.0         1.098612
# AAACGAAAGGTAGCCA-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGTTGCCTA-1_0-1         0.000000              0.0         0.000000
# AAACGAACACATGAAA-1_0-1         0.000000              0.0         0.000000
# AAACGAACACTATGTG-1_0-1         0.000000              0.0         0.000000
# AAACGAACAGCCTATA-1_0-1         0.000000              0.0         0.000000
#
# gene_id                 ENSG00000141338  ENSG00000115657  ENSG00000131269  \
# AAACCCAAGAGCCATG-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGATTAGAC-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGGTCGCCT-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGTCATTGC-1_0-1              0.0         0.000000         0.000000
# AAACCCACACGGATCC-1_0-1              0.0         0.000000         0.000000
# AAACCCACACTCCTTG-1_0-1              0.0         0.000000         0.000000
# AAACCCACATCTATCT-1_0-1              0.0         0.000000         1.098612
# AAACCCAGTACGATTC-1_0-1              0.0         0.000000         0.000000
# AAACCCAGTGATAGTA-1_0-1              0.0         0.000000         0.000000
# AAACCCAGTGTATTGC-1_0-1              0.0         0.000000         0.000000
# AAACCCATCAGGACAG-1_0-1              0.0         0.000000         0.000000
# AAACCCATCTAAGGAA-1_0-1              0.0         0.000000         0.000000
# AAACCCATCTTTGCGC-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGCGGACAT-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGGGCTAAC-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGGTAGCCA-1_0-1              0.0         0.000000         0.000000
# AAACGAAAGTTGCCTA-1_0-1              0.0         0.000000         0.000000
# AAACGAACACATGAAA-1_0-1              0.0         0.693147         0.000000
# AAACGAACACTATGTG-1_0-1              0.0         0.000000         0.000000
# AAACGAACAGCCTATA-1_0-1              0.0         0.000000         0.000000
#
# gene_id                 ENSG00000023839
# AAACCCAAGAGCCATG-1_0-1              0.0
# AAACCCAAGATTAGAC-1_0-1              0.0
# AAACCCAAGGTCGCCT-1_0-1              0.0
# AAACCCAAGTCATTGC-1_0-1              0.0
# AAACCCACACGGATCC-1_0-1              0.0
# AAACCCACACTCCTTG-1_0-1              0.0
# AAACCCACATCTATCT-1_0-1              0.0
# AAACCCAGTACGATTC-1_0-1              0.0
# AAACCCAGTGATAGTA-1_0-1              0.0
# AAACCCAGTGTATTGC-1_0-1              0.0
# AAACCCATCAGGACAG-1_0-1              0.0
# AAACCCATCTAAGGAA-1_0-1              0.0
# AAACCCATCTTTGCGC-1_0-1              0.0
# AAACGAAAGCGGACAT-1_0-1              0.0
# AAACGAAAGGGCTAAC-1_0-1              0.0
# AAACGAAAGGTAGCCA-1_0-1              0.0
# AAACGAAAGTTGCCTA-1_0-1              0.0
# AAACGAACACATGAAA-1_0-1              0.0
# AAACGAACACTATGTG-1_0-1              0.0
# AAACGAACAGCCTATA-1_0-1              0.0

# %% [markdown]
# Wilcoxon is rank based so apparently normalization is not necessary

# %%
sc.pp.log1p(adata)

# %%
adata[:20,10:20].to_df()
# Out:
# gene_id                 ENSG00000165029  ENSG00000179869  ENSG00000107331  \
# AAACCCAAGAGCCATG-1_0-1         0.000000              0.0              0.0
# AAACCCAAGATTAGAC-1_0-1         1.098612              0.0              0.0
# AAACCCAAGGTCGCCT-1_0-1         0.000000              0.0              0.0
# AAACCCAAGTCATTGC-1_0-1         0.000000              0.0              0.0
# AAACCCACACGGATCC-1_0-1         0.000000              0.0              0.0
# AAACCCACACTCCTTG-1_0-1         0.000000              0.0              0.0
# AAACCCACATCTATCT-1_0-1         0.000000              0.0              0.0
# AAACCCAGTACGATTC-1_0-1         0.000000              0.0              0.0
# AAACCCAGTGATAGTA-1_0-1         0.000000              0.0              0.0
# AAACCCAGTGTATTGC-1_0-1         0.000000              0.0              0.0
# AAACCCATCAGGACAG-1_0-1         0.000000              0.0              0.0
# AAACCCATCTAAGGAA-1_0-1         0.000000              0.0              0.0
# AAACCCATCTTTGCGC-1_0-1         0.000000              0.0              0.0
# AAACGAAAGCGGACAT-1_0-1         0.000000              0.0              0.0
# AAACGAAAGGGCTAAC-1_0-1         1.386294              0.0              0.0
# AAACGAAAGGTAGCCA-1_0-1         0.000000              0.0              0.0
# AAACGAAAGTTGCCTA-1_0-1         0.000000              0.0              0.0
# AAACGAACACATGAAA-1_0-1         0.000000              0.0              0.0
# AAACGAACACTATGTG-1_0-1         0.000000              0.0              0.0
# AAACGAACAGCCTATA-1_0-1         0.000000              0.0              0.0
#
# gene_id                 ENSG00000167972  ENSG00000154262  ENSG00000064687  \
# AAACCCAAGAGCCATG-1_0-1         0.000000              0.0         0.000000
# AAACCCAAGATTAGAC-1_0-1         1.609438              0.0         0.000000
# AAACCCAAGGTCGCCT-1_0-1         0.000000              0.0         0.000000
# AAACCCAAGTCATTGC-1_0-1         0.000000              0.0         0.000000
# AAACCCACACGGATCC-1_0-1         0.000000              0.0         0.000000
# AAACCCACACTCCTTG-1_0-1         0.000000              0.0         0.000000
# AAACCCACATCTATCT-1_0-1         0.000000              0.0         0.000000
# AAACCCAGTACGATTC-1_0-1         0.693147              0.0         0.000000
# AAACCCAGTGATAGTA-1_0-1         0.000000              0.0         0.000000
# AAACCCAGTGTATTGC-1_0-1         0.000000              0.0         0.000000
# AAACCCATCAGGACAG-1_0-1         0.000000              0.0         0.000000
# AAACCCATCTAAGGAA-1_0-1         0.000000              0.0         0.000000
# AAACCCATCTTTGCGC-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGCGGACAT-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGGGCTAAC-1_0-1         1.791759              0.0         1.098612
# AAACGAAAGGTAGCCA-1_0-1         0.000000              0.0         0.000000
# AAACGAAAGTTGCCTA-1_0-1         0.000000              0.0         0.000000
# AAACGAACACATGAAA-1_0-1         0.000000              0.0         0.000000
# AAACGAACACTATGTG-1_0-1         0.000000              0.0         0.000000
# AAACGAACAGCCTATA-1_0-1         0.000000              0.0         0.000000
#
# gene_id                 ENSG00000141338  ENSG00000115657  ENSG00000131269  \
# AAACCCAAGAGCCATG-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGATTAGAC-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGGTCGCCT-1_0-1              0.0         0.000000         0.000000
# AAACCCAAGTCATTGC-1_0-1              0.0         0.000000         0.000000
# AAACCCACACGGATCC-1_0-1              0.0         0.000000         0.000000
# AAACCCACACTCCTTG-1_0-1              0.0         0.000000         0.000000
# AAACCCACATCTATCT-1_0-1              0.0         0.000000         1.098612
# AAACCCAGTACGATTC-1_0-1              0.0         0.000000         0.000000
# AAACCCAGTGATAGTA-1_0-1              0.0         0.000000         0.000000
# AAACCCAGTGTATTGC-1_0-1              0.0         0.000000         0.000000
# AAACCCATCAGGACAG-1_0-1              0.0         0.000000         0.000000
# AAACCCATCTAAGGAA-1_0-1              0.0         0.000000         0.000000
# AAACCCATCTTTGCGC-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGCGGACAT-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGGGCTAAC-1_0-1              0.0         0.000000         0.693147
# AAACGAAAGGTAGCCA-1_0-1              0.0         0.000000         0.000000
# AAACGAAAGTTGCCTA-1_0-1              0.0         0.000000         0.000000
# AAACGAACACATGAAA-1_0-1              0.0         0.693147         0.000000
# AAACGAACACTATGTG-1_0-1              0.0         0.000000         0.000000
# AAACGAACAGCCTATA-1_0-1              0.0         0.000000         0.000000
#
# gene_id                 ENSG00000023839
# AAACCCAAGAGCCATG-1_0-1              0.0
# AAACCCAAGATTAGAC-1_0-1              0.0
# AAACCCAAGGTCGCCT-1_0-1              0.0
# AAACCCAAGTCATTGC-1_0-1              0.0
# AAACCCACACGGATCC-1_0-1              0.0
# AAACCCACACTCCTTG-1_0-1              0.0
# AAACCCACATCTATCT-1_0-1              0.0
# AAACCCAGTACGATTC-1_0-1              0.0
# AAACCCAGTGATAGTA-1_0-1              0.0
# AAACCCAGTGTATTGC-1_0-1              0.0
# AAACCCATCAGGACAG-1_0-1              0.0
# AAACCCATCTAAGGAA-1_0-1              0.0
# AAACCCATCTTTGCGC-1_0-1              0.0
# AAACGAAAGCGGACAT-1_0-1              0.0
# AAACGAAAGGGCTAAC-1_0-1              0.0
# AAACGAAAGGTAGCCA-1_0-1              0.0
# AAACGAAAGTTGCCTA-1_0-1              0.0
# AAACGAACACATGAAA-1_0-1              0.0
# AAACGAACACTATGTG-1_0-1              0.0
# AAACGAACAGCCTATA-1_0-1              0.0

# %% [markdown]
# ## Marker Genes

# %% [markdown]
# We use th wilcoxon paired metho beacuse it considers hetorgeneity in te cell abundances. The one group vs rest does not do this.
# So the idea is to first make all the pairwise comparisons and then do a summary of the stasticstics.
#
# For that we have a method that automatically does the pairwise of a list of groups you give.
#
# Then we choose the Rest Group and gather its stasticis in `.uns` key.  And then we have a method that takes the mean of those stastisitcs and outputs marker genes for every cell type vs. its rest.

# %%
adata.obs['type_tissue'] = adata.obs['cell_type_adjusted']
adata.obs['type_tissue']
# Out:
# AAACCCAAGAGCCATG-1_0-1    T cell CD8 effector memory
# AAACCCAAGATTAGAC-1_0-1               Tumor LUAD_Club
# AAACCCAAGGTCGCCT-1_0-1                        B cell
# AAACCCAAGTCATTGC-1_0-1                        B cell
# AAACCCACACGGATCC-1_0-1                   Plasma cell
#                                      ...
# 811511_27-3                              Neutrophils
# 468397_27-3                              Neutrophils
# 115884_27-3                              Neutrophils
# 201201_27-3                              Neutrophils
# 194204_27-3                              Neutrophils
# Name: type_tissue, Length: 402634, dtype: object

# %% [markdown]
# ### Pairwise

# %% [markdown]
# With parallel is shit! With 4 groups and 12 jobs it takes 26 min

# %% [markdown]
# Without parallel, still runs parallel from nnumpy in the scanpy method. With 4 groups it takes 12 min
#
# TODO: Limit the number of cores this uses https://stackoverflow.com/questions/55746872/how-to-limit-number-of-cpus-used-by-a-python-script-w-o-terminal-or-multiproces

# %%
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)
types = adata.obs.type_tissue.unique()
w_folder = 'wilcoxon_DE'

# Load

all_path = f'{w_folder}/{time}_{id_}'
key_pair = "rank_genes_groups_pairwise"

valid_types
# Out:
# ['T cell CD4',
#  'Macrophage',
#  'T cell CD8 effector memory',
#  'B cell',
#  'T cell regulatory',
#  'Plasma cell',
#  'Macrophage alveolar',
#  'transitional club/AT2',
#  'T cell CD8 terminally exhausted',
#  'Neutrophils',
#  'Tumor LUAD_transitional',
#  'NK cell',
#  'Monocyte classical',
#  'cDC2',
#  'Tumor LUAD_mitotic',
#  'Mast cell',
#  'Tumor LUAD_EMT1',
#  'Tumor LUAD_LUSC_mitotic',
#  'Alveolar cell type 2',
#  'T cell NK-like',
#  'Tumor LUSC_mainly',
#  'Fibroblast peribronchial',
#  'Tumor LUAD_mixed',
#  'T cell CD8 activated',
#  'Tumor LUSC_LUAD_mitotic',
#  'T cell CD8 naive',
#  'Tumor LUAD_Club',
#  'Endothelial cell venous',
#  'Tumor LUAD_LUSC',
#  'myeloid dividing',
#  'Ciliated',
#  'Tumor LUSC_mitotic2',
#  'Tumor LUSC_mitotic',
#  'T cell CD8 dividing',
#  'Tumor LUSC_mainly2',
#  'Tumor mitotic_LUSC',
#  'Tumor mixed_LUAD',
#  'T cell CD4 dividing',
#  'Tumor mitotic_mixed',
#  'Tumor LUAD_mainly1',
#  'Fibroblast alveolar',
#  'Tumor cells LUAD',
#  'Pericyte',
#  'pDC',
#  'Fibroblast adventitial',
#  'Monocyte non-classical',
#  'DC mature',
#  'cDC1',
#  'Club',
#  'Smooth muscle cell',
#  'Endothelial cell capillary',
#  'Tumor LUAD_EMT2',
#  'Alveolar cell type 1',
#  'Plasma cell dividing',
#  'stromal dividing',
#  'Endothelial cell lymphatic',
#  'NK cell dividing',
#  'B cell dividing',
#  'Endothelial cell arterial',
#  'Tumor LUAD_EMT3',
#  'Tumor cells LUAD mitotic',
#  'Mesothelial',
#  'ROS1+ healthy epithelial',
#  'Tumor cells LUSC']

# %% [markdown]
# For the extended dataset and late stage cancer it took 6hours

# %%
# %%time

if load_wilcoxon:
    adata.uns[key_pair] = np.load(all_path + '_pair.npy', allow_pickle='TRUE').item()
else:
    # TODO Adress this: is sensitive to the population composition, which introduces an element of unpredictability to the marker sets due to variation in cell type abundances
    # Solved by using pairwise wilcoxon
    results = ut.rank_genes_groups_pairwise(adata, 'type_tissue', method='wilcoxon', use_raw=False,
                       groups=valid_types, parallel=False)
    adata.uns[key_pair] = results
    np.save(all_path + '_pair.npy', adata.uns[key_pair])
# Out:
# Comparing T cell CD4_vs_Macrophage
# Comparing T cell CD4_vs_T cell CD8 effector memory
# Comparing T cell CD4_vs_B cell
# Comparing T cell CD4_vs_T cell regulatory
# Comparing T cell CD4_vs_Plasma cell
# Comparing T cell CD4_vs_Macrophage alveolar
# Comparing T cell CD4_vs_transitional club/AT2
# Comparing T cell CD4_vs_T cell CD8 terminally exhausted
# Comparing T cell CD4_vs_Neutrophils
# Comparing T cell CD4_vs_Tumor LUAD_transitional
# Comparing T cell CD4_vs_NK cell
# Comparing T cell CD4_vs_Monocyte classical
# Comparing T cell CD4_vs_cDC2
# Comparing T cell CD4_vs_Tumor LUAD_mitotic
# Comparing T cell CD4_vs_Mast cell
# Comparing T cell CD4_vs_Tumor LUAD_EMT1
# Comparing T cell CD4_vs_Tumor LUAD_LUSC_mitotic
# Comparing T cell CD4_vs_Alveolar cell type 2
# Comparing T cell CD4_vs_T cell NK-like
# Comparing T cell CD4_vs_Tumor LUSC_mainly
# Comparing T cell CD4_vs_Fibroblast peribronchial
# Comparing T cell CD4_vs_Tumor LUAD_mixed
# Comparing T cell CD4_vs_T cell CD8 activated
# Comparing T cell CD4_vs_Tumor LUSC_LUAD_mitotic
# Comparing T cell CD4_vs_T cell CD8 naive
# Comparing T cell CD4_vs_Tumor LUAD_Club
# Comparing T cell CD4_vs_Endothelial cell venous
# Comparing T cell CD4_vs_Tumor LUAD_LUSC
# Comparing T cell CD4_vs_myeloid dividing
# Comparing T cell CD4_vs_Ciliated
# Comparing T cell CD4_vs_Tumor LUSC_mitotic2
# Comparing T cell CD4_vs_Tumor LUSC_mitotic
# Comparing T cell CD4_vs_T cell CD8 dividing
# Comparing T cell CD4_vs_Tumor LUSC_mainly2
# Comparing T cell CD4_vs_Tumor mitotic_LUSC
# Comparing T cell CD4_vs_Tumor mixed_LUAD
# Comparing T cell CD4_vs_T cell CD4 dividing
# Comparing T cell CD4_vs_Tumor mitotic_mixed
# Comparing T cell CD4_vs_Tumor LUAD_mainly1
# Comparing T cell CD4_vs_Fibroblast alveolar
# Comparing T cell CD4_vs_Tumor cells LUAD
# Comparing T cell CD4_vs_Pericyte
# Comparing T cell CD4_vs_pDC
# Comparing T cell CD4_vs_Fibroblast adventitial
# Comparing T cell CD4_vs_Monocyte non-classical
# Comparing T cell CD4_vs_DC mature
# Comparing T cell CD4_vs_cDC1
# Comparing T cell CD4_vs_Club
# Comparing T cell CD4_vs_Smooth muscle cell
# Comparing T cell CD4_vs_Endothelial cell capillary
# Comparing T cell CD4_vs_Tumor LUAD_EMT2
# Comparing T cell CD4_vs_Alveolar cell type 1
# Comparing T cell CD4_vs_Plasma cell dividing
# Comparing T cell CD4_vs_stromal dividing
# Comparing T cell CD4_vs_Endothelial cell lymphatic
# Comparing T cell CD4_vs_NK cell dividing
# Comparing T cell CD4_vs_B cell dividing
# Comparing T cell CD4_vs_Endothelial cell arterial
# Comparing T cell CD4_vs_Tumor LUAD_EMT3
# Comparing T cell CD4_vs_Tumor cells LUAD mitotic
# Comparing T cell CD4_vs_Mesothelial
# Comparing T cell CD4_vs_ROS1+ healthy epithelial
# Comparing T cell CD4_vs_Tumor cells LUSC
# Comparing Macrophage_vs_T cell CD4
# Comparing Macrophage_vs_T cell CD8 effector memory
# Comparing Macrophage_vs_B cell
# Comparing Macrophage_vs_T cell regulatory
# Comparing Macrophage_vs_Plasma cell
# Comparing Macrophage_vs_Macrophage alveolar
# Comparing Macrophage_vs_transitional club/AT2
# Comparing Macrophage_vs_T cell CD8 terminally exhausted
# Comparing Macrophage_vs_Neutrophils
# Comparing Macrophage_vs_Tumor LUAD_transitional
# Comparing Macrophage_vs_NK cell
# Comparing Macrophage_vs_Monocyte classical
# Comparing Macrophage_vs_cDC2
# Comparing Macrophage_vs_Tumor LUAD_mitotic
# Comparing Macrophage_vs_Mast cell
# Comparing Macrophage_vs_Tumor LUAD_EMT1
# Comparing Macrophage_vs_Tumor LUAD_LUSC_mitotic
# Comparing Macrophage_vs_Alveolar cell type 2
# Comparing Macrophage_vs_T cell NK-like
# Comparing Macrophage_vs_Tumor LUSC_mainly
# Comparing Macrophage_vs_Fibroblast peribronchial
# Comparing Macrophage_vs_Tumor LUAD_mixed
# Comparing Macrophage_vs_T cell CD8 activated
# Comparing Macrophage_vs_Tumor LUSC_LUAD_mitotic
# Comparing Macrophage_vs_T cell CD8 naive
# Comparing Macrophage_vs_Tumor LUAD_Club
# Comparing Macrophage_vs_Endothelial cell venous
# Comparing Macrophage_vs_Tumor LUAD_LUSC
# Comparing Macrophage_vs_myeloid dividing
# Comparing Macrophage_vs_Ciliated
# Comparing Macrophage_vs_Tumor LUSC_mitotic2
# Comparing Macrophage_vs_Tumor LUSC_mitotic
# Comparing Macrophage_vs_T cell CD8 dividing
# Comparing Macrophage_vs_Tumor LUSC_mainly2
# Comparing Macrophage_vs_Tumor mitotic_LUSC
# Comparing Macrophage_vs_Tumor mixed_LUAD
# Comparing Macrophage_vs_T cell CD4 dividing
# Comparing Macrophage_vs_Tumor mitotic_mixed
# Comparing Macrophage_vs_Tumor LUAD_mainly1
# Comparing Macrophage_vs_Fibroblast alveolar
# Comparing Macrophage_vs_Tumor cells LUAD
# Comparing Macrophage_vs_Pericyte
# Comparing Macrophage_vs_pDC
# Comparing Macrophage_vs_Fibroblast adventitial
# Comparing Macrophage_vs_Monocyte non-classical
# Comparing Macrophage_vs_DC mature
# Comparing Macrophage_vs_cDC1
# Comparing Macrophage_vs_Club
# Comparing Macrophage_vs_Smooth muscle cell
# Comparing Macrophage_vs_Endothelial cell capillary
# Comparing Macrophage_vs_Tumor LUAD_EMT2
# Comparing Macrophage_vs_Alveolar cell type 1
# Comparing Macrophage_vs_Plasma cell dividing
# Comparing Macrophage_vs_stromal dividing
# Comparing Macrophage_vs_Endothelial cell lymphatic
# Comparing Macrophage_vs_NK cell dividing
# Comparing Macrophage_vs_B cell dividing
# Comparing Macrophage_vs_Endothelial cell arterial
# Comparing Macrophage_vs_Tumor LUAD_EMT3
# Comparing Macrophage_vs_Tumor cells LUAD mitotic
# Comparing Macrophage_vs_Mesothelial
# Comparing Macrophage_vs_ROS1+ healthy epithelial
# Comparing Macrophage_vs_Tumor cells LUSC
# Comparing T cell CD8 effector memory_vs_T cell CD4
# Comparing T cell CD8 effector memory_vs_Macrophage
# Comparing T cell CD8 effector memory_vs_B cell
# Comparing T cell CD8 effector memory_vs_T cell regulatory
# Comparing T cell CD8 effector memory_vs_Plasma cell
# Comparing T cell CD8 effector memory_vs_Macrophage alveolar
# Comparing T cell CD8 effector memory_vs_transitional club/AT2
# Comparing T cell CD8 effector memory_vs_T cell CD8 terminally exhausted
# Comparing T cell CD8 effector memory_vs_Neutrophils
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_transitional
# Comparing T cell CD8 effector memory_vs_NK cell
# Comparing T cell CD8 effector memory_vs_Monocyte classical
# Comparing T cell CD8 effector memory_vs_cDC2
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_mitotic
# Comparing T cell CD8 effector memory_vs_Mast cell
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_EMT1
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_LUSC_mitotic
# Comparing T cell CD8 effector memory_vs_Alveolar cell type 2
# Comparing T cell CD8 effector memory_vs_T cell NK-like
# Comparing T cell CD8 effector memory_vs_Tumor LUSC_mainly
# Comparing T cell CD8 effector memory_vs_Fibroblast peribronchial
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_mixed
# Comparing T cell CD8 effector memory_vs_T cell CD8 activated
# Comparing T cell CD8 effector memory_vs_Tumor LUSC_LUAD_mitotic
# Comparing T cell CD8 effector memory_vs_T cell CD8 naive
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_Club
# Comparing T cell CD8 effector memory_vs_Endothelial cell venous
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_LUSC
# Comparing T cell CD8 effector memory_vs_myeloid dividing
# Comparing T cell CD8 effector memory_vs_Ciliated
# Comparing T cell CD8 effector memory_vs_Tumor LUSC_mitotic2
# Comparing T cell CD8 effector memory_vs_Tumor LUSC_mitotic
# Comparing T cell CD8 effector memory_vs_T cell CD8 dividing
# Comparing T cell CD8 effector memory_vs_Tumor LUSC_mainly2
# Comparing T cell CD8 effector memory_vs_Tumor mitotic_LUSC
# Comparing T cell CD8 effector memory_vs_Tumor mixed_LUAD
# Comparing T cell CD8 effector memory_vs_T cell CD4 dividing
# Comparing T cell CD8 effector memory_vs_Tumor mitotic_mixed
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_mainly1
# Comparing T cell CD8 effector memory_vs_Fibroblast alveolar
# Comparing T cell CD8 effector memory_vs_Tumor cells LUAD
# Comparing T cell CD8 effector memory_vs_Pericyte
# Comparing T cell CD8 effector memory_vs_pDC
# Comparing T cell CD8 effector memory_vs_Fibroblast adventitial
# Comparing T cell CD8 effector memory_vs_Monocyte non-classical
# Comparing T cell CD8 effector memory_vs_DC mature
# Comparing T cell CD8 effector memory_vs_cDC1
# Comparing T cell CD8 effector memory_vs_Club
# Comparing T cell CD8 effector memory_vs_Smooth muscle cell
# Comparing T cell CD8 effector memory_vs_Endothelial cell capillary
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_EMT2
# Comparing T cell CD8 effector memory_vs_Alveolar cell type 1
# Comparing T cell CD8 effector memory_vs_Plasma cell dividing
# Comparing T cell CD8 effector memory_vs_stromal dividing
# Comparing T cell CD8 effector memory_vs_Endothelial cell lymphatic
# Comparing T cell CD8 effector memory_vs_NK cell dividing
# Comparing T cell CD8 effector memory_vs_B cell dividing
# Comparing T cell CD8 effector memory_vs_Endothelial cell arterial
# Comparing T cell CD8 effector memory_vs_Tumor LUAD_EMT3
# Comparing T cell CD8 effector memory_vs_Tumor cells LUAD mitotic
# Comparing T cell CD8 effector memory_vs_Mesothelial
# Comparing T cell CD8 effector memory_vs_ROS1+ healthy epithelial
# Comparing T cell CD8 effector memory_vs_Tumor cells LUSC
# Comparing B cell_vs_T cell CD4
# Comparing B cell_vs_Macrophage
# Comparing B cell_vs_T cell CD8 effector memory
# Comparing B cell_vs_T cell regulatory
# Comparing B cell_vs_Plasma cell
# Comparing B cell_vs_Macrophage alveolar
# Comparing B cell_vs_transitional club/AT2
# Comparing B cell_vs_T cell CD8 terminally exhausted
# Comparing B cell_vs_Neutrophils
# Comparing B cell_vs_Tumor LUAD_transitional
# Comparing B cell_vs_NK cell
# Comparing B cell_vs_Monocyte classical
# Comparing B cell_vs_cDC2
# Comparing B cell_vs_Tumor LUAD_mitotic
# Comparing B cell_vs_Mast cell
# Comparing B cell_vs_Tumor LUAD_EMT1
# Comparing B cell_vs_Tumor LUAD_LUSC_mitotic
# Comparing B cell_vs_Alveolar cell type 2
# Comparing B cell_vs_T cell NK-like
# Comparing B cell_vs_Tumor LUSC_mainly
# Comparing B cell_vs_Fibroblast peribronchial
# Comparing B cell_vs_Tumor LUAD_mixed
# Comparing B cell_vs_T cell CD8 activated
# Comparing B cell_vs_Tumor LUSC_LUAD_mitotic
# Comparing B cell_vs_T cell CD8 naive
# Comparing B cell_vs_Tumor LUAD_Club
# Comparing B cell_vs_Endothelial cell venous
# Comparing B cell_vs_Tumor LUAD_LUSC
# Comparing B cell_vs_myeloid dividing
# Comparing B cell_vs_Ciliated
# Comparing B cell_vs_Tumor LUSC_mitotic2
# Comparing B cell_vs_Tumor LUSC_mitotic
# Comparing B cell_vs_T cell CD8 dividing
# Comparing B cell_vs_Tumor LUSC_mainly2
# Comparing B cell_vs_Tumor mitotic_LUSC
# Comparing B cell_vs_Tumor mixed_LUAD
# Comparing B cell_vs_T cell CD4 dividing
# Comparing B cell_vs_Tumor mitotic_mixed
# Comparing B cell_vs_Tumor LUAD_mainly1
# Comparing B cell_vs_Fibroblast alveolar
# Comparing B cell_vs_Tumor cells LUAD
# Comparing B cell_vs_Pericyte
# Comparing B cell_vs_pDC
# Comparing B cell_vs_Fibroblast adventitial
# Comparing B cell_vs_Monocyte non-classical
# Comparing B cell_vs_DC mature
# Comparing B cell_vs_cDC1
# Comparing B cell_vs_Club
# Comparing B cell_vs_Smooth muscle cell
# Comparing B cell_vs_Endothelial cell capillary
# Comparing B cell_vs_Tumor LUAD_EMT2
# Comparing B cell_vs_Alveolar cell type 1
# Comparing B cell_vs_Plasma cell dividing
# Comparing B cell_vs_stromal dividing
# Comparing B cell_vs_Endothelial cell lymphatic
# Comparing B cell_vs_NK cell dividing
# Comparing B cell_vs_B cell dividing
# Comparing B cell_vs_Endothelial cell arterial
# Comparing B cell_vs_Tumor LUAD_EMT3
# Comparing B cell_vs_Tumor cells LUAD mitotic
# Comparing B cell_vs_Mesothelial
# Comparing B cell_vs_ROS1+ healthy epithelial
# Comparing B cell_vs_Tumor cells LUSC
# Comparing T cell regulatory_vs_T cell CD4
# Comparing T cell regulatory_vs_Macrophage
# Comparing T cell regulatory_vs_T cell CD8 effector memory
# Comparing T cell regulatory_vs_B cell
# Comparing T cell regulatory_vs_Plasma cell
# Comparing T cell regulatory_vs_Macrophage alveolar
# Comparing T cell regulatory_vs_transitional club/AT2
# Comparing T cell regulatory_vs_T cell CD8 terminally exhausted
# Comparing T cell regulatory_vs_Neutrophils
# Comparing T cell regulatory_vs_Tumor LUAD_transitional
# Comparing T cell regulatory_vs_NK cell
# Comparing T cell regulatory_vs_Monocyte classical
# Comparing T cell regulatory_vs_cDC2
# Comparing T cell regulatory_vs_Tumor LUAD_mitotic
# Comparing T cell regulatory_vs_Mast cell
# Comparing T cell regulatory_vs_Tumor LUAD_EMT1
# Comparing T cell regulatory_vs_Tumor LUAD_LUSC_mitotic
# Comparing T cell regulatory_vs_Alveolar cell type 2
# Comparing T cell regulatory_vs_T cell NK-like
# Comparing T cell regulatory_vs_Tumor LUSC_mainly
# Comparing T cell regulatory_vs_Fibroblast peribronchial
# Comparing T cell regulatory_vs_Tumor LUAD_mixed
# Comparing T cell regulatory_vs_T cell CD8 activated
# Comparing T cell regulatory_vs_Tumor LUSC_LUAD_mitotic
# Comparing T cell regulatory_vs_T cell CD8 naive
# Comparing T cell regulatory_vs_Tumor LUAD_Club
# Comparing T cell regulatory_vs_Endothelial cell venous
# Comparing T cell regulatory_vs_Tumor LUAD_LUSC
# Comparing T cell regulatory_vs_myeloid dividing
# Comparing T cell regulatory_vs_Ciliated
# Comparing T cell regulatory_vs_Tumor LUSC_mitotic2
# Comparing T cell regulatory_vs_Tumor LUSC_mitotic
# Comparing T cell regulatory_vs_T cell CD8 dividing
# Comparing T cell regulatory_vs_Tumor LUSC_mainly2
# Comparing T cell regulatory_vs_Tumor mitotic_LUSC
# Comparing T cell regulatory_vs_Tumor mixed_LUAD
# Comparing T cell regulatory_vs_T cell CD4 dividing
# Comparing T cell regulatory_vs_Tumor mitotic_mixed
# Comparing T cell regulatory_vs_Tumor LUAD_mainly1
# Comparing T cell regulatory_vs_Fibroblast alveolar
# Comparing T cell regulatory_vs_Tumor cells LUAD
# Comparing T cell regulatory_vs_Pericyte
# Comparing T cell regulatory_vs_pDC
# Comparing T cell regulatory_vs_Fibroblast adventitial
# Comparing T cell regulatory_vs_Monocyte non-classical
# Comparing T cell regulatory_vs_DC mature
# Comparing T cell regulatory_vs_cDC1
# Comparing T cell regulatory_vs_Club
# Comparing T cell regulatory_vs_Smooth muscle cell
# Comparing T cell regulatory_vs_Endothelial cell capillary
# Comparing T cell regulatory_vs_Tumor LUAD_EMT2
# Comparing T cell regulatory_vs_Alveolar cell type 1
# Comparing T cell regulatory_vs_Plasma cell dividing
# Comparing T cell regulatory_vs_stromal dividing
# Comparing T cell regulatory_vs_Endothelial cell lymphatic
# Comparing T cell regulatory_vs_NK cell dividing
# Comparing T cell regulatory_vs_B cell dividing
# Comparing T cell regulatory_vs_Endothelial cell arterial
# Comparing T cell regulatory_vs_Tumor LUAD_EMT3
# Comparing T cell regulatory_vs_Tumor cells LUAD mitotic
# Comparing T cell regulatory_vs_Mesothelial
# Comparing T cell regulatory_vs_ROS1+ healthy epithelial
# Comparing T cell regulatory_vs_Tumor cells LUSC
# Comparing Plasma cell_vs_T cell CD4
# Comparing Plasma cell_vs_Macrophage
# Comparing Plasma cell_vs_T cell CD8 effector memory
# Comparing Plasma cell_vs_B cell
# Comparing Plasma cell_vs_T cell regulatory
# Comparing Plasma cell_vs_Macrophage alveolar
# Comparing Plasma cell_vs_transitional club/AT2
# Comparing Plasma cell_vs_T cell CD8 terminally exhausted
# Comparing Plasma cell_vs_Neutrophils
# Comparing Plasma cell_vs_Tumor LUAD_transitional
# Comparing Plasma cell_vs_NK cell
# Comparing Plasma cell_vs_Monocyte classical
# Comparing Plasma cell_vs_cDC2
# Comparing Plasma cell_vs_Tumor LUAD_mitotic
# Comparing Plasma cell_vs_Mast cell
# Comparing Plasma cell_vs_Tumor LUAD_EMT1
# Comparing Plasma cell_vs_Tumor LUAD_LUSC_mitotic
# Comparing Plasma cell_vs_Alveolar cell type 2
# Comparing Plasma cell_vs_T cell NK-like
# Comparing Plasma cell_vs_Tumor LUSC_mainly
# Comparing Plasma cell_vs_Fibroblast peribronchial
# Comparing Plasma cell_vs_Tumor LUAD_mixed
# Comparing Plasma cell_vs_T cell CD8 activated
# Comparing Plasma cell_vs_Tumor LUSC_LUAD_mitotic
# Comparing Plasma cell_vs_T cell CD8 naive
# Comparing Plasma cell_vs_Tumor LUAD_Club
# Comparing Plasma cell_vs_Endothelial cell venous
# Comparing Plasma cell_vs_Tumor LUAD_LUSC
# Comparing Plasma cell_vs_myeloid dividing
# Comparing Plasma cell_vs_Ciliated
# Comparing Plasma cell_vs_Tumor LUSC_mitotic2
# Comparing Plasma cell_vs_Tumor LUSC_mitotic
# Comparing Plasma cell_vs_T cell CD8 dividing
# Comparing Plasma cell_vs_Tumor LUSC_mainly2
# Comparing Plasma cell_vs_Tumor mitotic_LUSC
# Comparing Plasma cell_vs_Tumor mixed_LUAD
# Comparing Plasma cell_vs_T cell CD4 dividing
# Comparing Plasma cell_vs_Tumor mitotic_mixed
# Comparing Plasma cell_vs_Tumor LUAD_mainly1
# Comparing Plasma cell_vs_Fibroblast alveolar
# Comparing Plasma cell_vs_Tumor cells LUAD
# Comparing Plasma cell_vs_Pericyte
# Comparing Plasma cell_vs_pDC
# Comparing Plasma cell_vs_Fibroblast adventitial
# Comparing Plasma cell_vs_Monocyte non-classical
# Comparing Plasma cell_vs_DC mature
# Comparing Plasma cell_vs_cDC1
# Comparing Plasma cell_vs_Club
# Comparing Plasma cell_vs_Smooth muscle cell
# Comparing Plasma cell_vs_Endothelial cell capillary
# Comparing Plasma cell_vs_Tumor LUAD_EMT2
# Comparing Plasma cell_vs_Alveolar cell type 1
# Comparing Plasma cell_vs_Plasma cell dividing
# Comparing Plasma cell_vs_stromal dividing
# Comparing Plasma cell_vs_Endothelial cell lymphatic
# Comparing Plasma cell_vs_NK cell dividing
# Comparing Plasma cell_vs_B cell dividing
# Comparing Plasma cell_vs_Endothelial cell arterial
# Comparing Plasma cell_vs_Tumor LUAD_EMT3
# Comparing Plasma cell_vs_Tumor cells LUAD mitotic
# Comparing Plasma cell_vs_Mesothelial
# Comparing Plasma cell_vs_ROS1+ healthy epithelial
# Comparing Plasma cell_vs_Tumor cells LUSC
# Comparing Macrophage alveolar_vs_T cell CD4
# Comparing Macrophage alveolar_vs_Macrophage
# Comparing Macrophage alveolar_vs_T cell CD8 effector memory
# Comparing Macrophage alveolar_vs_B cell
# Comparing Macrophage alveolar_vs_T cell regulatory
# Comparing Macrophage alveolar_vs_Plasma cell
# Comparing Macrophage alveolar_vs_transitional club/AT2
# Comparing Macrophage alveolar_vs_T cell CD8 terminally exhausted
# Comparing Macrophage alveolar_vs_Neutrophils
# Comparing Macrophage alveolar_vs_Tumor LUAD_transitional
# Comparing Macrophage alveolar_vs_NK cell
# Comparing Macrophage alveolar_vs_Monocyte classical
# Comparing Macrophage alveolar_vs_cDC2
# Comparing Macrophage alveolar_vs_Tumor LUAD_mitotic
# Comparing Macrophage alveolar_vs_Mast cell
# Comparing Macrophage alveolar_vs_Tumor LUAD_EMT1
# Comparing Macrophage alveolar_vs_Tumor LUAD_LUSC_mitotic
# Comparing Macrophage alveolar_vs_Alveolar cell type 2
# Comparing Macrophage alveolar_vs_T cell NK-like
# Comparing Macrophage alveolar_vs_Tumor LUSC_mainly
# Comparing Macrophage alveolar_vs_Fibroblast peribronchial
# Comparing Macrophage alveolar_vs_Tumor LUAD_mixed
# Comparing Macrophage alveolar_vs_T cell CD8 activated
# Comparing Macrophage alveolar_vs_Tumor LUSC_LUAD_mitotic
# Comparing Macrophage alveolar_vs_T cell CD8 naive
# Comparing Macrophage alveolar_vs_Tumor LUAD_Club
# Comparing Macrophage alveolar_vs_Endothelial cell venous
# Comparing Macrophage alveolar_vs_Tumor LUAD_LUSC
# Comparing Macrophage alveolar_vs_myeloid dividing
# Comparing Macrophage alveolar_vs_Ciliated
# Comparing Macrophage alveolar_vs_Tumor LUSC_mitotic2
# Comparing Macrophage alveolar_vs_Tumor LUSC_mitotic
# Comparing Macrophage alveolar_vs_T cell CD8 dividing
# Comparing Macrophage alveolar_vs_Tumor LUSC_mainly2
# Comparing Macrophage alveolar_vs_Tumor mitotic_LUSC
# Comparing Macrophage alveolar_vs_Tumor mixed_LUAD
# Comparing Macrophage alveolar_vs_T cell CD4 dividing
# Comparing Macrophage alveolar_vs_Tumor mitotic_mixed
# Comparing Macrophage alveolar_vs_Tumor LUAD_mainly1
# Comparing Macrophage alveolar_vs_Fibroblast alveolar
# Comparing Macrophage alveolar_vs_Tumor cells LUAD
# Comparing Macrophage alveolar_vs_Pericyte
# Comparing Macrophage alveolar_vs_pDC
# Comparing Macrophage alveolar_vs_Fibroblast adventitial
# Comparing Macrophage alveolar_vs_Monocyte non-classical
# Comparing Macrophage alveolar_vs_DC mature
# Comparing Macrophage alveolar_vs_cDC1
# Comparing Macrophage alveolar_vs_Club
# Comparing Macrophage alveolar_vs_Smooth muscle cell
# Comparing Macrophage alveolar_vs_Endothelial cell capillary
# Comparing Macrophage alveolar_vs_Tumor LUAD_EMT2
# Comparing Macrophage alveolar_vs_Alveolar cell type 1
# Comparing Macrophage alveolar_vs_Plasma cell dividing
# Comparing Macrophage alveolar_vs_stromal dividing
# Comparing Macrophage alveolar_vs_Endothelial cell lymphatic
# Comparing Macrophage alveolar_vs_NK cell dividing
# Comparing Macrophage alveolar_vs_B cell dividing
# Comparing Macrophage alveolar_vs_Endothelial cell arterial
# Comparing Macrophage alveolar_vs_Tumor LUAD_EMT3
# Comparing Macrophage alveolar_vs_Tumor cells LUAD mitotic
# Comparing Macrophage alveolar_vs_Mesothelial
# Comparing Macrophage alveolar_vs_ROS1+ healthy epithelial
# Comparing Macrophage alveolar_vs_Tumor cells LUSC
# Comparing transitional club/AT2_vs_T cell CD4
# Comparing transitional club/AT2_vs_Macrophage
# Comparing transitional club/AT2_vs_T cell CD8 effector memory
# Comparing transitional club/AT2_vs_B cell
# Comparing transitional club/AT2_vs_T cell regulatory
# Comparing transitional club/AT2_vs_Plasma cell
# Comparing transitional club/AT2_vs_Macrophage alveolar
# Comparing transitional club/AT2_vs_T cell CD8 terminally exhausted
# Comparing transitional club/AT2_vs_Neutrophils
# Comparing transitional club/AT2_vs_Tumor LUAD_transitional
# Comparing transitional club/AT2_vs_NK cell
# Comparing transitional club/AT2_vs_Monocyte classical
# Comparing transitional club/AT2_vs_cDC2
# Comparing transitional club/AT2_vs_Tumor LUAD_mitotic
# Comparing transitional club/AT2_vs_Mast cell
# Comparing transitional club/AT2_vs_Tumor LUAD_EMT1
# Comparing transitional club/AT2_vs_Tumor LUAD_LUSC_mitotic
# Comparing transitional club/AT2_vs_Alveolar cell type 2
# Comparing transitional club/AT2_vs_T cell NK-like
# Comparing transitional club/AT2_vs_Tumor LUSC_mainly
# Comparing transitional club/AT2_vs_Fibroblast peribronchial
# Comparing transitional club/AT2_vs_Tumor LUAD_mixed
# Comparing transitional club/AT2_vs_T cell CD8 activated
# Comparing transitional club/AT2_vs_Tumor LUSC_LUAD_mitotic
# Comparing transitional club/AT2_vs_T cell CD8 naive
# Comparing transitional club/AT2_vs_Tumor LUAD_Club
# Comparing transitional club/AT2_vs_Endothelial cell venous
# Comparing transitional club/AT2_vs_Tumor LUAD_LUSC
# Comparing transitional club/AT2_vs_myeloid dividing
# Comparing transitional club/AT2_vs_Ciliated
# Comparing transitional club/AT2_vs_Tumor LUSC_mitotic2
# Comparing transitional club/AT2_vs_Tumor LUSC_mitotic
# Comparing transitional club/AT2_vs_T cell CD8 dividing
# Comparing transitional club/AT2_vs_Tumor LUSC_mainly2
# Comparing transitional club/AT2_vs_Tumor mitotic_LUSC
# Comparing transitional club/AT2_vs_Tumor mixed_LUAD
# Comparing transitional club/AT2_vs_T cell CD4 dividing
# Comparing transitional club/AT2_vs_Tumor mitotic_mixed
# Comparing transitional club/AT2_vs_Tumor LUAD_mainly1
# Comparing transitional club/AT2_vs_Fibroblast alveolar
# Comparing transitional club/AT2_vs_Tumor cells LUAD
# Comparing transitional club/AT2_vs_Pericyte
# Comparing transitional club/AT2_vs_pDC
# Comparing transitional club/AT2_vs_Fibroblast adventitial
# Comparing transitional club/AT2_vs_Monocyte non-classical
# Comparing transitional club/AT2_vs_DC mature
# Comparing transitional club/AT2_vs_cDC1
# Comparing transitional club/AT2_vs_Club
# Comparing transitional club/AT2_vs_Smooth muscle cell
# Comparing transitional club/AT2_vs_Endothelial cell capillary
# Comparing transitional club/AT2_vs_Tumor LUAD_EMT2
# Comparing transitional club/AT2_vs_Alveolar cell type 1
# Comparing transitional club/AT2_vs_Plasma cell dividing
# Comparing transitional club/AT2_vs_stromal dividing
# Comparing transitional club/AT2_vs_Endothelial cell lymphatic
# Comparing transitional club/AT2_vs_NK cell dividing
# Comparing transitional club/AT2_vs_B cell dividing
# Comparing transitional club/AT2_vs_Endothelial cell arterial
# Comparing transitional club/AT2_vs_Tumor LUAD_EMT3
# Comparing transitional club/AT2_vs_Tumor cells LUAD mitotic
# Comparing transitional club/AT2_vs_Mesothelial
# Comparing transitional club/AT2_vs_ROS1+ healthy epithelial
# Comparing transitional club/AT2_vs_Tumor cells LUSC
# Comparing T cell CD8 terminally exhausted_vs_T cell CD4
# Comparing T cell CD8 terminally exhausted_vs_Macrophage
# Comparing T cell CD8 terminally exhausted_vs_T cell CD8 effector memory
# Comparing T cell CD8 terminally exhausted_vs_B cell
# Comparing T cell CD8 terminally exhausted_vs_T cell regulatory
# Comparing T cell CD8 terminally exhausted_vs_Plasma cell
# Comparing T cell CD8 terminally exhausted_vs_Macrophage alveolar
# Comparing T cell CD8 terminally exhausted_vs_transitional club/AT2
# Comparing T cell CD8 terminally exhausted_vs_Neutrophils
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_transitional
# Comparing T cell CD8 terminally exhausted_vs_NK cell
# Comparing T cell CD8 terminally exhausted_vs_Monocyte classical
# Comparing T cell CD8 terminally exhausted_vs_cDC2
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_mitotic
# Comparing T cell CD8 terminally exhausted_vs_Mast cell
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_EMT1
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_LUSC_mitotic
# Comparing T cell CD8 terminally exhausted_vs_Alveolar cell type 2
# Comparing T cell CD8 terminally exhausted_vs_T cell NK-like
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUSC_mainly
# Comparing T cell CD8 terminally exhausted_vs_Fibroblast peribronchial
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_mixed
# Comparing T cell CD8 terminally exhausted_vs_T cell CD8 activated
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUSC_LUAD_mitotic
# Comparing T cell CD8 terminally exhausted_vs_T cell CD8 naive
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_Club
# Comparing T cell CD8 terminally exhausted_vs_Endothelial cell venous
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_LUSC
# Comparing T cell CD8 terminally exhausted_vs_myeloid dividing
# Comparing T cell CD8 terminally exhausted_vs_Ciliated
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUSC_mitotic2
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUSC_mitotic
# Comparing T cell CD8 terminally exhausted_vs_T cell CD8 dividing
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUSC_mainly2
# Comparing T cell CD8 terminally exhausted_vs_Tumor mitotic_LUSC
# Comparing T cell CD8 terminally exhausted_vs_Tumor mixed_LUAD
# Comparing T cell CD8 terminally exhausted_vs_T cell CD4 dividing
# Comparing T cell CD8 terminally exhausted_vs_Tumor mitotic_mixed
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_mainly1
# Comparing T cell CD8 terminally exhausted_vs_Fibroblast alveolar
# Comparing T cell CD8 terminally exhausted_vs_Tumor cells LUAD
# Comparing T cell CD8 terminally exhausted_vs_Pericyte
# Comparing T cell CD8 terminally exhausted_vs_pDC
# Comparing T cell CD8 terminally exhausted_vs_Fibroblast adventitial
# Comparing T cell CD8 terminally exhausted_vs_Monocyte non-classical
# Comparing T cell CD8 terminally exhausted_vs_DC mature
# Comparing T cell CD8 terminally exhausted_vs_cDC1
# Comparing T cell CD8 terminally exhausted_vs_Club
# Comparing T cell CD8 terminally exhausted_vs_Smooth muscle cell
# Comparing T cell CD8 terminally exhausted_vs_Endothelial cell capillary
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_EMT2
# Comparing T cell CD8 terminally exhausted_vs_Alveolar cell type 1
# Comparing T cell CD8 terminally exhausted_vs_Plasma cell dividing
# Comparing T cell CD8 terminally exhausted_vs_stromal dividing
# Comparing T cell CD8 terminally exhausted_vs_Endothelial cell lymphatic
# Comparing T cell CD8 terminally exhausted_vs_NK cell dividing
# Comparing T cell CD8 terminally exhausted_vs_B cell dividing
# Comparing T cell CD8 terminally exhausted_vs_Endothelial cell arterial
# Comparing T cell CD8 terminally exhausted_vs_Tumor LUAD_EMT3
# Comparing T cell CD8 terminally exhausted_vs_Tumor cells LUAD mitotic
# Comparing T cell CD8 terminally exhausted_vs_Mesothelial
# Comparing T cell CD8 terminally exhausted_vs_ROS1+ healthy epithelial
# Comparing T cell CD8 terminally exhausted_vs_Tumor cells LUSC
# Comparing Neutrophils_vs_T cell CD4
# Comparing Neutrophils_vs_Macrophage
# Comparing Neutrophils_vs_T cell CD8 effector memory
# Comparing Neutrophils_vs_B cell
# Comparing Neutrophils_vs_T cell regulatory
# Comparing Neutrophils_vs_Plasma cell
# Comparing Neutrophils_vs_Macrophage alveolar
# Comparing Neutrophils_vs_transitional club/AT2
# Comparing Neutrophils_vs_T cell CD8 terminally exhausted
# Comparing Neutrophils_vs_Tumor LUAD_transitional
# Comparing Neutrophils_vs_NK cell
# Comparing Neutrophils_vs_Monocyte classical
# Comparing Neutrophils_vs_cDC2
# Comparing Neutrophils_vs_Tumor LUAD_mitotic
# Comparing Neutrophils_vs_Mast cell
# Comparing Neutrophils_vs_Tumor LUAD_EMT1
# Comparing Neutrophils_vs_Tumor LUAD_LUSC_mitotic
# Comparing Neutrophils_vs_Alveolar cell type 2
# Comparing Neutrophils_vs_T cell NK-like
# Comparing Neutrophils_vs_Tumor LUSC_mainly
# Comparing Neutrophils_vs_Fibroblast peribronchial
# Comparing Neutrophils_vs_Tumor LUAD_mixed
# Comparing Neutrophils_vs_T cell CD8 activated
# Comparing Neutrophils_vs_Tumor LUSC_LUAD_mitotic
# Comparing Neutrophils_vs_T cell CD8 naive
# Comparing Neutrophils_vs_Tumor LUAD_Club
# Comparing Neutrophils_vs_Endothelial cell venous
# Comparing Neutrophils_vs_Tumor LUAD_LUSC
# Comparing Neutrophils_vs_myeloid dividing
# Comparing Neutrophils_vs_Ciliated
# Comparing Neutrophils_vs_Tumor LUSC_mitotic2
# Comparing Neutrophils_vs_Tumor LUSC_mitotic
# Comparing Neutrophils_vs_T cell CD8 dividing
# Comparing Neutrophils_vs_Tumor LUSC_mainly2
# Comparing Neutrophils_vs_Tumor mitotic_LUSC
# Comparing Neutrophils_vs_Tumor mixed_LUAD
# Comparing Neutrophils_vs_T cell CD4 dividing
# Comparing Neutrophils_vs_Tumor mitotic_mixed
# Comparing Neutrophils_vs_Tumor LUAD_mainly1
# Comparing Neutrophils_vs_Fibroblast alveolar
# Comparing Neutrophils_vs_Tumor cells LUAD
# Comparing Neutrophils_vs_Pericyte
# Comparing Neutrophils_vs_pDC
# Comparing Neutrophils_vs_Fibroblast adventitial
# Comparing Neutrophils_vs_Monocyte non-classical
# Comparing Neutrophils_vs_DC mature
# Comparing Neutrophils_vs_cDC1
# Comparing Neutrophils_vs_Club
# Comparing Neutrophils_vs_Smooth muscle cell
# Comparing Neutrophils_vs_Endothelial cell capillary
# Comparing Neutrophils_vs_Tumor LUAD_EMT2
# Comparing Neutrophils_vs_Alveolar cell type 1
# Comparing Neutrophils_vs_Plasma cell dividing
# Comparing Neutrophils_vs_stromal dividing
# Comparing Neutrophils_vs_Endothelial cell lymphatic
# Comparing Neutrophils_vs_NK cell dividing
# Comparing Neutrophils_vs_B cell dividing
# Comparing Neutrophils_vs_Endothelial cell arterial
# Comparing Neutrophils_vs_Tumor LUAD_EMT3
# Comparing Neutrophils_vs_Tumor cells LUAD mitotic
# Comparing Neutrophils_vs_Mesothelial
# Comparing Neutrophils_vs_ROS1+ healthy epithelial
# Comparing Neutrophils_vs_Tumor cells LUSC
# Comparing Tumor LUAD_transitional_vs_T cell CD4
# Comparing Tumor LUAD_transitional_vs_Macrophage
# Comparing Tumor LUAD_transitional_vs_T cell CD8 effector memory
# Comparing Tumor LUAD_transitional_vs_B cell
# Comparing Tumor LUAD_transitional_vs_T cell regulatory
# Comparing Tumor LUAD_transitional_vs_Plasma cell
# Comparing Tumor LUAD_transitional_vs_Macrophage alveolar
# Comparing Tumor LUAD_transitional_vs_transitional club/AT2
# Comparing Tumor LUAD_transitional_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUAD_transitional_vs_Neutrophils
# Comparing Tumor LUAD_transitional_vs_NK cell
# Comparing Tumor LUAD_transitional_vs_Monocyte classical
# Comparing Tumor LUAD_transitional_vs_cDC2
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_mitotic
# Comparing Tumor LUAD_transitional_vs_Mast cell
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_EMT1
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUAD_transitional_vs_Alveolar cell type 2
# Comparing Tumor LUAD_transitional_vs_T cell NK-like
# Comparing Tumor LUAD_transitional_vs_Tumor LUSC_mainly
# Comparing Tumor LUAD_transitional_vs_Fibroblast peribronchial
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_mixed
# Comparing Tumor LUAD_transitional_vs_T cell CD8 activated
# Comparing Tumor LUAD_transitional_vs_Tumor LUSC_LUAD_mitotic
# Comparing Tumor LUAD_transitional_vs_T cell CD8 naive
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_Club
# Comparing Tumor LUAD_transitional_vs_Endothelial cell venous
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_LUSC
# Comparing Tumor LUAD_transitional_vs_myeloid dividing
# Comparing Tumor LUAD_transitional_vs_Ciliated
# Comparing Tumor LUAD_transitional_vs_Tumor LUSC_mitotic2
# Comparing Tumor LUAD_transitional_vs_Tumor LUSC_mitotic
# Comparing Tumor LUAD_transitional_vs_T cell CD8 dividing
# Comparing Tumor LUAD_transitional_vs_Tumor LUSC_mainly2
# Comparing Tumor LUAD_transitional_vs_Tumor mitotic_LUSC
# Comparing Tumor LUAD_transitional_vs_Tumor mixed_LUAD
# Comparing Tumor LUAD_transitional_vs_T cell CD4 dividing
# Comparing Tumor LUAD_transitional_vs_Tumor mitotic_mixed
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_mainly1
# Comparing Tumor LUAD_transitional_vs_Fibroblast alveolar
# Comparing Tumor LUAD_transitional_vs_Tumor cells LUAD
# Comparing Tumor LUAD_transitional_vs_Pericyte
# Comparing Tumor LUAD_transitional_vs_pDC
# Comparing Tumor LUAD_transitional_vs_Fibroblast adventitial
# Comparing Tumor LUAD_transitional_vs_Monocyte non-classical
# Comparing Tumor LUAD_transitional_vs_DC mature
# Comparing Tumor LUAD_transitional_vs_cDC1
# Comparing Tumor LUAD_transitional_vs_Club
# Comparing Tumor LUAD_transitional_vs_Smooth muscle cell
# Comparing Tumor LUAD_transitional_vs_Endothelial cell capillary
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_EMT2
# Comparing Tumor LUAD_transitional_vs_Alveolar cell type 1
# Comparing Tumor LUAD_transitional_vs_Plasma cell dividing
# Comparing Tumor LUAD_transitional_vs_stromal dividing
# Comparing Tumor LUAD_transitional_vs_Endothelial cell lymphatic
# Comparing Tumor LUAD_transitional_vs_NK cell dividing
# Comparing Tumor LUAD_transitional_vs_B cell dividing
# Comparing Tumor LUAD_transitional_vs_Endothelial cell arterial
# Comparing Tumor LUAD_transitional_vs_Tumor LUAD_EMT3
# Comparing Tumor LUAD_transitional_vs_Tumor cells LUAD mitotic
# Comparing Tumor LUAD_transitional_vs_Mesothelial
# Comparing Tumor LUAD_transitional_vs_ROS1+ healthy epithelial
# Comparing Tumor LUAD_transitional_vs_Tumor cells LUSC
# Comparing NK cell_vs_T cell CD4
# Comparing NK cell_vs_Macrophage
# Comparing NK cell_vs_T cell CD8 effector memory
# Comparing NK cell_vs_B cell
# Comparing NK cell_vs_T cell regulatory
# Comparing NK cell_vs_Plasma cell
# Comparing NK cell_vs_Macrophage alveolar
# Comparing NK cell_vs_transitional club/AT2
# Comparing NK cell_vs_T cell CD8 terminally exhausted
# Comparing NK cell_vs_Neutrophils
# Comparing NK cell_vs_Tumor LUAD_transitional
# Comparing NK cell_vs_Monocyte classical
# Comparing NK cell_vs_cDC2
# Comparing NK cell_vs_Tumor LUAD_mitotic
# Comparing NK cell_vs_Mast cell
# Comparing NK cell_vs_Tumor LUAD_EMT1
# Comparing NK cell_vs_Tumor LUAD_LUSC_mitotic
# Comparing NK cell_vs_Alveolar cell type 2
# Comparing NK cell_vs_T cell NK-like
# Comparing NK cell_vs_Tumor LUSC_mainly
# Comparing NK cell_vs_Fibroblast peribronchial
# Comparing NK cell_vs_Tumor LUAD_mixed
# Comparing NK cell_vs_T cell CD8 activated
# Comparing NK cell_vs_Tumor LUSC_LUAD_mitotic
# Comparing NK cell_vs_T cell CD8 naive
# Comparing NK cell_vs_Tumor LUAD_Club
# Comparing NK cell_vs_Endothelial cell venous
# Comparing NK cell_vs_Tumor LUAD_LUSC
# Comparing NK cell_vs_myeloid dividing
# Comparing NK cell_vs_Ciliated
# Comparing NK cell_vs_Tumor LUSC_mitotic2
# Comparing NK cell_vs_Tumor LUSC_mitotic
# Comparing NK cell_vs_T cell CD8 dividing
# Comparing NK cell_vs_Tumor LUSC_mainly2
# Comparing NK cell_vs_Tumor mitotic_LUSC
# Comparing NK cell_vs_Tumor mixed_LUAD
# Comparing NK cell_vs_T cell CD4 dividing
# Comparing NK cell_vs_Tumor mitotic_mixed
# Comparing NK cell_vs_Tumor LUAD_mainly1
# Comparing NK cell_vs_Fibroblast alveolar
# Comparing NK cell_vs_Tumor cells LUAD
# Comparing NK cell_vs_Pericyte
# Comparing NK cell_vs_pDC
# Comparing NK cell_vs_Fibroblast adventitial
# Comparing NK cell_vs_Monocyte non-classical
# Comparing NK cell_vs_DC mature
# Comparing NK cell_vs_cDC1
# Comparing NK cell_vs_Club
# Comparing NK cell_vs_Smooth muscle cell
# Comparing NK cell_vs_Endothelial cell capillary
# Comparing NK cell_vs_Tumor LUAD_EMT2
# Comparing NK cell_vs_Alveolar cell type 1
# Comparing NK cell_vs_Plasma cell dividing
# Comparing NK cell_vs_stromal dividing
# Comparing NK cell_vs_Endothelial cell lymphatic
# Comparing NK cell_vs_NK cell dividing
# Comparing NK cell_vs_B cell dividing
# Comparing NK cell_vs_Endothelial cell arterial
# Comparing NK cell_vs_Tumor LUAD_EMT3
# Comparing NK cell_vs_Tumor cells LUAD mitotic
# Comparing NK cell_vs_Mesothelial
# Comparing NK cell_vs_ROS1+ healthy epithelial
# Comparing NK cell_vs_Tumor cells LUSC
# Comparing Monocyte classical_vs_T cell CD4
# Comparing Monocyte classical_vs_Macrophage
# Comparing Monocyte classical_vs_T cell CD8 effector memory
# Comparing Monocyte classical_vs_B cell
# Comparing Monocyte classical_vs_T cell regulatory
# Comparing Monocyte classical_vs_Plasma cell
# Comparing Monocyte classical_vs_Macrophage alveolar
# Comparing Monocyte classical_vs_transitional club/AT2
# Comparing Monocyte classical_vs_T cell CD8 terminally exhausted
# Comparing Monocyte classical_vs_Neutrophils
# Comparing Monocyte classical_vs_Tumor LUAD_transitional
# Comparing Monocyte classical_vs_NK cell
# Comparing Monocyte classical_vs_cDC2
# Comparing Monocyte classical_vs_Tumor LUAD_mitotic
# Comparing Monocyte classical_vs_Mast cell
# Comparing Monocyte classical_vs_Tumor LUAD_EMT1
# Comparing Monocyte classical_vs_Tumor LUAD_LUSC_mitotic
# Comparing Monocyte classical_vs_Alveolar cell type 2
# Comparing Monocyte classical_vs_T cell NK-like
# Comparing Monocyte classical_vs_Tumor LUSC_mainly
# Comparing Monocyte classical_vs_Fibroblast peribronchial
# Comparing Monocyte classical_vs_Tumor LUAD_mixed
# Comparing Monocyte classical_vs_T cell CD8 activated
# Comparing Monocyte classical_vs_Tumor LUSC_LUAD_mitotic
# Comparing Monocyte classical_vs_T cell CD8 naive
# Comparing Monocyte classical_vs_Tumor LUAD_Club
# Comparing Monocyte classical_vs_Endothelial cell venous
# Comparing Monocyte classical_vs_Tumor LUAD_LUSC
# Comparing Monocyte classical_vs_myeloid dividing
# Comparing Monocyte classical_vs_Ciliated
# Comparing Monocyte classical_vs_Tumor LUSC_mitotic2
# Comparing Monocyte classical_vs_Tumor LUSC_mitotic
# Comparing Monocyte classical_vs_T cell CD8 dividing
# Comparing Monocyte classical_vs_Tumor LUSC_mainly2
# Comparing Monocyte classical_vs_Tumor mitotic_LUSC
# Comparing Monocyte classical_vs_Tumor mixed_LUAD
# Comparing Monocyte classical_vs_T cell CD4 dividing
# Comparing Monocyte classical_vs_Tumor mitotic_mixed
# Comparing Monocyte classical_vs_Tumor LUAD_mainly1
# Comparing Monocyte classical_vs_Fibroblast alveolar
# Comparing Monocyte classical_vs_Tumor cells LUAD
# Comparing Monocyte classical_vs_Pericyte
# Comparing Monocyte classical_vs_pDC
# Comparing Monocyte classical_vs_Fibroblast adventitial
# Comparing Monocyte classical_vs_Monocyte non-classical
# Comparing Monocyte classical_vs_DC mature
# Comparing Monocyte classical_vs_cDC1
# Comparing Monocyte classical_vs_Club
# Comparing Monocyte classical_vs_Smooth muscle cell
# Comparing Monocyte classical_vs_Endothelial cell capillary
# Comparing Monocyte classical_vs_Tumor LUAD_EMT2
# Comparing Monocyte classical_vs_Alveolar cell type 1
# Comparing Monocyte classical_vs_Plasma cell dividing
# Comparing Monocyte classical_vs_stromal dividing
# Comparing Monocyte classical_vs_Endothelial cell lymphatic
# Comparing Monocyte classical_vs_NK cell dividing
# Comparing Monocyte classical_vs_B cell dividing
# Comparing Monocyte classical_vs_Endothelial cell arterial
# Comparing Monocyte classical_vs_Tumor LUAD_EMT3
# Comparing Monocyte classical_vs_Tumor cells LUAD mitotic
# Comparing Monocyte classical_vs_Mesothelial
# Comparing Monocyte classical_vs_ROS1+ healthy epithelial
# Comparing Monocyte classical_vs_Tumor cells LUSC
# Comparing cDC2_vs_T cell CD4
# Comparing cDC2_vs_Macrophage
# Comparing cDC2_vs_T cell CD8 effector memory
# Comparing cDC2_vs_B cell
# Comparing cDC2_vs_T cell regulatory
# Comparing cDC2_vs_Plasma cell
# Comparing cDC2_vs_Macrophage alveolar
# Comparing cDC2_vs_transitional club/AT2
# Comparing cDC2_vs_T cell CD8 terminally exhausted
# Comparing cDC2_vs_Neutrophils
# Comparing cDC2_vs_Tumor LUAD_transitional
# Comparing cDC2_vs_NK cell
# Comparing cDC2_vs_Monocyte classical
# Comparing cDC2_vs_Tumor LUAD_mitotic
# Comparing cDC2_vs_Mast cell
# Comparing cDC2_vs_Tumor LUAD_EMT1
# Comparing cDC2_vs_Tumor LUAD_LUSC_mitotic
# Comparing cDC2_vs_Alveolar cell type 2
# Comparing cDC2_vs_T cell NK-like
# Comparing cDC2_vs_Tumor LUSC_mainly
# Comparing cDC2_vs_Fibroblast peribronchial
# Comparing cDC2_vs_Tumor LUAD_mixed
# Comparing cDC2_vs_T cell CD8 activated
# Comparing cDC2_vs_Tumor LUSC_LUAD_mitotic
# Comparing cDC2_vs_T cell CD8 naive
# Comparing cDC2_vs_Tumor LUAD_Club
# Comparing cDC2_vs_Endothelial cell venous
# Comparing cDC2_vs_Tumor LUAD_LUSC
# Comparing cDC2_vs_myeloid dividing
# Comparing cDC2_vs_Ciliated
# Comparing cDC2_vs_Tumor LUSC_mitotic2
# Comparing cDC2_vs_Tumor LUSC_mitotic
# Comparing cDC2_vs_T cell CD8 dividing
# Comparing cDC2_vs_Tumor LUSC_mainly2
# Comparing cDC2_vs_Tumor mitotic_LUSC
# Comparing cDC2_vs_Tumor mixed_LUAD
# Comparing cDC2_vs_T cell CD4 dividing
# Comparing cDC2_vs_Tumor mitotic_mixed
# Comparing cDC2_vs_Tumor LUAD_mainly1
# Comparing cDC2_vs_Fibroblast alveolar
# Comparing cDC2_vs_Tumor cells LUAD
# Comparing cDC2_vs_Pericyte
# Comparing cDC2_vs_pDC
# Comparing cDC2_vs_Fibroblast adventitial
# Comparing cDC2_vs_Monocyte non-classical
# Comparing cDC2_vs_DC mature
# Comparing cDC2_vs_cDC1
# Comparing cDC2_vs_Club
# Comparing cDC2_vs_Smooth muscle cell
# Comparing cDC2_vs_Endothelial cell capillary
# Comparing cDC2_vs_Tumor LUAD_EMT2
# Comparing cDC2_vs_Alveolar cell type 1
# Comparing cDC2_vs_Plasma cell dividing
# Comparing cDC2_vs_stromal dividing
# Comparing cDC2_vs_Endothelial cell lymphatic
# Comparing cDC2_vs_NK cell dividing
# Comparing cDC2_vs_B cell dividing
# Comparing cDC2_vs_Endothelial cell arterial
# Comparing cDC2_vs_Tumor LUAD_EMT3
# Comparing cDC2_vs_Tumor cells LUAD mitotic
# Comparing cDC2_vs_Mesothelial
# Comparing cDC2_vs_ROS1+ healthy epithelial
# Comparing cDC2_vs_Tumor cells LUSC
# Comparing Tumor LUAD_mitotic_vs_T cell CD4
# Comparing Tumor LUAD_mitotic_vs_Macrophage
# Comparing Tumor LUAD_mitotic_vs_T cell CD8 effector memory
# Comparing Tumor LUAD_mitotic_vs_B cell
# Comparing Tumor LUAD_mitotic_vs_T cell regulatory
# Comparing Tumor LUAD_mitotic_vs_Plasma cell
# Comparing Tumor LUAD_mitotic_vs_Macrophage alveolar
# Comparing Tumor LUAD_mitotic_vs_transitional club/AT2
# Comparing Tumor LUAD_mitotic_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUAD_mitotic_vs_Neutrophils
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_transitional
# Comparing Tumor LUAD_mitotic_vs_NK cell
# Comparing Tumor LUAD_mitotic_vs_Monocyte classical
# Comparing Tumor LUAD_mitotic_vs_cDC2
# Comparing Tumor LUAD_mitotic_vs_Mast cell
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_EMT1
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUAD_mitotic_vs_Alveolar cell type 2
# Comparing Tumor LUAD_mitotic_vs_T cell NK-like
# Comparing Tumor LUAD_mitotic_vs_Tumor LUSC_mainly
# Comparing Tumor LUAD_mitotic_vs_Fibroblast peribronchial
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_mixed
# Comparing Tumor LUAD_mitotic_vs_T cell CD8 activated
# Comparing Tumor LUAD_mitotic_vs_Tumor LUSC_LUAD_mitotic
# Comparing Tumor LUAD_mitotic_vs_T cell CD8 naive
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_Club
# Comparing Tumor LUAD_mitotic_vs_Endothelial cell venous
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_LUSC
# Comparing Tumor LUAD_mitotic_vs_myeloid dividing
# Comparing Tumor LUAD_mitotic_vs_Ciliated
# Comparing Tumor LUAD_mitotic_vs_Tumor LUSC_mitotic2
# Comparing Tumor LUAD_mitotic_vs_Tumor LUSC_mitotic
# Comparing Tumor LUAD_mitotic_vs_T cell CD8 dividing
# Comparing Tumor LUAD_mitotic_vs_Tumor LUSC_mainly2
# Comparing Tumor LUAD_mitotic_vs_Tumor mitotic_LUSC
# Comparing Tumor LUAD_mitotic_vs_Tumor mixed_LUAD
# Comparing Tumor LUAD_mitotic_vs_T cell CD4 dividing
# Comparing Tumor LUAD_mitotic_vs_Tumor mitotic_mixed
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_mainly1
# Comparing Tumor LUAD_mitotic_vs_Fibroblast alveolar
# Comparing Tumor LUAD_mitotic_vs_Tumor cells LUAD
# Comparing Tumor LUAD_mitotic_vs_Pericyte
# Comparing Tumor LUAD_mitotic_vs_pDC
# Comparing Tumor LUAD_mitotic_vs_Fibroblast adventitial
# Comparing Tumor LUAD_mitotic_vs_Monocyte non-classical
# Comparing Tumor LUAD_mitotic_vs_DC mature
# Comparing Tumor LUAD_mitotic_vs_cDC1
# Comparing Tumor LUAD_mitotic_vs_Club
# Comparing Tumor LUAD_mitotic_vs_Smooth muscle cell
# Comparing Tumor LUAD_mitotic_vs_Endothelial cell capillary
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_EMT2
# Comparing Tumor LUAD_mitotic_vs_Alveolar cell type 1
# Comparing Tumor LUAD_mitotic_vs_Plasma cell dividing
# Comparing Tumor LUAD_mitotic_vs_stromal dividing
# Comparing Tumor LUAD_mitotic_vs_Endothelial cell lymphatic
# Comparing Tumor LUAD_mitotic_vs_NK cell dividing
# Comparing Tumor LUAD_mitotic_vs_B cell dividing
# Comparing Tumor LUAD_mitotic_vs_Endothelial cell arterial
# Comparing Tumor LUAD_mitotic_vs_Tumor LUAD_EMT3
# Comparing Tumor LUAD_mitotic_vs_Tumor cells LUAD mitotic
# Comparing Tumor LUAD_mitotic_vs_Mesothelial
# Comparing Tumor LUAD_mitotic_vs_ROS1+ healthy epithelial
# Comparing Tumor LUAD_mitotic_vs_Tumor cells LUSC
# Comparing Mast cell_vs_T cell CD4
# Comparing Mast cell_vs_Macrophage
# Comparing Mast cell_vs_T cell CD8 effector memory
# Comparing Mast cell_vs_B cell
# Comparing Mast cell_vs_T cell regulatory
# Comparing Mast cell_vs_Plasma cell
# Comparing Mast cell_vs_Macrophage alveolar
# Comparing Mast cell_vs_transitional club/AT2
# Comparing Mast cell_vs_T cell CD8 terminally exhausted
# Comparing Mast cell_vs_Neutrophils
# Comparing Mast cell_vs_Tumor LUAD_transitional
# Comparing Mast cell_vs_NK cell
# Comparing Mast cell_vs_Monocyte classical
# Comparing Mast cell_vs_cDC2
# Comparing Mast cell_vs_Tumor LUAD_mitotic
# Comparing Mast cell_vs_Tumor LUAD_EMT1
# Comparing Mast cell_vs_Tumor LUAD_LUSC_mitotic
# Comparing Mast cell_vs_Alveolar cell type 2
# Comparing Mast cell_vs_T cell NK-like
# Comparing Mast cell_vs_Tumor LUSC_mainly
# Comparing Mast cell_vs_Fibroblast peribronchial
# Comparing Mast cell_vs_Tumor LUAD_mixed
# Comparing Mast cell_vs_T cell CD8 activated
# Comparing Mast cell_vs_Tumor LUSC_LUAD_mitotic
# Comparing Mast cell_vs_T cell CD8 naive
# Comparing Mast cell_vs_Tumor LUAD_Club
# Comparing Mast cell_vs_Endothelial cell venous
# Comparing Mast cell_vs_Tumor LUAD_LUSC
# Comparing Mast cell_vs_myeloid dividing
# Comparing Mast cell_vs_Ciliated
# Comparing Mast cell_vs_Tumor LUSC_mitotic2
# Comparing Mast cell_vs_Tumor LUSC_mitotic
# Comparing Mast cell_vs_T cell CD8 dividing
# Comparing Mast cell_vs_Tumor LUSC_mainly2
# Comparing Mast cell_vs_Tumor mitotic_LUSC
# Comparing Mast cell_vs_Tumor mixed_LUAD
# Comparing Mast cell_vs_T cell CD4 dividing
# Comparing Mast cell_vs_Tumor mitotic_mixed
# Comparing Mast cell_vs_Tumor LUAD_mainly1
# Comparing Mast cell_vs_Fibroblast alveolar
# Comparing Mast cell_vs_Tumor cells LUAD
# Comparing Mast cell_vs_Pericyte
# Comparing Mast cell_vs_pDC
# Comparing Mast cell_vs_Fibroblast adventitial
# Comparing Mast cell_vs_Monocyte non-classical
# Comparing Mast cell_vs_DC mature
# Comparing Mast cell_vs_cDC1
# Comparing Mast cell_vs_Club
# Comparing Mast cell_vs_Smooth muscle cell
# Comparing Mast cell_vs_Endothelial cell capillary
# Comparing Mast cell_vs_Tumor LUAD_EMT2
# Comparing Mast cell_vs_Alveolar cell type 1
# Comparing Mast cell_vs_Plasma cell dividing
# Comparing Mast cell_vs_stromal dividing
# Comparing Mast cell_vs_Endothelial cell lymphatic
# Comparing Mast cell_vs_NK cell dividing
# Comparing Mast cell_vs_B cell dividing
# Comparing Mast cell_vs_Endothelial cell arterial
# Comparing Mast cell_vs_Tumor LUAD_EMT3
# Comparing Mast cell_vs_Tumor cells LUAD mitotic
# Comparing Mast cell_vs_Mesothelial
# Comparing Mast cell_vs_ROS1+ healthy epithelial
# Comparing Mast cell_vs_Tumor cells LUSC
# Comparing Tumor LUAD_EMT1_vs_T cell CD4
# Comparing Tumor LUAD_EMT1_vs_Macrophage
# Comparing Tumor LUAD_EMT1_vs_T cell CD8 effector memory
# Comparing Tumor LUAD_EMT1_vs_B cell
# Comparing Tumor LUAD_EMT1_vs_T cell regulatory
# Comparing Tumor LUAD_EMT1_vs_Plasma cell
# Comparing Tumor LUAD_EMT1_vs_Macrophage alveolar
# Comparing Tumor LUAD_EMT1_vs_transitional club/AT2
# Comparing Tumor LUAD_EMT1_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUAD_EMT1_vs_Neutrophils
# Comparing Tumor LUAD_EMT1_vs_Tumor LUAD_transitional
# Comparing Tumor LUAD_EMT1_vs_NK cell
# Comparing Tumor LUAD_EMT1_vs_Monocyte classical
# Comparing Tumor LUAD_EMT1_vs_cDC2
# Comparing Tumor LUAD_EMT1_vs_Tumor LUAD_mitotic
# Comparing Tumor LUAD_EMT1_vs_Mast cell
# Comparing Tumor LUAD_EMT1_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUAD_EMT1_vs_Alveolar cell type 2
# Comparing Tumor LUAD_EMT1_vs_T cell NK-like
# ...
# Comparing Endothelial cell venous_vs_pDC
# Comparing Endothelial cell venous_vs_Fibroblast adventitial
# Comparing Endothelial cell venous_vs_Monocyte non-classical
# Comparing Endothelial cell venous_vs_DC mature
# Comparing Endothelial cell venous_vs_cDC1
# Comparing Endothelial cell venous_vs_Club
# Comparing Endothelial cell venous_vs_Smooth muscle cell
# Comparing Endothelial cell venous_vs_Endothelial cell capillary
# Comparing Endothelial cell venous_vs_Tumor LUAD_EMT2
# Comparing Endothelial cell venous_vs_Alveolar cell type 1
# Comparing Endothelial cell venous_vs_Plasma cell dividing
# Comparing Endothelial cell venous_vs_stromal dividing
# Comparing Endothelial cell venous_vs_Endothelial cell lymphatic
# Comparing Endothelial cell venous_vs_NK cell dividing
# Comparing Endothelial cell venous_vs_B cell dividing
# Comparing Endothelial cell venous_vs_Endothelial cell arterial
# Comparing Endothelial cell venous_vs_Tumor LUAD_EMT3
# Comparing Endothelial cell venous_vs_Tumor cells LUAD mitotic
# Comparing Endothelial cell venous_vs_Mesothelial
# Comparing Endothelial cell venous_vs_ROS1+ healthy epithelial
# Comparing Endothelial cell venous_vs_Tumor cells LUSC
# Comparing Tumor LUAD_LUSC_vs_T cell CD4
# Comparing Tumor LUAD_LUSC_vs_Macrophage
# Comparing Tumor LUAD_LUSC_vs_T cell CD8 effector memory
# Comparing Tumor LUAD_LUSC_vs_B cell
# Comparing Tumor LUAD_LUSC_vs_T cell regulatory
# Comparing Tumor LUAD_LUSC_vs_Plasma cell
# Comparing Tumor LUAD_LUSC_vs_Macrophage alveolar
# Comparing Tumor LUAD_LUSC_vs_transitional club/AT2
# Comparing Tumor LUAD_LUSC_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUAD_LUSC_vs_Neutrophils
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_transitional
# Comparing Tumor LUAD_LUSC_vs_NK cell
# Comparing Tumor LUAD_LUSC_vs_Monocyte classical
# Comparing Tumor LUAD_LUSC_vs_cDC2
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_mitotic
# Comparing Tumor LUAD_LUSC_vs_Mast cell
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_EMT1
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUAD_LUSC_vs_Alveolar cell type 2
# Comparing Tumor LUAD_LUSC_vs_T cell NK-like
# Comparing Tumor LUAD_LUSC_vs_Tumor LUSC_mainly
# Comparing Tumor LUAD_LUSC_vs_Fibroblast peribronchial
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_mixed
# Comparing Tumor LUAD_LUSC_vs_T cell CD8 activated
# Comparing Tumor LUAD_LUSC_vs_Tumor LUSC_LUAD_mitotic
# Comparing Tumor LUAD_LUSC_vs_T cell CD8 naive
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_Club
# Comparing Tumor LUAD_LUSC_vs_Endothelial cell venous
# Comparing Tumor LUAD_LUSC_vs_myeloid dividing
# Comparing Tumor LUAD_LUSC_vs_Ciliated
# Comparing Tumor LUAD_LUSC_vs_Tumor LUSC_mitotic2
# Comparing Tumor LUAD_LUSC_vs_Tumor LUSC_mitotic
# Comparing Tumor LUAD_LUSC_vs_T cell CD8 dividing
# Comparing Tumor LUAD_LUSC_vs_Tumor LUSC_mainly2
# Comparing Tumor LUAD_LUSC_vs_Tumor mitotic_LUSC
# Comparing Tumor LUAD_LUSC_vs_Tumor mixed_LUAD
# Comparing Tumor LUAD_LUSC_vs_T cell CD4 dividing
# Comparing Tumor LUAD_LUSC_vs_Tumor mitotic_mixed
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_mainly1
# Comparing Tumor LUAD_LUSC_vs_Fibroblast alveolar
# Comparing Tumor LUAD_LUSC_vs_Tumor cells LUAD
# Comparing Tumor LUAD_LUSC_vs_Pericyte
# Comparing Tumor LUAD_LUSC_vs_pDC
# Comparing Tumor LUAD_LUSC_vs_Fibroblast adventitial
# Comparing Tumor LUAD_LUSC_vs_Monocyte non-classical
# Comparing Tumor LUAD_LUSC_vs_DC mature
# Comparing Tumor LUAD_LUSC_vs_cDC1
# Comparing Tumor LUAD_LUSC_vs_Club
# Comparing Tumor LUAD_LUSC_vs_Smooth muscle cell
# Comparing Tumor LUAD_LUSC_vs_Endothelial cell capillary
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_EMT2
# Comparing Tumor LUAD_LUSC_vs_Alveolar cell type 1
# Comparing Tumor LUAD_LUSC_vs_Plasma cell dividing
# Comparing Tumor LUAD_LUSC_vs_stromal dividing
# Comparing Tumor LUAD_LUSC_vs_Endothelial cell lymphatic
# Comparing Tumor LUAD_LUSC_vs_NK cell dividing
# Comparing Tumor LUAD_LUSC_vs_B cell dividing
# Comparing Tumor LUAD_LUSC_vs_Endothelial cell arterial
# Comparing Tumor LUAD_LUSC_vs_Tumor LUAD_EMT3
# Comparing Tumor LUAD_LUSC_vs_Tumor cells LUAD mitotic
# Comparing Tumor LUAD_LUSC_vs_Mesothelial
# Comparing Tumor LUAD_LUSC_vs_ROS1+ healthy epithelial
# Comparing Tumor LUAD_LUSC_vs_Tumor cells LUSC
# Comparing myeloid dividing_vs_T cell CD4
# Comparing myeloid dividing_vs_Macrophage
# Comparing myeloid dividing_vs_T cell CD8 effector memory
# Comparing myeloid dividing_vs_B cell
# Comparing myeloid dividing_vs_T cell regulatory
# Comparing myeloid dividing_vs_Plasma cell
# Comparing myeloid dividing_vs_Macrophage alveolar
# Comparing myeloid dividing_vs_transitional club/AT2
# Comparing myeloid dividing_vs_T cell CD8 terminally exhausted
# Comparing myeloid dividing_vs_Neutrophils
# Comparing myeloid dividing_vs_Tumor LUAD_transitional
# Comparing myeloid dividing_vs_NK cell
# Comparing myeloid dividing_vs_Monocyte classical
# Comparing myeloid dividing_vs_cDC2
# Comparing myeloid dividing_vs_Tumor LUAD_mitotic
# Comparing myeloid dividing_vs_Mast cell
# Comparing myeloid dividing_vs_Tumor LUAD_EMT1
# Comparing myeloid dividing_vs_Tumor LUAD_LUSC_mitotic
# Comparing myeloid dividing_vs_Alveolar cell type 2
# Comparing myeloid dividing_vs_T cell NK-like
# Comparing myeloid dividing_vs_Tumor LUSC_mainly
# Comparing myeloid dividing_vs_Fibroblast peribronchial
# Comparing myeloid dividing_vs_Tumor LUAD_mixed
# Comparing myeloid dividing_vs_T cell CD8 activated
# Comparing myeloid dividing_vs_Tumor LUSC_LUAD_mitotic
# Comparing myeloid dividing_vs_T cell CD8 naive
# Comparing myeloid dividing_vs_Tumor LUAD_Club
# Comparing myeloid dividing_vs_Endothelial cell venous
# Comparing myeloid dividing_vs_Tumor LUAD_LUSC
# Comparing myeloid dividing_vs_Ciliated
# Comparing myeloid dividing_vs_Tumor LUSC_mitotic2
# Comparing myeloid dividing_vs_Tumor LUSC_mitotic
# Comparing myeloid dividing_vs_T cell CD8 dividing
# Comparing myeloid dividing_vs_Tumor LUSC_mainly2
# Comparing myeloid dividing_vs_Tumor mitotic_LUSC
# Comparing myeloid dividing_vs_Tumor mixed_LUAD
# Comparing myeloid dividing_vs_T cell CD4 dividing
# Comparing myeloid dividing_vs_Tumor mitotic_mixed
# Comparing myeloid dividing_vs_Tumor LUAD_mainly1
# Comparing myeloid dividing_vs_Fibroblast alveolar
# Comparing myeloid dividing_vs_Tumor cells LUAD
# Comparing myeloid dividing_vs_Pericyte
# Comparing myeloid dividing_vs_pDC
# Comparing myeloid dividing_vs_Fibroblast adventitial
# Comparing myeloid dividing_vs_Monocyte non-classical
# Comparing myeloid dividing_vs_DC mature
# Comparing myeloid dividing_vs_cDC1
# Comparing myeloid dividing_vs_Club
# Comparing myeloid dividing_vs_Smooth muscle cell
# Comparing myeloid dividing_vs_Endothelial cell capillary
# Comparing myeloid dividing_vs_Tumor LUAD_EMT2
# Comparing myeloid dividing_vs_Alveolar cell type 1
# Comparing myeloid dividing_vs_Plasma cell dividing
# Comparing myeloid dividing_vs_stromal dividing
# Comparing myeloid dividing_vs_Endothelial cell lymphatic
# Comparing myeloid dividing_vs_NK cell dividing
# Comparing myeloid dividing_vs_B cell dividing
# Comparing myeloid dividing_vs_Endothelial cell arterial
# Comparing myeloid dividing_vs_Tumor LUAD_EMT3
# Comparing myeloid dividing_vs_Tumor cells LUAD mitotic
# Comparing myeloid dividing_vs_Mesothelial
# Comparing myeloid dividing_vs_ROS1+ healthy epithelial
# Comparing myeloid dividing_vs_Tumor cells LUSC
# Comparing Ciliated_vs_T cell CD4
# Comparing Ciliated_vs_Macrophage
# Comparing Ciliated_vs_T cell CD8 effector memory
# Comparing Ciliated_vs_B cell
# Comparing Ciliated_vs_T cell regulatory
# Comparing Ciliated_vs_Plasma cell
# Comparing Ciliated_vs_Macrophage alveolar
# Comparing Ciliated_vs_transitional club/AT2
# Comparing Ciliated_vs_T cell CD8 terminally exhausted
# Comparing Ciliated_vs_Neutrophils
# Comparing Ciliated_vs_Tumor LUAD_transitional
# Comparing Ciliated_vs_NK cell
# Comparing Ciliated_vs_Monocyte classical
# Comparing Ciliated_vs_cDC2
# Comparing Ciliated_vs_Tumor LUAD_mitotic
# Comparing Ciliated_vs_Mast cell
# Comparing Ciliated_vs_Tumor LUAD_EMT1
# Comparing Ciliated_vs_Tumor LUAD_LUSC_mitotic
# Comparing Ciliated_vs_Alveolar cell type 2
# Comparing Ciliated_vs_T cell NK-like
# Comparing Ciliated_vs_Tumor LUSC_mainly
# Comparing Ciliated_vs_Fibroblast peribronchial
# Comparing Ciliated_vs_Tumor LUAD_mixed
# Comparing Ciliated_vs_T cell CD8 activated
# Comparing Ciliated_vs_Tumor LUSC_LUAD_mitotic
# Comparing Ciliated_vs_T cell CD8 naive
# Comparing Ciliated_vs_Tumor LUAD_Club
# Comparing Ciliated_vs_Endothelial cell venous
# Comparing Ciliated_vs_Tumor LUAD_LUSC
# Comparing Ciliated_vs_myeloid dividing
# Comparing Ciliated_vs_Tumor LUSC_mitotic2
# Comparing Ciliated_vs_Tumor LUSC_mitotic
# Comparing Ciliated_vs_T cell CD8 dividing
# Comparing Ciliated_vs_Tumor LUSC_mainly2
# Comparing Ciliated_vs_Tumor mitotic_LUSC
# Comparing Ciliated_vs_Tumor mixed_LUAD
# Comparing Ciliated_vs_T cell CD4 dividing
# Comparing Ciliated_vs_Tumor mitotic_mixed
# Comparing Ciliated_vs_Tumor LUAD_mainly1
# Comparing Ciliated_vs_Fibroblast alveolar
# Comparing Ciliated_vs_Tumor cells LUAD
# Comparing Ciliated_vs_Pericyte
# Comparing Ciliated_vs_pDC
# Comparing Ciliated_vs_Fibroblast adventitial
# Comparing Ciliated_vs_Monocyte non-classical
# Comparing Ciliated_vs_DC mature
# Comparing Ciliated_vs_cDC1
# Comparing Ciliated_vs_Club
# Comparing Ciliated_vs_Smooth muscle cell
# Comparing Ciliated_vs_Endothelial cell capillary
# Comparing Ciliated_vs_Tumor LUAD_EMT2
# Comparing Ciliated_vs_Alveolar cell type 1
# Comparing Ciliated_vs_Plasma cell dividing
# Comparing Ciliated_vs_stromal dividing
# Comparing Ciliated_vs_Endothelial cell lymphatic
# Comparing Ciliated_vs_NK cell dividing
# Comparing Ciliated_vs_B cell dividing
# Comparing Ciliated_vs_Endothelial cell arterial
# Comparing Ciliated_vs_Tumor LUAD_EMT3
# Comparing Ciliated_vs_Tumor cells LUAD mitotic
# Comparing Ciliated_vs_Mesothelial
# Comparing Ciliated_vs_ROS1+ healthy epithelial
# Comparing Ciliated_vs_Tumor cells LUSC
# Comparing Tumor LUSC_mitotic2_vs_T cell CD4
# Comparing Tumor LUSC_mitotic2_vs_Macrophage
# Comparing Tumor LUSC_mitotic2_vs_T cell CD8 effector memory
# Comparing Tumor LUSC_mitotic2_vs_B cell
# Comparing Tumor LUSC_mitotic2_vs_T cell regulatory
# Comparing Tumor LUSC_mitotic2_vs_Plasma cell
# Comparing Tumor LUSC_mitotic2_vs_Macrophage alveolar
# Comparing Tumor LUSC_mitotic2_vs_transitional club/AT2
# Comparing Tumor LUSC_mitotic2_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUSC_mitotic2_vs_Neutrophils
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_transitional
# Comparing Tumor LUSC_mitotic2_vs_NK cell
# Comparing Tumor LUSC_mitotic2_vs_Monocyte classical
# Comparing Tumor LUSC_mitotic2_vs_cDC2
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_mitotic
# Comparing Tumor LUSC_mitotic2_vs_Mast cell
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_EMT1
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUSC_mitotic2_vs_Alveolar cell type 2
# Comparing Tumor LUSC_mitotic2_vs_T cell NK-like
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUSC_mainly
# Comparing Tumor LUSC_mitotic2_vs_Fibroblast peribronchial
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_mixed
# Comparing Tumor LUSC_mitotic2_vs_T cell CD8 activated
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUSC_LUAD_mitotic
# Comparing Tumor LUSC_mitotic2_vs_T cell CD8 naive
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_Club
# Comparing Tumor LUSC_mitotic2_vs_Endothelial cell venous
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_LUSC
# Comparing Tumor LUSC_mitotic2_vs_myeloid dividing
# Comparing Tumor LUSC_mitotic2_vs_Ciliated
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUSC_mitotic
# Comparing Tumor LUSC_mitotic2_vs_T cell CD8 dividing
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUSC_mainly2
# Comparing Tumor LUSC_mitotic2_vs_Tumor mitotic_LUSC
# Comparing Tumor LUSC_mitotic2_vs_Tumor mixed_LUAD
# Comparing Tumor LUSC_mitotic2_vs_T cell CD4 dividing
# Comparing Tumor LUSC_mitotic2_vs_Tumor mitotic_mixed
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_mainly1
# Comparing Tumor LUSC_mitotic2_vs_Fibroblast alveolar
# Comparing Tumor LUSC_mitotic2_vs_Tumor cells LUAD
# Comparing Tumor LUSC_mitotic2_vs_Pericyte
# Comparing Tumor LUSC_mitotic2_vs_pDC
# Comparing Tumor LUSC_mitotic2_vs_Fibroblast adventitial
# Comparing Tumor LUSC_mitotic2_vs_Monocyte non-classical
# Comparing Tumor LUSC_mitotic2_vs_DC mature
# Comparing Tumor LUSC_mitotic2_vs_cDC1
# Comparing Tumor LUSC_mitotic2_vs_Club
# Comparing Tumor LUSC_mitotic2_vs_Smooth muscle cell
# Comparing Tumor LUSC_mitotic2_vs_Endothelial cell capillary
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_EMT2
# Comparing Tumor LUSC_mitotic2_vs_Alveolar cell type 1
# Comparing Tumor LUSC_mitotic2_vs_Plasma cell dividing
# Comparing Tumor LUSC_mitotic2_vs_stromal dividing
# Comparing Tumor LUSC_mitotic2_vs_Endothelial cell lymphatic
# Comparing Tumor LUSC_mitotic2_vs_NK cell dividing
# Comparing Tumor LUSC_mitotic2_vs_B cell dividing
# Comparing Tumor LUSC_mitotic2_vs_Endothelial cell arterial
# Comparing Tumor LUSC_mitotic2_vs_Tumor LUAD_EMT3
# Comparing Tumor LUSC_mitotic2_vs_Tumor cells LUAD mitotic
# Comparing Tumor LUSC_mitotic2_vs_Mesothelial
# Comparing Tumor LUSC_mitotic2_vs_ROS1+ healthy epithelial
# Comparing Tumor LUSC_mitotic2_vs_Tumor cells LUSC
# Comparing Tumor LUSC_mitotic_vs_T cell CD4
# Comparing Tumor LUSC_mitotic_vs_Macrophage
# Comparing Tumor LUSC_mitotic_vs_T cell CD8 effector memory
# Comparing Tumor LUSC_mitotic_vs_B cell
# Comparing Tumor LUSC_mitotic_vs_T cell regulatory
# Comparing Tumor LUSC_mitotic_vs_Plasma cell
# Comparing Tumor LUSC_mitotic_vs_Macrophage alveolar
# Comparing Tumor LUSC_mitotic_vs_transitional club/AT2
# Comparing Tumor LUSC_mitotic_vs_T cell CD8 terminally exhausted
# Comparing Tumor LUSC_mitotic_vs_Neutrophils
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_transitional
# Comparing Tumor LUSC_mitotic_vs_NK cell
# Comparing Tumor LUSC_mitotic_vs_Monocyte classical
# Comparing Tumor LUSC_mitotic_vs_cDC2
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_mitotic
# Comparing Tumor LUSC_mitotic_vs_Mast cell
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_EMT1
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_LUSC_mitotic
# Comparing Tumor LUSC_mitotic_vs_Alveolar cell type 2
# Comparing Tumor LUSC_mitotic_vs_T cell NK-like
# Comparing Tumor LUSC_mitotic_vs_Tumor LUSC_mainly
# Comparing Tumor LUSC_mitotic_vs_Fibroblast peribronchial
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_mixed
# Comparing Tumor LUSC_mitotic_vs_T cell CD8 activated
# Comparing Tumor LUSC_mitotic_vs_Tumor LUSC_LUAD_mitotic
# Comparing Tumor LUSC_mitotic_vs_T cell CD8 naive
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_Club
# Comparing Tumor LUSC_mitotic_vs_Endothelial cell venous
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_LUSC
# Comparing Tumor LUSC_mitotic_vs_myeloid dividing
# Comparing Tumor LUSC_mitotic_vs_Ciliated
# Comparing Tumor LUSC_mitotic_vs_Tumor LUSC_mitotic2
# Comparing Tumor LUSC_mitotic_vs_T cell CD8 dividing
# Comparing Tumor LUSC_mitotic_vs_Tumor LUSC_mainly2
# Comparing Tumor LUSC_mitotic_vs_Tumor mitotic_LUSC
# Comparing Tumor LUSC_mitotic_vs_Tumor mixed_LUAD
# Comparing Tumor LUSC_mitotic_vs_T cell CD4 dividing
# Comparing Tumor LUSC_mitotic_vs_Tumor mitotic_mixed
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_mainly1
# Comparing Tumor LUSC_mitotic_vs_Fibroblast alveolar
# Comparing Tumor LUSC_mitotic_vs_Tumor cells LUAD
# Comparing Tumor LUSC_mitotic_vs_Pericyte
# Comparing Tumor LUSC_mitotic_vs_pDC
# Comparing Tumor LUSC_mitotic_vs_Fibroblast adventitial
# Comparing Tumor LUSC_mitotic_vs_Monocyte non-classical
# Comparing Tumor LUSC_mitotic_vs_DC mature
# Comparing Tumor LUSC_mitotic_vs_cDC1
# Comparing Tumor LUSC_mitotic_vs_Club
# Comparing Tumor LUSC_mitotic_vs_Smooth muscle cell
# Comparing Tumor LUSC_mitotic_vs_Endothelial cell capillary
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_EMT2
# Comparing Tumor LUSC_mitotic_vs_Alveolar cell type 1
# Comparing Tumor LUSC_mitotic_vs_Plasma cell dividing
# Comparing Tumor LUSC_mitotic_vs_stromal dividing
# Comparing Tumor LUSC_mitotic_vs_Endothelial cell lymphatic
# Comparing Tumor LUSC_mitotic_vs_NK cell dividing
# Comparing Tumor LUSC_mitotic_vs_B cell dividing
# Comparing Tumor LUSC_mitotic_vs_Endothelial cell arterial
# Comparing Tumor LUSC_mitotic_vs_Tumor LUAD_EMT3
# Comparing Tumor LUSC_mitotic_vs_Tumor cells LUAD mitotic
# Comparing Tumor LUSC_mitotic_vs_Mesothelial
# Comparing Tumor LUSC_mitotic_vs_ROS1+ healthy epithelial
# Comparing Tumor LUSC_mitotic_vs_Tumor cells LUSC
# Comparing T cell CD8 dividing_vs_T cell CD4
# Comparing T cell CD8 dividing_vs_Macrophage

# %% [markdown]
# ### Summaries

# %%
results = adata.uns[key_pair]

# %%
import multiprocessing
def process_gene(group1, pairwise_dict, groups2):
    scores = {}
    genes = next(iter(results.items()))[1]['names']
    comparisons = [(group1, group2) for group2 in groups2 if group1 != group2]
    
    for gene in genes:
        comparison_scores = []
        for comparison in comparisons:
            comp_key = f'{comparison[0]}_vs_{comparison[1]}'
            gene_index = np.where(results[comp_key]['names'] == gene)[0]
            comparison_scores.append(results[comp_key]['scores'][gene_index][0])
        scores[gene] = comparison_scores
    return group1, scores

num_processes = 40

# %% [markdown]
# Tumor against all

# %%
adata.uns['rank_genes_groups_summary_tumorall']

# %%
# %%time
groups = [ group for group in valid_types if 'Tumor' in group]
scores_dict = {group: {} for group in groups}

with multiprocessing.Pool(num_processes) as pool:
    for group_scores in pool.starmap(process_gene, [(group1, results, valid_types) for group1 in groups]):
        scores_dict[group_scores[0]] = group_scores[1]

adata.uns['rank_genes_groups_summary_tumorall'] = scores_dict

# %% [markdown]
# We make it mimic the structure that the scanpy tool for ranking genes already has to be able to work with our other methods.

# %%
# %%time
regions = ['tumorall']
# regions = ['normalall']

for region in regions:
    if load_wilcoxon:
        adata.uns[f'rank_genes_groups_{region}'] = np.load(all_path + f'_{region}.npy', allow_pickle=True).item()
        continue

    regioner = {cell_type: {gene: np.mean(scores) for gene, scores in genes_dict.items()}
                    for cell_type, genes_dict in adata.uns[f'rank_genes_groups_summary_{region}'].items()}
    regioner = {cell_type: sorted(genes.items(), key=lambda k: k[1], reverse=True) for cell_type, genes in regioner.items()}

    types_num = len(regioner)
    genes_num = len(next(iter(results.values()))['names'])
    scores = [[None] * genes_num for _ in range(types_num)]
    names = [[None] * genes_num for _ in range(types_num)]
    
    for i, cell_type in enumerate(regioner.keys()):
        j = 0
        for gene, score in regioner[cell_type]:
            scores[i][j] = score
            names[i][j] = gene
            j += 1

    names_zip = list(zip(*names))
    dtypes = [(typer, float) for typer in regioner.keys()]
    dtypes_names = [(typer, 'O') for typer in regioner.keys()]

    i = 0
    for n_scores in zip(*scores):
        if i==0:
            rank_scores = np.rec.array([n_scores], dtype=dtypes)
            rank_names = np.rec.array([names_zip[i]], dtype=dtypes_names)
        else:
            temp_scores = np.rec.array([n_scores], dtype=dtypes)
            rank_scores = np.rec.array(np.concatenate((rank_scores, temp_scores)))
    
            temp_names = np.rec.array([names_zip[i]], dtype=dtypes_names)
            rank_names = np.rec.array(np.concatenate((rank_names, temp_names)))
        i += 1

    rec_region = {'params': {'groupby': 'type_tissue', 'reference': region, 'method': 'wilcoxon', 'use_raw': False, 'layer': None, 'corr_method': 'benjamini-hochberg'}}
    rec_region['names'] = rank_names
    rec_region['scores'] = rank_scores

    adata.uns[f'rank_genes_groups_{region}'] = rec_region
    np.save(all_path + f'_{region}.npy', adata.uns[f'rank_genes_groups_{region}'])
# Out:
# CPU times: user 50.4 s, sys: 338 ms, total: 50.7 s
# Wall time: 50.7 s

# %%
[ keyer  for keyer in adata.uns.keys() if 'rank_genes' in keyer]
# Out:
# ['rank_genes_groups_pairwise',
#  'rank_genes_groups_summary_tumorall',
#  'rank_genes_groups_tumorall']

# %% [markdown]
# ### Plotting

# %%
def cond_plot(adata, cond_types, valid_types, ax=None,
              key='wilcoxon', fontsize=9, titlesize=14, **kwds):
    if set(cond_types).issubset(valid_types):
        ut.rank_genes_group(adata, cond_types[0], n_genes=n_genes,
                            ax=ax, sharey=False, key=key, show=False,
                            fontsize=fontsize, titlesize=titlesize)
    else:
        # pass
        # Draw an empty plot with a message
        ax.text(0.5, 0.5, f'Missing cells: {cond_types}', color='red', 
                       ha='center', va='center', transform=ax.transAxes)
        ax.axis('off')

# %%
region = 'tumorall'
types = adata.uns[f'rank_genes_groups_{region}']['scores'].dtype.names
num_types = len(types)
fig, axs = plt.subplots(num_types, 1, figsize=(12, 4.5*(num_types)))
n_genes = 20
for i, type in enumerate(types):
    # tumor_tumor = type + '_TT_Tumor'
    # normal_tumor = type + '_TT_Normal'
    titlesize = 9
    fontsize = 6

    
    cond_plot(adata, [type], valid_types, n_genes=n_genes,
                     ax= axs[i], sharey=False, key=f'rank_genes_groups_{region}', show=False,
                     fontsize=fontsize, titlesize=titlesize)
    # cond_plot(adata, [type], valid_types, n_genes=n_genes,
    #                  ax= axs[i, 1], sharey=False, key=f'rank_genes_groups_onlytumor', show=False,
    #                  fontsize=fontsize, titlesize=titlesize)
    # cond_plot(adata, [tumor_tumor, normal_tumor], valid_types, n_genes=n_genes, ax= axs[i, 1],
    #                         key=f"w_pair_{type}_differ", show=False,
    #                  fontsize=fontsize, titlesize=titlesize)

# Display the entire figure with all plots
plt.show()

# %% [markdown]
# ## Heatmaps

# %% [markdown]
# To show heatmap we need the logfold changes also...

# %%
sc.pl.rank_genes_groups_heatmap(adata, show_gene_labels=True, key='wilcoxon')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_type_tissue). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 36896 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /usr/local/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:1067: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if isinstance(groupby, str) and is_categorical_dtype(adata.obs[groupby]):
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:105: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(adata.obs[group]):
# /usr/local/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Airway epithelium_TT_Normal, Airway epithelium_TT_Tumor, Alveolar epithelium_TT_Normal, etc.
# var_group_labels: Lymphoid_TT_Normal, Myeloid_TT_Normal, Airway epithelium_TT_Tumor, etc.
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:133: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = rep_df.groupby(level=0).mean()

# %% [markdown]
# ## GSEA

# %%
from gprofiler import GProfiler
import gseapy
import seaborn as sns
gp = GProfiler(return_dataframe=True, user_agent='INMEGEN')

# %%
# gen_list = adata.uns['wilcoxon']['names']['Airway epithelium_TT_Tumor'][100:]
# enrich = gp.profile(list(gen_list), sources=['GO:BP'], organism="hsapiens")
# enrich.iloc[:25,:]

# %%
#  Download Gene symbols
if not os.path.exists('h.all.v2023.2.Hs.symbols.gmt'):
    ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.symbols.gmt

#  Gene entrez
# if not os.path.exists('h.all.v2023.2.Hs.entrez.gmt'):
# ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.entrez.gmt

# %%
from typing import List

def get_gseas_df(adata: ad.AnnData, valid_types: List[str],
                 types: List[str], id_: str, load_gsea: bool = False,
                 key:str = 'rank_gene_groups', gsea_folder:str = 'gseapy_gsea') -> pd.DataFrame:
    """
    Generates a combined DataFrame from GSEA results for different cell types.

    Args:
    adata (ad.AnnData): An AnnData object containing the dataset.
    valid_types (List[str]): A list of valid cell types to filter the cell types.
    types (List[str]): A list of cell types to be considered for analysis.
    id_ (str): Identifier used in generating the GSEA path.
    load_gsea (bool, optional): Flag to load existing GSEA results. Defaults to False.

    Returns:
    pd.DataFrame: A combined DataFrame with GSEA results pivoted by cell type and hallmark.

    The function uses the provided 'types', intersects them with 'valid_types',
    and computes GSEA for each type. The final DataFrame is a pivot table with cell types as rows
    and GSEA hallmarks as columns.
    """
    # Intersect types with valid types
    types = set(types).intersection(valid_types)
    dfs = []

    for type in types:
        ranks = adata.uns[key]
        type_path = type.replace('/','_')
        gsea_path = f'{gsea_folder}/{type_path}_{id_}.npz'

        # Generate gene scores
        gene_scores = {gene: ranks['scores'][type][i] for i, gene in enumerate(ranks['names'][type])}
        gene_scores = pd.Series(gene_scores)

        # Run GSEA
        if load_gsea:
            gseas = np.load(gsea_path, allow_pickle='TRUE').item()
        else:
            pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
                                     processes=20, permutation_num=100, seed=6, no_plot=True)
            gseas = pre_res.res2d
            np.save(gsea_path, gseas)

        data1 = {'hallmark': list(gseas['Term'].str.slice(9)), 'score': list(gseas['NES'])}
        df_celltype1 = pd.DataFrame(data1)
        df_celltype1['cell_type'] = type
        dfs.append(df_celltype1)

    # Combine all DataFrames
    combined_df = pd.concat(dfs).reset_index(drop=True).pivot(index='cell_type', columns='hallmark', values='score')
    return combined_df

# %%
# %%time
#papermill_description=GSEA
gsea_folder = 'gseapy_gsea'
combined_dfs = {}

for region in regions:
    gsea_path = f'{gsea_folder}/heatmap_{region}_{time}.csv'
    if load_gsea_heatmap:
        combined_dfs[region] = pd.read_csv(gsea_path, index_col=0)
    else:
        types = adata.uns[f'rank_genes_groups_{region}']['scores'].dtype.names
        combined_dfs[region] = get_gseas_df(adata, valid_types, types, id_, load_gsea=False, key=f'rank_genes_groups_{region}')
        combined_dfs[region].to_csv(gsea_path)
# Out:
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:37,876 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:38,663 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:39,269 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:39,846 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:40,412 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:40,973 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:41,549 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:42,115 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:42,669 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:43,224 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:44,377 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:44,933 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:45,653 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:46,265 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:47,496 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:48,052 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:48,644 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:49,209 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:49,772 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:50,339 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:50,948 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:52,126 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:53,836 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:54,399 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:54,964 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:55,542 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:56,880 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:57,611 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:58,198 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:58,768 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:56:59,905 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:01,082 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:01,647 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:02,213 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:02,801 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:03,421 [WARNING] Duplicated values found in preranked stats: 1.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:04,004 [WARNING] Duplicated values found in preranked stats: 1.98% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:04,609 [WARNING] Duplicated values found in preranked stats: 1.70% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:05,196 [WARNING] Duplicated values found in preranked stats: 1.99% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:05,796 [WARNING] Duplicated values found in preranked stats: 1.56% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:06,518 [WARNING] Duplicated values found in preranked stats: 1.35% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:07,144 [WARNING] Duplicated values found in preranked stats: 1.99% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:07,741 [WARNING] Duplicated values found in preranked stats: 1.89% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:08,410 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:08,978 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:09,572 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:10,152 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:11,312 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:11,896 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:12,463 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:13,104 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:13,678 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:14,273 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:14,841 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:15,423 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:16,006 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:16,598 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:17,177 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:17,754 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:18,329 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:18,926 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:19,513 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:20,134 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:20,716 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:21,417 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:22,008 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:22,600 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:23,176 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:24,927 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:25,500 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:26,084 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:26,664 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:27,229 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:27,791 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:28,381 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:28,945 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:30,085 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:30,669 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:31,815 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:32,381 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:32,965 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:33,542 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:34,701 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:35,900 [WARNING] Duplicated values found in preranked stats: 0.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:36,476 [WARNING] Duplicated values found in preranked stats: 0.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:37,075 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_145298/3327198433.py:40: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-06-14 23:57:37,675 [WARNING] Duplicated values found in preranked stats: 0.03% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# CPU times: user 3min 28s, sys: 14.7 s, total: 3min 43s
# Wall time: 1min

# %%
combined_dfs[region]
# Out:
# hallmark                  ADIPOGENESIS  ALLOGRAFT_REJECTION  \
# cell_type
# Tumor cells LUAD              1.385179            -1.000000
# Tumor cells LUAD EMT          0.962979            -1.698852
# Tumor cells LUAD MSLN         1.205333             0.721505
# Tumor cells LUAD NE           1.108878            -1.000000
# Tumor cells LUAD mitotic      1.211308            -1.000000
# Tumor cells LUSC              1.362146            -2.268965
# Tumor cells LUSC mitotic      1.270469            -1.000000
# Tumor cells NSCLC mixed      -1.244759            -2.045948
#
# hallmark                  ANDROGEN_RESPONSE  ANGIOGENESIS  APICAL_JUNCTION  \
# cell_type
# Tumor cells LUAD                   1.327392      0.898662         0.975571
# Tumor cells LUAD EMT              -1.297952      1.385156        -1.147256
# Tumor cells LUAD MSLN              1.245030      1.239334         1.101454
# Tumor cells LUAD NE                1.050197      0.676721         0.925393
# Tumor cells LUAD mitotic           1.080180     -1.306534         0.976211
# Tumor cells LUSC                  -1.004088     -1.060499         0.947719
# Tumor cells LUSC mitotic           0.935149     -1.296147         0.782493
# Tumor cells NSCLC mixed            1.075813     -1.245467         1.175175
#
# hallmark                  APICAL_SURFACE  APOPTOSIS  BILE_ACID_METABOLISM  \
# cell_type
# Tumor cells LUAD                0.961109   1.003821              1.019825
# Tumor cells LUAD EMT           -0.743597  -1.372340             -1.305298
# Tumor cells LUAD MSLN           1.045558   1.100449              1.054247
# Tumor cells LUAD NE             1.060494   0.875229              0.997833
# Tumor cells LUAD mitotic        0.959492   1.129360              0.852761
# Tumor cells LUSC                1.162958  -1.052432              0.821036
# Tumor cells LUSC mitotic        1.078952   0.813501              0.940703
# Tumor cells NSCLC mixed         1.340076  -1.038423             -0.833133
#
# hallmark                  CHOLESTEROL_HOMEOSTASIS  COAGULATION  ...  \
# cell_type                                                       ...
# Tumor cells LUAD                         1.490762     1.176540  ...
# Tumor cells LUAD EMT                     1.018020    -1.013391  ...
# Tumor cells LUAD MSLN                    1.244188     1.131000  ...
# Tumor cells LUAD NE                      1.139776     0.572162  ...
# Tumor cells LUAD mitotic                 1.355446     1.131085  ...
# Tumor cells LUSC                         1.308656    -1.234129  ...
# Tumor cells LUSC mitotic                 1.264724    -1.203123  ...
# Tumor cells NSCLC mixed                  1.300499     1.010599  ...
#
# hallmark                  PROTEIN_SECRETION  REACTIVE_OXYGEN_SPECIES_PATHWAY  \
# cell_type
# Tumor cells LUAD                   1.621359                         1.415603
# Tumor cells LUAD EMT              -1.006692                         1.592662
# Tumor cells LUAD MSLN              1.362180                         1.048373
# Tumor cells LUAD NE                1.302258                         1.096325
# Tumor cells LUAD mitotic           1.435936                         1.264051
# Tumor cells LUSC                   1.324436                         1.636218
# Tumor cells LUSC mitotic           1.263732                         1.471365
# Tumor cells NSCLC mixed            1.019497                        -1.303180
#
# hallmark                  SPERMATOGENESIS  TGF_BETA_SIGNALING  \
# cell_type
# Tumor cells LUAD                 1.045800            0.911878
# Tumor cells LUAD EMT             0.633768           -1.293659
# Tumor cells LUAD MSLN            0.950002            1.072134
# Tumor cells LUAD NE              1.109654            0.900400
# Tumor cells LUAD mitotic         1.229550            0.784730
# Tumor cells LUSC                 1.362052           -1.419960
# Tumor cells LUSC mitotic         1.576645           -1.160731
# Tumor cells NSCLC mixed         -0.813187           -1.095983
#
# hallmark                  TNFA_SIGNALING_VIA_NFKB  UNFOLDED_PROTEIN_RESPONSE  \
# cell_type
# Tumor cells LUAD                        -1.000000                   1.406214
# Tumor cells LUAD EMT                    -1.720307                  -1.067344
# Tumor cells LUAD MSLN                    0.948464                   1.235048
# Tumor cells LUAD NE                      0.667036                   1.315554
# Tumor cells LUAD mitotic                -1.000000                   1.191127
# Tumor cells LUSC                        -1.835468                   1.059770
# Tumor cells LUSC mitotic                -1.000000                   1.310929
# Tumor cells NSCLC mixed                 -1.135068                  -1.164943
#
# hallmark                  UV_RESPONSE_DN  UV_RESPONSE_UP  \
# cell_type
# Tumor cells LUAD                1.120867        1.009145
# Tumor cells LUAD EMT            1.043090       -1.483855
# Tumor cells LUAD MSLN           1.099807        1.140690
# Tumor cells LUAD NE             0.978590        1.028570
# Tumor cells LUAD mitotic        1.038920        1.032342
# Tumor cells LUSC               -0.952888        1.000061
# Tumor cells LUSC mitotic       -0.880739        1.057436
# Tumor cells NSCLC mixed        -0.914398       -1.121742
#
# hallmark                  WNT_BETA_CATENIN_SIGNALING  XENOBIOTIC_METABOLISM
# cell_type
# Tumor cells LUAD                            0.765120               1.385751
# Tumor cells LUAD EMT                        0.973137               1.132077
# Tumor cells LUAD MSLN                       0.870975               1.185255
# Tumor cells LUAD NE                         0.965479               1.106298
# Tumor cells LUAD mitotic                    0.801956               1.146589
# Tumor cells LUSC                            0.781523               1.557828
# Tumor cells LUSC mitotic                    0.790173               1.289721
# Tumor cells NSCLC mixed                    -1.144146              -1.000073
#
# [8 rows x 50 columns]

# %%
# Plotting the heatmap
# combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Tumor']
for region in regions:
    plt.figure(figsize=(15, 8))
    sns.heatmap(combined_dfs[region], cmap='viridis')
    plt.title(f'Hallmarks Scores by Cell Type for {region}')
    plt.xlabel('Hallmarks')
    plt.ylabel('Cell Types')
    plt.show()

# %% [markdown]
# ## Pseudotime

# %%
adata_tumor
# Out:
# View of AnnData object with n_obs × n_vars = 46473 × 17811
#     obs: 'sample', 'uicc_stage', 'ever_smoker', 'age', 'donor_id', 'origin', 'dataset', 'ann_fine', 'cell_type_predicted', 'doublet_status', 'leiden', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito', 'ann_coarse', 'cell_type_tumor', 'tumor_stage', 'EGFR_mutation', 'TP53_mutation', 'ALK_mutation', 'BRAF_mutation', 'ERBB2_mutation', 'KRAS_mutation', 'ROS_mutation', 'origin_fine', 'study', 'platform', 'cell_type_major', 'cell_type_neutro', 'cell_type_neutro_coarse', 'suspension_type', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'type_tissue', 'tumor'
#     var: 'is_highly_variable', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'ens'
#     uns: '_scvi', 'ann_fine_colors', 'batch_condition', 'cell_type_major_colors', 'cell_type_tumor_colors', 'citation', 'dataset_colors', 'default_embedding', 'hvg', 'neighbors', 'origin_colors', 'platform_colors', 'schema_reference', 'schema_version', 'title', 'umap', 'wilcoxon', 'cell_type_colors', 'tumor_colors', 'rank_genes_groups', 'rank_genes_groups_pairwise', 'rank_genes_groups_summary'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap'
#     layers: 'count', 'counts_length_scaled'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.draw_graph(adata_t_b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 sc.pl.draw_graph(adata_t_b)
#
# File /usr/local/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:795, in draw_graph(adata, layout, **kwargs)
#     761 """\
#     762 Scatter plot in graph-drawing basis.
#     763
#    (...)
#     792 tl.draw_graph
#     793 """
#     794 if layout is None:
# --> 795     layout = str(adata.uns['draw_graph']['params']['layout'])
#     796 basis = 'draw_graph_' + layout
#     797 if 'X_' + basis not in adata.obsm_keys():
#
# KeyError: 'draw_graph'

# %%
adata.obs['cell_type_tumor']

# %%
# adata_normal = adata[np.logical_not(adata.obs['cell_type_tumor'].str.contains('Tumor'))]
adata_t_b = adata[np.logical_or(adata.obs['cell_type_tumor'].str.contains('T cell'), adata.obs['cell_type_tumor'].str.contains('B cell'))]

# %%
sc.tl.diffmap(adata_t_b)
# Out:
# /usr/local/lib/python3.11/site-packages/scanpy/neighbors/__init__.py:933: RuntimeWarning: divide by zero encountered in divide
#   Q = scipy.sparse.spdiags(1.0 / q, 0, W.shape[0], W.shape[0])
# /usr/local/lib/python3.11/site-packages/scanpy/neighbors/__init__.py:943: RuntimeWarning: divide by zero encountered in divide
#   self.Z = scipy.sparse.spdiags(1.0 / z, 0, K.shape[0], K.shape[0])
# ---------------------------------------------------------------------------
# ArpackNoConvergence                       Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 sc.tl.diffmap(adata_t_b)
#
# File /usr/local/lib/python3.11/site-packages/scanpy/tools/_diffmap.py:77, in diffmap(adata, n_comps, neighbors_key, random_state, copy)
#      75     raise ValueError('Provide any value greater than 2 for `n_comps`. ')
#      76 adata = adata.copy() if copy else adata
# ---> 77 _diffmap(
#      78     adata, n_comps=n_comps, neighbors_key=neighbors_key, random_state=random_state
#      79 )
#      80 return adata if copy else None
#
# File /usr/local/lib/python3.11/site-packages/scanpy/tools/_dpt.py:17, in _diffmap(adata, n_comps, neighbors_key, random_state)
#      15 dpt = DPT(adata, neighbors_key=neighbors_key)
#      16 dpt.compute_transitions()
# ---> 17 dpt.compute_eigen(n_comps=n_comps, random_state=random_state)
#      18 adata.obsm['X_diffmap'] = dpt.eigen_basis
#      19 adata.uns['diffmap_evals'] = dpt.eigen_values
#
# File /usr/local/lib/python3.11/site-packages/scanpy/neighbors/__init__.py:1000, in Neighbors.compute_eigen(self, n_comps, sym, sort, random_state)
#     998     random_state = check_random_state(random_state)
#     999     v0 = random_state.standard_normal((matrix.shape[0]))
# -> 1000     evals, evecs = scipy.sparse.linalg.eigsh(
#    1001         matrix, k=n_comps, which=which, ncv=ncv, v0=v0
#    1002     )
#    1003     evals, evecs = evals.astype(np.float32), evecs.astype(np.float32)
#    1004 if sort == 'decrease':
#
# File /usr/local/lib/python3.11/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1697, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1695 with _ARPACK_LOCK:
#    1696     while not params.converged:
# -> 1697         params.iterate()
#    1699     return params.extract(return_eigenvectors)
#
# File /usr/local/lib/python3.11/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:571, in _SymmetricArpackParams.iterate(self)
#     569     pass
#     570 elif self.info == 1:
# --> 571     self._raise_no_convergence()
#     572 else:
#     573     raise ArpackError(self.info, infodict=self.iterate_infodict)
#
# File /usr/local/lib/python3.11/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:377, in _ArpackParams._raise_no_convergence(self)
#     375     vec = np.zeros((self.n, 0))
#     376     k_ok = 0
# --> 377 raise ArpackNoConvergence(msg % (num_iter, k_ok, self.k), ev, vec)
#
# ArpackNoConvergence: ARPACK error -1: No convergence (504391 iterations, 2/15 eigenvectors converged)
