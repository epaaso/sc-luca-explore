# %%
id_ = 'Zilionis_Klein_2019_NSCLC'
# id = 'Lambrechts_2018_LUAD_6149v1'
backup_dir = '/root/datos/maestria/netopaas/luca_explore/surgeries'
infercnv_dir = '/root/datos/maestria/netopaas/infercnv'
ikarus_dir = '/root/datos/maestria/netopaas/ikarus'
load_wilcoxon = True
load_gsea = True
load_gsea_heatmap = False
run_umap = False

# %%
# Parameters
id_ = "Lambrechts_2018_LUAD_6149v2"

# %% [markdown]
# # Cell Type Verification

# %% [markdown]
# ## Libraries and Data

# %% [markdown]
# We want to check our tumor vs normal classifier. For that we will explore the state of our cells by different methods.
#
# 1. Via UMAP, how the types of cell cluster vs the tumor and normal labels. Also, if it is normal adjacent or tumor. Sample labels to discard batch effects.
# 2. Marker genes plots for these comparisons per cell type: (**TypeNormalPred_HT** vs **REST**) (**TypeNormalPred_TT** vs **REST**) (**TypeNormalPred_HT** vs **TypeNormalPred_TT**)
#    (**TypeTumorPred_TT** vs **REST**) (**TypeTumorPred_TT** vs **TypeNormalPred_TT**)
# 3. Heatmaps With the above groups (**TumorPred_TT**, **NormalPred_TT**, **NormalPred_HT**) as  cell labels and hierarchical clustering in the genes. With genes chosen from the marker genes.
# 4. Prevalent gene ontologies for each of the groups above, considering also hallmark ontologies

# %%
import os
from pathlib import Path
import gdown

import sys
# This makes the working dir change apparently
sys.path.append("..")
import utils.functions as ut

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from scipy.sparse import csr_matrix

import anndata as ad
import scanpy as sc

# %%
# adata = sc.read_h5ad(f'{backup_dir}/combTumor_{id_}.h5ad')
adata = sc.read_h5ad(f'{backup_dir}/filtered_{id_}.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 48422 × 26993
#     obs: 'dataset', 'sample', 'patient', 'condition', 'platform', 'origin', 'sex', 'age', 'tissue', 'n_counts', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito'
#     var: 'n_counts', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# ### Types from infercnv dir

# %%
types = pd.read_csv(f'{infercnv_dir}/{id_}.csv')
types = types.rename(columns={'Unnamed: 0':'barcode_'})
types = types.rename(columns={'Level_2_transfered_label':'cell_type'})
types
# Out:
#                     barcode_ cell_type
# 0       AAACCTGCAACTGCGC-1_0  Lymphoid
# 1       AAACCTGCAAGTCATC-1_0   Myeloid
# 2       AAACCTGGTAAGTGTA-1_0   Myeloid
# 3       AAACCTGGTTCAGTAC-1_0  Lymphoid
# 4       AAACGGGAGAAGGGTA-1_0  Lymphoid
# ...                      ...       ...
# 48417  TTTGTCATCAGCCTAA-1_11  Lymphoid
# 48418  TTTGTCATCAGTACGT-1_11  Lymphoid
# 48419  TTTGTCATCCAAGTAC-1_11  Lymphoid
# 48420  TTTGTCATCGCACTCT-1_11  Lymphoid
# 48421  TTTGTCATCTCTTGAT-1_11  Lymphoid
#
# [48422 rows x 2 columns]

# %%
adata.obs['barcode_'] = adata.obs.index
adata.obs = pd.merge(adata.obs, types, on='barcode_',
                    how='left')
adata.obs.cell_type = adata.obs.cell_type.fillna('Unknown')
adata.obs.columns
# Out:
# Index(['dataset', 'sample', 'patient', 'condition', 'platform', 'origin',
#        'sex', 'age', 'tissue', 'n_counts', 'n_genes', 'n_genes_by_counts',
#        'total_counts', 'total_counts_mito', 'pct_counts_mito', 'barcode_',
#        'cell_type'],
#       dtype='object')

# %% [markdown]
# ### Tumor prediction from ikarus

# %%
preds = pd.read_csv(f'{ikarus_dir}/{id_}.csv')
preds
# Out:
#        Unnamed: 0 final_pred
# 0               0     Normal
# 1               1     Normal
# 2               2     Normal
# 3               3     Normal
# 4               4     Normal
# ...           ...        ...
# 48417       48417     Normal
# 48418       48418     Normal
# 48419       48419     Normal
# 48420       48420     Normal
# 48421       48421     Normal
#
# [48422 rows x 2 columns]

# %%
adata.obs['final_pred'] = list(preds.iloc[:,1])

# %%
adata.obs['origin']
# Out:
# 0        normal_adjacent
# 1        normal_adjacent
# 2        normal_adjacent
# 3        normal_adjacent
# 4        normal_adjacent
#               ...
# 48417      tumor_primary
# 48418      tumor_primary
# 48419      tumor_primary
# 48420      tumor_primary
# 48421      tumor_primary
# Name: origin, Length: 48422, dtype: category
# Categories (4, object): ['normal_adjacent', 'tumor_edge', 'tumor_middle', 'tumor_primary']

# %%
adata[np.logical_or(adata.obs['origin'].str.contains('normal'), adata.obs['origin']=='tumor_primary')].obs['origin'].value_counts()
# Out:
# origin
# normal_adjacent    12901
# tumor_primary      10778
# Name: count, dtype: int64

# %%
adata.layers['counts'] = adata.X

# %%
sc.pp.normalize_total(adata, target_sum=1e6)
sc.pp.log1p(adata)

# %% [markdown]
# ## UMAP Clusters

# %% [markdown]
# We see similarities between cell types in normal tisse and tumor tissue. And  also what cell types are tumoral.

# %%
#papermill_description=UMAP
if run_umap:
    sc.tl.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)

# %%
if run_umap:
    fig, axs = plt.subplots(2, 2, figsize=(15, 10))
    
    sc.pl.umap(
        adata,
        color="cell_type",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="final_pred",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="origin",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="sample",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    # Display the entire figure with all plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can see that for the 'Tumor' prediciton there are mostly cells from patient 41, although there are many more samples from primary tumor.
# This could be due to batch effects. So it is worthwile to run the prediction again with batch correction.

# %%
# adata.obs.groupby('leiden').count()
adata.obs.groupby('sample').count().iloc[:,0]
# Out:
# /tmp/ipykernel_27820/2910804369.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby('sample').count().iloc[:,0]
# sample
# BT1290    3758
# BT1291    3617
# BT1292    2736
# BT1293    4073
# BT1294    2764
# BT1295    2976
# BT1296    4986
# BT1297    4866
# BT1298    3176
# BT1299    4328
# BT1300    5078
# BT1301    6064
# Name: dataset, dtype: int64

# %% [markdown]
# ## Marker Genes

# %% [markdown]
# Create a column that merges cell type, tissue and tumor pred

# %%
adata.obs['type_tissue'] = adata.obs.apply(lambda x: str(x['cell_type']) + '_' + 
                 ('HT' if 'normal' in x['origin'] else 'TT') + 
                 '_' + x['final_pred'], axis=1)
adata.obs['type_tissue'] = adata.obs['type_tissue'].astype('category')
adata.obs['type_tissue']
# Out:
# 0        Lymphoid_HT_Normal
# 1         Myeloid_HT_Normal
# 2         Myeloid_HT_Normal
# 3        Lymphoid_HT_Normal
# 4        Lymphoid_HT_Normal
#                 ...
# 48417    Lymphoid_TT_Normal
# 48418    Lymphoid_TT_Normal
# 48419    Lymphoid_TT_Normal
# 48420    Lymphoid_TT_Normal
# 48421    Lymphoid_TT_Normal
# Name: type_tissue, Length: 48422, dtype: category
# Categories (36, object): ['Airway epithelium_HT_Normal', 'Airway epithelium_HT_Tumor', 'Airway epithelium_TT_Normal', 'Airway epithelium_TT_Tumor', ..., 'Unknown_HT_Normal', 'Unknown_HT_Tumor', 'Unknown_TT_Normal', 'Unknown_TT_Tumor']

# %%
# We dont get them with unique because it saves the NaN's
adata.obs.cell_type = adata.obs.cell_type.astype('category')
types = adata.obs.cell_type.cat.categories
num_types = len(types)
types
# Out:
# Index(['Airway epithelium', 'Alveolar epithelium', 'Blood vessels',
#        'Fibroblast lineage', 'Lymphatic EC', 'Lymphoid', 'Mesothelium',
#        'Myeloid', 'Smooth muscle', 'Unknown'],
#       dtype='object')

# %%
adata.obs['type_tissue'].value_counts()
# Out:
# type_tissue
# Lymphoid_TT_Normal               20617
# Lymphoid_HT_Normal                6024
# Myeloid_TT_Normal                 4811
# Myeloid_HT_Normal                 4595
# Airway epithelium_TT_Tumor        2864
# Unknown_TT_Tumor                  2502
# Alveolar epithelium_TT_Tumor      1156
# Alveolar epithelium_HT_Normal     1014
# Airway epithelium_TT_Normal        857
# Fibroblast lineage_TT_Normal       784
# Blood vessels_TT_Normal            740
# Blood vessels_HT_Normal            642
# Unknown_TT_Normal                  503
# Lymphoid_TT_Tumor                  241
# Fibroblast lineage_HT_Normal       227
# Alveolar epithelium_TT_Normal      207
# Unknown_HT_Normal                  148
# Smooth muscle_TT_Normal            102
# Airway epithelium_HT_Normal         68
# Airway epithelium_HT_Tumor          57
# Myeloid_TT_Tumor                    57
# Lymphatic EC_TT_Normal              51
# Lymphatic EC_HT_Normal              33
# Myeloid_HT_Tumor                    27
# Unknown_HT_Tumor                    26
# Alveolar epithelium_HT_Tumor        23
# Blood vessels_TT_Tumor              18
# Smooth muscle_HT_Normal             11
# Mesothelium_TT_Normal                4
# Fibroblast lineage_TT_Tumor          3
# Blood vessels_HT_Tumor               2
# Lymphatic EC_TT_Tumor                2
# Smooth muscle_TT_Tumor               2
# Mesothelium_HT_Normal                2
# Lymphatic EC_HT_Tumor                1
# Lymphoid_HT_Tumor                    1
# Name: count, dtype: int64

# %%
#papermill_description=WILCOXON_DE
# Get the groups that have more than 2 cells associated with them
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)
w_folder = 'wilcoxon_DE'

# Load

all_path = f'{w_folder}/all_{id_}.npy'
key = "wilcoxon"

if load_wilcoxon:
    adata.uns[key] = np.load(all_path, allow_pickle='TRUE').item()
else:
    sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = key,
                       groups=valid_types)
    np.save(all_path, adata.uns[key])

for type in types:
    tumor_tumor = type + '_TT_Tumor'
    normal_tumor = type + '_TT_Normal'
    normal_healthy = type + '_HT_Normal'

    differ_key = f"w_pair_{type}_differ"
    normal_key = f"w_pair_{type}_normal"
    differ_path =  f'{w_folder}/{differ_key}.npy'
    normal_path = f'{w_folder}/{normal_key}.npy'
    if load_wilcoxon:
        # We check for existance  here and not up there because there some datasets with no normal tissue
        if os.path.exists(differ_path):
            adata.uns[differ_key] = np.load(differ_path, allow_pickle='TRUE').item()
        if os.path.exists(normal_path):
            adata.uns[normal_key] = np.load(normal_path, allow_pickle='TRUE').item()
    else:
        if set([tumor_tumor, normal_tumor]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = differ_key,
                                    groups=[tumor_tumor], reference=normal_tumor)
            np.save(differ_path, adata.uns[differ_key])
            
        if set([normal_tumor, normal_healthy]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = normal_key,
                                    groups=[normal_tumor], reference=normal_healthy)
            np.save(normal_path, adata.uns[normal_key])

# %%
def cond_plot(adata, cond_types, valid_types, ax=None,
              key='wilcoxon', fontsize=9, titlesize=14, **kwds):
    print(cond_types)
    if set(cond_types).issubset(valid_types):
        ut.rank_genes_group(adata, cond_types[0], n_genes=n_genes,
                            ax=ax, sharey=False, key=key, show=False,
                            fontsize=fontsize, titlesize=titlesize)
    else:
        # Draw an empty plot with a message
        ax.text(0.5, 0.5, f'Missing cells: {cond_types}', color='red', 
                       ha='center', va='center', transform=ax.transAxes)
        ax.axis('off')

# %%
valid_types
# Out:
# ['Lymphoid_TT_Normal',
#  'Lymphoid_HT_Normal',
#  'Myeloid_TT_Normal',
#  'Myeloid_HT_Normal',
#  'Airway epithelium_TT_Tumor',
#  'Unknown_TT_Tumor',
#  'Alveolar epithelium_TT_Tumor',
#  'Alveolar epithelium_HT_Normal',
#  'Airway epithelium_TT_Normal',
#  'Fibroblast lineage_TT_Normal',
#  'Blood vessels_TT_Normal',
#  'Blood vessels_HT_Normal',
#  'Unknown_TT_Normal',
#  'Lymphoid_TT_Tumor',
#  'Fibroblast lineage_HT_Normal',
#  'Alveolar epithelium_TT_Normal',
#  'Unknown_HT_Normal',
#  'Smooth muscle_TT_Normal',
#  'Airway epithelium_HT_Normal',
#  'Airway epithelium_HT_Tumor',
#  'Myeloid_TT_Tumor',
#  'Lymphatic EC_TT_Normal',
#  'Lymphatic EC_HT_Normal',
#  'Myeloid_HT_Tumor',
#  'Unknown_HT_Tumor',
#  'Alveolar epithelium_HT_Tumor',
#  'Blood vessels_TT_Tumor',
#  'Smooth muscle_HT_Normal',
#  'Mesothelium_TT_Normal',
#  'Fibroblast lineage_TT_Tumor']

# %%
if(adata.obs.origin.str.contains('tumor').any()):
    fig, axs = plt.subplots(num_types, 2, figsize=(12, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        tumor_tumor = type + '_TT_Tumor'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [tumor_tumor], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [tumor_tumor, normal_tumor], valid_types, n_genes=n_genes, ax= axs[i, 1],
                                key=f"w_pair_{type}_differ", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    from warnings import warn
    warn('NO TUMOR TISSUES!?!?!?!!?')
# Out:
# ['Airway epithelium_TT_Tumor']
# ['Airway epithelium_TT_Tumor', 'Airway epithelium_TT_Normal']
# ['Alveolar epithelium_TT_Tumor']
# ['Alveolar epithelium_TT_Tumor', 'Alveolar epithelium_TT_Normal']
# ['Blood vessels_TT_Tumor']
# ['Blood vessels_TT_Tumor', 'Blood vessels_TT_Normal']
# ['Fibroblast lineage_TT_Tumor']
# ['Fibroblast lineage_TT_Tumor', 'Fibroblast lineage_TT_Normal']
# ['Lymphatic EC_TT_Tumor']
# ['Lymphatic EC_TT_Tumor', 'Lymphatic EC_TT_Normal']
# ['Lymphoid_TT_Tumor']
# ['Lymphoid_TT_Tumor', 'Lymphoid_TT_Normal']
# ['Mesothelium_TT_Tumor']
# ['Mesothelium_TT_Tumor', 'Mesothelium_TT_Normal']
# ['Myeloid_TT_Tumor']
# ['Myeloid_TT_Tumor', 'Myeloid_TT_Normal']
# ['Smooth muscle_TT_Tumor']
# ['Smooth muscle_TT_Tumor', 'Smooth muscle_TT_Normal']
# ['Unknown_TT_Tumor']
# ['Unknown_TT_Tumor', 'Unknown_TT_Normal']

# %%
adata.obs.origin.str.contains('normal').any()
# Out:
# True

# %%
from warnings import warn

if(adata.obs.origin.str.contains('normal').any()):
    fig, axs = plt.subplots(num_types, 3, figsize=(17, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        normal_healthy = type + '_HT_Normal'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [normal_healthy], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [normal_tumor], valid_types, n_genes=n_genes,
                                ax= axs[i, 1], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        print(f"w_pair_{type}_normal")
        cond_plot(adata, [normal_tumor, normal_healthy], valid_types, n_genes=n_genes, ax= axs[i, 2],
                                key=f"w_pair_{type}_normal", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    warn('No healthy tissue!')
# Out:
# ['Airway epithelium_HT_Normal']
# ['Airway epithelium_TT_Normal']
# w_pair_Airway epithelium_normal
# ['Airway epithelium_TT_Normal', 'Airway epithelium_HT_Normal']
# ['Alveolar epithelium_HT_Normal']
# ['Alveolar epithelium_TT_Normal']
# w_pair_Alveolar epithelium_normal
# ['Alveolar epithelium_TT_Normal', 'Alveolar epithelium_HT_Normal']
# ['Blood vessels_HT_Normal']
# ['Blood vessels_TT_Normal']
# w_pair_Blood vessels_normal
# ['Blood vessels_TT_Normal', 'Blood vessels_HT_Normal']
# ['Fibroblast lineage_HT_Normal']
# ['Fibroblast lineage_TT_Normal']
# w_pair_Fibroblast lineage_normal
# ['Fibroblast lineage_TT_Normal', 'Fibroblast lineage_HT_Normal']
# ['Lymphatic EC_HT_Normal']
# ['Lymphatic EC_TT_Normal']
# w_pair_Lymphatic EC_normal
# ['Lymphatic EC_TT_Normal', 'Lymphatic EC_HT_Normal']
# ['Lymphoid_HT_Normal']
# ['Lymphoid_TT_Normal']
# w_pair_Lymphoid_normal
# ['Lymphoid_TT_Normal', 'Lymphoid_HT_Normal']
# ['Mesothelium_HT_Normal']
# ['Mesothelium_TT_Normal']
# w_pair_Mesothelium_normal
# ['Mesothelium_TT_Normal', 'Mesothelium_HT_Normal']
# ['Myeloid_HT_Normal']
# ['Myeloid_TT_Normal']
# w_pair_Myeloid_normal
# ['Myeloid_TT_Normal', 'Myeloid_HT_Normal']
# ['Smooth muscle_HT_Normal']
# ['Smooth muscle_TT_Normal']
# w_pair_Smooth muscle_normal
# ['Smooth muscle_TT_Normal', 'Smooth muscle_HT_Normal']
# ['Unknown_HT_Normal']
# ['Unknown_TT_Normal']
# w_pair_Unknown_normal
# ['Unknown_TT_Normal', 'Unknown_HT_Normal']

# %% [markdown]
# ## Heatmaps

# %%
sc.pl.rank_genes_groups_heatmap(adata, show_gene_labels=True, key='wilcoxon')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_type_tissue). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 26993 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /usr/local/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:1067: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if isinstance(groupby, str) and is_categorical_dtype(adata.obs[groupby]):
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:105: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(adata.obs[group]):
# /usr/local/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Airway epithelium_HT_Normal, Airway epithelium_HT_Tumor, Airway epithelium_TT_Normal, etc.
# var_group_labels: Lymphoid_TT_Normal, Lymphoid_HT_Normal, Myeloid_TT_Normal, etc.
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:133: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = rep_df.groupby(level=0).mean()

# %% [markdown]
# ## GSEA

# %%
from gprofiler import GProfiler
import gseapy
import seaborn as sns
gp = GProfiler(return_dataframe=True, user_agent='INMEGEN')

# %%
# gen_list = adata.uns['wilcoxon']['names']['Airway epithelium_TT_Tumor'][100:]
# enrich = gp.profile(list(gen_list), sources=['GO:BP'], organism="hsapiens")
# enrich.iloc[:25,:]

# %%
#  Download Gene symbols
if not os.path.exists('h.all.v2023.2.Hs.symbols.gmt'):
    ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.symbols.gmt

#  Gene entrez
# if not os.path.exists('h.all.v2023.2.Hs.entrez.gmt'):
# ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.entrez.gmt

# %%
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)

# %%
from typing import List

def get_gseas_df(adata: ad.AnnData, valid_types: List[str], types: List[str], id_: str, load_gsea: bool = False) -> pd.DataFrame:
    """
    Generates a combined DataFrame from GSEA results for different cell types.

    Args:
    adata (ad.AnnData): An AnnData object containing the dataset.
    valid_types (List[str]): A list of valid cell types to filter the cell types.
    types (List[str]): A list of cell types to be considered for analysis.
    id_ (str): Identifier used in generating the GSEA path.
    load_gsea (bool, optional): Flag to load existing GSEA results. Defaults to False.

    Returns:
    pd.DataFrame: A combined DataFrame with GSEA results pivoted by cell type and hallmark.

    The function uses the provided 'types', intersects them with 'valid_types',
    and computes GSEA for each type. The final DataFrame is a pivot table with cell types as rows
    and GSEA hallmarks as columns.
    """
    # Intersect types with valid types
    types = set(types).intersection(valid_types)

    gsea_folder = 'gseapy_gsea'
    dfs = []

    for type in types:
        wilco = adata.uns['wilcoxon']
        gsea_path = f'{gsea_folder}/{type}_{id_}.npz'

        # Generate gene scores
        gene_scores = {gene: wilco['scores'][type][i] for i, gene in enumerate(wilco['names'][type])}
        gene_scores = pd.Series(gene_scores)

        # Run GSEA
        if load_gsea:
            gseas = np.load(gsea_path, allow_pickle='TRUE').item()
        else:
            pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
                                     processes=20, permutation_num=100, seed=6, no_plot=True)
            gseas = pre_res.res2d
            np.save(gsea_path, gseas)

        data1 = {'hallmark': list(gseas['Term'].str.slice(9)), 'score': list(gseas['NES'])}
        df_celltype1 = pd.DataFrame(data1)
        df_celltype1['cell_type'] = type
        dfs.append(df_celltype1)

    # Combine all DataFrames
    combined_df = pd.concat(dfs).reset_index(drop=True).pivot(index='cell_type', columns='hallmark', values='score')
    return combined_df

# %%
#papermill_description=GSEA
gsea_folder = 'gseapy_gsea'
gsea_path = f'{gsea_folder}/heatmap_{id_}.csv'

if load_gsea_heatmap:
    combined_df = pd.read_csv(gsea_path, index_col=0)
else:
    types = adata.obs.loc[:, 'type_tissue'].unique()
    combined_df = get_gseas_df(adata, valid_types, types, id_, load_gsea=False)
    combined_df.to_csv(gsea_path)
# Out:
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:17,020 [WARNING] Duplicated values found in preranked stats: 50.74% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:18,612 [WARNING] Duplicated values found in preranked stats: 65.92% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:20,482 [WARNING] Duplicated values found in preranked stats: 38.17% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:21,800 [WARNING] Duplicated values found in preranked stats: 20.15% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:23,111 [WARNING] Duplicated values found in preranked stats: 66.33% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:24,997 [WARNING] Duplicated values found in preranked stats: 23.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:26,350 [WARNING] Duplicated values found in preranked stats: 21.57% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:27,759 [WARNING] Duplicated values found in preranked stats: 27.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:29,359 [WARNING] Duplicated values found in preranked stats: 31.37% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:30,586 [WARNING] Duplicated values found in preranked stats: 34.74% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:31,759 [WARNING] Duplicated values found in preranked stats: 40.25% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:33,259 [WARNING] Duplicated values found in preranked stats: 24.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:34,248 [WARNING] Duplicated values found in preranked stats: 62.13% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:35,506 [WARNING] Duplicated values found in preranked stats: 68.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:36,916 [WARNING] Duplicated values found in preranked stats: 53.47% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:38,042 [WARNING] Duplicated values found in preranked stats: 26.51% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:39,423 [WARNING] Duplicated values found in preranked stats: 41.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:40,646 [WARNING] Duplicated values found in preranked stats: 66.05% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:41,987 [WARNING] Duplicated values found in preranked stats: 59.43% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:43,045 [WARNING] Duplicated values found in preranked stats: 41.57% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:44,477 [WARNING] Duplicated values found in preranked stats: 40.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:45,660 [WARNING] Duplicated values found in preranked stats: 24.86% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:46,986 [WARNING] Duplicated values found in preranked stats: 67.55% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:48,232 [WARNING] Duplicated values found in preranked stats: 40.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:49,453 [WARNING] Duplicated values found in preranked stats: 60.52% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:51,091 [WARNING] Duplicated values found in preranked stats: 49.94% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:52,284 [WARNING] Duplicated values found in preranked stats: 28.79% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:53,508 [WARNING] Duplicated values found in preranked stats: 30.67% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:54,873 [WARNING] Duplicated values found in preranked stats: 50.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27820/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:56,133 [WARNING] Duplicated values found in preranked stats: 21.38% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %%
combined_df
# Out:
# hallmark                       ADIPOGENESIS  ALLOGRAFT_REJECTION  \
# cell_type
# Airway epithelium_HT_Normal        1.123893            -1.000000
# Airway epithelium_HT_Tumor        -1.273820            -1.374955
# Airway epithelium_TT_Normal        1.262962            -1.000000
# Airway epithelium_TT_Tumor         1.306781            -2.362293
# Alveolar epithelium_HT_Normal      1.435411            -2.040281
# Alveolar epithelium_HT_Tumor      -1.091289            -1.366905
# Alveolar epithelium_TT_Normal      1.322651            -1.000000
# Alveolar epithelium_TT_Tumor       1.259932            -1.000000
# Blood vessels_HT_Normal           -0.908752            -1.167960
# Blood vessels_TT_Normal            1.296711            -1.786364
# Blood vessels_TT_Tumor            -1.056260            -2.041559
# Fibroblast lineage_HT_Normal       1.204832            -1.755734
# Fibroblast lineage_TT_Normal       1.262779            -1.000000
# Fibroblast lineage_TT_Tumor        1.073951            -1.000000
# Lymphatic EC_HT_Normal             1.204408            -1.000000
# Lymphatic EC_TT_Normal             1.239970            -1.000000
# Lymphoid_HT_Normal                -1.515392             1.000000
# Lymphoid_TT_Normal                -1.388585             1.000000
# Lymphoid_TT_Tumor                 -1.284748            -1.540114
# Mesothelium_TT_Normal              1.055705             0.610791
# Myeloid_HT_Normal                  1.280470             0.996402
# Myeloid_HT_Tumor                  -1.084876            -1.027059
# Myeloid_TT_Normal                  1.448330             1.161851
# Myeloid_TT_Tumor                   1.281181            -1.803643
# Smooth muscle_HT_Normal            1.094226            -1.632704
# Smooth muscle_TT_Normal            1.147706            -1.758297
# Unknown_HT_Normal                  1.331949            -1.000000
# Unknown_HT_Tumor                  -1.164851            -1.364143
# Unknown_TT_Normal                  1.293543            -1.000000
# Unknown_TT_Tumor                   1.319887            -1.000000
#
# hallmark                       ANDROGEN_RESPONSE  ANGIOGENESIS  \
# cell_type
# Airway epithelium_HT_Normal             1.128001      0.719408
# Airway epithelium_HT_Tumor             -1.049352     -1.230369
# Airway epithelium_TT_Normal             1.135019      1.020224
# Airway epithelium_TT_Tumor              1.033060     -0.854660
# Alveolar epithelium_HT_Normal           1.462589      0.701101
# Alveolar epithelium_HT_Tumor           -0.981344     -1.009524
# Alveolar epithelium_TT_Normal           1.216582     -0.852585
# Alveolar epithelium_TT_Tumor            1.059673      0.980047
# Blood vessels_HT_Normal                 1.066310      1.376765
# Blood vessels_TT_Normal                 1.020436      1.361928
# Blood vessels_TT_Tumor                  1.159040      1.086210
# Fibroblast lineage_HT_Normal            1.210557      1.699591
# Fibroblast lineage_TT_Normal            1.095800      1.564238
# Fibroblast lineage_TT_Tumor             1.022122      1.084144
# Lymphatic EC_HT_Normal                  1.203189      1.104160
# Lymphatic EC_TT_Normal                  1.024671      0.985618
# Lymphoid_HT_Normal                     -1.201016     -1.054633
# Lymphoid_TT_Normal                     -1.227008     -1.196673
# Lymphoid_TT_Tumor                      -1.038466     -1.035907
# Mesothelium_TT_Normal                   1.014500      1.079388
# Myeloid_HT_Normal                       1.121312      1.040404
# Myeloid_HT_Tumor                       -1.127403     -0.721296
# Myeloid_TT_Normal                       1.113314      1.447835
# Myeloid_TT_Tumor                       -0.944812      1.249573
# Smooth muscle_HT_Normal                -0.895217      1.128845
# Smooth muscle_TT_Normal                -1.017817      1.901531
# Unknown_HT_Normal                       1.369634      0.948603
# Unknown_HT_Tumor                       -1.091642     -1.189949
# Unknown_TT_Normal                       1.165934      1.297063
# Unknown_TT_Tumor                        1.041454      0.913829
#
# hallmark                       APICAL_JUNCTION  APICAL_SURFACE  APOPTOSIS  \
# cell_type
# Airway epithelium_HT_Normal           0.853176        0.886788   1.089294
# Airway epithelium_HT_Tumor           -1.092209       -1.028400  -1.106641
# Airway epithelium_TT_Normal           0.984706        1.036086   1.070775
# Airway epithelium_TT_Tumor            0.887905        0.791204   0.883178
# Alveolar epithelium_HT_Normal         1.123526        0.834042   1.240595
# Alveolar epithelium_HT_Tumor         -1.069445       -0.863728  -1.044533
# Alveolar epithelium_TT_Normal         0.896747        0.924233   1.061753
# Alveolar epithelium_TT_Tumor          1.082445        1.021778   0.975282
# Blood vessels_HT_Normal               1.392851        1.147541   1.595620
# Blood vessels_TT_Normal               1.419239        1.304170   1.174641
# Blood vessels_TT_Tumor               -0.999969        0.795905  -1.132696
# Fibroblast lineage_HT_Normal          1.272529        1.198921   1.689402
# Fibroblast lineage_TT_Normal          1.268585        1.284683   1.214580
# Fibroblast lineage_TT_Tumor           1.003009        1.070823   1.016300
# Lymphatic EC_HT_Normal                1.156496        1.349898   1.275420
# Lymphatic EC_TT_Normal                1.169633        1.155145   1.066236
# Lymphoid_HT_Normal                   -1.079011       -0.891102  -1.172978
# Lymphoid_TT_Normal                   -1.082798       -0.913302  -1.128903
# Lymphoid_TT_Tumor                    -1.142142       -0.953974  -1.284960
# Mesothelium_TT_Normal                 0.979978        1.135301   1.033197
# Myeloid_HT_Normal                     1.001445        0.986272   1.090343
# Myeloid_HT_Tumor                     -0.937096       -0.980477  -1.103599
# Myeloid_TT_Normal                     0.995112        0.915428   1.206039
# Myeloid_TT_Tumor                     -0.955900        1.045981  -1.136009
# Smooth muscle_HT_Normal               1.395599        1.024932   1.254804
# Smooth muscle_TT_Normal               1.461772        1.109968  -1.007235
# Unknown_HT_Normal                     1.193079        0.943843   1.372580
# Unknown_HT_Tumor                     -1.137828       -0.978950  -1.140475
# Unknown_TT_Normal                     1.106347        0.927441   1.123966
# Unknown_TT_Tumor                      1.040553        0.990171   1.006259
#
# hallmark                       BILE_ACID_METABOLISM  CHOLESTEROL_HOMEOSTASIS  \
# cell_type
# Airway epithelium_HT_Normal                1.163101                 1.251744
# Airway epithelium_HT_Tumor                -0.920842                -0.928213
# Airway epithelium_TT_Normal                1.156735                 1.192194
# Airway epithelium_TT_Tumor                 1.146226                 1.313805
# Alveolar epithelium_HT_Normal              1.336117                 1.597505
# Alveolar epithelium_HT_Tumor              -0.912577                -0.727404
# Alveolar epithelium_TT_Normal              1.234922                 1.350305
# Alveolar epithelium_TT_Tumor               0.982365                 1.276449
# Blood vessels_HT_Normal                   -1.289326                -0.812303
# Blood vessels_TT_Normal                   -1.090020                 0.844626
# Blood vessels_TT_Tumor                    -0.887741                -1.196847
# Fibroblast lineage_HT_Normal               0.959246                 1.152508
# Fibroblast lineage_TT_Normal               1.031406                 1.057048
# Fibroblast lineage_TT_Tumor                1.041768                 1.059723
# Lymphatic EC_HT_Normal                     0.830089                 1.111125
# Lymphatic EC_TT_Normal                     0.893451                 1.058740
# Lymphoid_HT_Normal                        -1.051379                -1.219966
# Lymphoid_TT_Normal                        -1.075947                -1.288584
# Lymphoid_TT_Tumor                         -0.980783                -1.152110
# Mesothelium_TT_Normal                      0.971988                 1.015061
# Myeloid_HT_Normal                          1.043422                 1.215835
# Myeloid_HT_Tumor                          -1.000152                -0.715041
# Myeloid_TT_Normal                          0.898112                 1.273593
# Myeloid_TT_Tumor                           0.996057                 1.407499
# Smooth muscle_HT_Normal                   -0.984136                 1.258187
# Smooth muscle_TT_Normal                   -1.209347                -1.056079
# Unknown_HT_Normal                          1.245944                 1.503614
# Unknown_HT_Tumor                          -1.044773                -0.969912
# Unknown_TT_Normal                          1.035594                 1.236580
# Unknown_TT_Tumor                           1.072014                 1.234010
#
# hallmark                       COAGULATION  ...  PROTEIN_SECRETION  \
# cell_type                                   ...
# Airway epithelium_HT_Normal       1.218556  ...           1.254245
# Airway epithelium_HT_Tumor       -1.152091  ...          -1.272841
# Airway epithelium_TT_Normal       1.292127  ...           1.364181
# Airway epithelium_TT_Tumor        0.989497  ...           1.393269
# Alveolar epithelium_HT_Normal     1.441982  ...           1.306637
# Alveolar epithelium_HT_Tumor     -0.952482  ...          -1.203062
# Alveolar epithelium_TT_Normal     1.371688  ...           1.362767
# Alveolar epithelium_TT_Tumor      1.192278  ...           1.305668
# Blood vessels_HT_Normal           1.884384  ...          -1.122223
# Blood vessels_TT_Normal           1.604597  ...           1.183660
# Blood vessels_TT_Tumor            1.245866  ...          -1.017423
# Fibroblast lineage_HT_Normal      2.082752  ...           0.975178
# Fibroblast lineage_TT_Normal      1.625847  ...           1.313749
# Fibroblast lineage_TT_Tumor       1.201734  ...           1.104921
# Lymphatic EC_HT_Normal            1.478114  ...           1.325080
# Lymphatic EC_TT_Normal            1.447809  ...           1.238900
# Lymphoid_HT_Normal               -1.391885  ...          -1.542034
# Lymphoid_TT_Normal               -1.446134  ...          -1.464255
# Lymphoid_TT_Tumor                -1.126261  ...          -1.087406
# Mesothelium_TT_Normal             1.127573  ...           1.062680
# Myeloid_HT_Normal                 1.252436  ...           1.232990
# Myeloid_HT_Tumor                 -0.720132  ...          -1.285030
# Myeloid_TT_Normal                 1.512849  ...           1.426379
# Myeloid_TT_Tumor                  1.818547  ...           1.064614
# Smooth muscle_HT_Normal           1.524615  ...          -1.043766
# Smooth muscle_TT_Normal           1.705564  ...          -0.895030
# Unknown_HT_Normal                 1.613836  ...           1.299295
# Unknown_HT_Tumor                 -1.132310  ...          -1.156460
# Unknown_TT_Normal                 1.389498  ...           1.334627
# Unknown_TT_Tumor                  1.206793  ...           1.400427
#
# hallmark                       REACTIVE_OXYGEN_SPECIES_PATHWAY  \
# cell_type
# Airway epithelium_HT_Normal                           1.024037
# Airway epithelium_HT_Tumor                           -0.748182
# Airway epithelium_TT_Normal                           1.324361
# Airway epithelium_TT_Tumor                            1.265418
# Alveolar epithelium_HT_Normal                         1.167762
# Alveolar epithelium_HT_Tumor                         -0.771012
# Alveolar epithelium_TT_Normal                         1.149012
# Alveolar epithelium_TT_Tumor                          1.148895
# Blood vessels_HT_Normal                              -0.945582
# Blood vessels_TT_Normal                               0.887836
# Blood vessels_TT_Tumor                               -0.926423
# Fibroblast lineage_HT_Normal                          0.987272
# Fibroblast lineage_TT_Normal                          1.119258
# Fibroblast lineage_TT_Tumor                           1.118520
# Lymphatic EC_HT_Normal                                0.989926
# Lymphatic EC_TT_Normal                                0.947790
# Lymphoid_HT_Normal                                   -1.333051
# Lymphoid_TT_Normal                                   -1.374122
# Lymphoid_TT_Tumor                                    -0.904939
# Mesothelium_TT_Normal                                 1.007579
# Myeloid_HT_Normal                                     1.258300
# Myeloid_HT_Tumor                                     -0.754967
# Myeloid_TT_Normal                                     1.224099
# Myeloid_TT_Tumor                                      1.402130
# Smooth muscle_HT_Normal                               0.954350
# Smooth muscle_TT_Normal                              -0.961924
# Unknown_HT_Normal                                     1.288432
# Unknown_HT_Tumor                                     -0.880401
# Unknown_TT_Normal                                     1.325108
# Unknown_TT_Tumor                                      1.336334
#
# hallmark                       SPERMATOGENESIS  TGF_BETA_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal           1.197766            1.091076
# Airway epithelium_HT_Tumor           -0.677905           -1.310535
# Airway epithelium_TT_Normal           1.054864            1.120769
# Airway epithelium_TT_Tumor            1.259071            0.752300
# Alveolar epithelium_HT_Normal         1.023162            1.191760
# Alveolar epithelium_HT_Tumor         -0.902628           -1.281667
# Alveolar epithelium_TT_Normal         1.052623            1.065424
# Alveolar epithelium_TT_Tumor          1.071280            1.088637
# Blood vessels_HT_Normal              -0.783433            1.512162
# Blood vessels_TT_Normal               0.925066            1.417902
# Blood vessels_TT_Tumor               -0.815664            1.337298
# Fibroblast lineage_HT_Normal         -0.841661            1.445525
# Fibroblast lineage_TT_Normal          0.808463            1.363094
# Fibroblast lineage_TT_Tumor           1.001427            0.976543
# Lymphatic EC_HT_Normal                0.992692            1.331816
# Lymphatic EC_TT_Normal                1.036663            1.335594
# Lymphoid_HT_Normal                   -0.990657           -1.044577
# Lymphoid_TT_Normal                   -1.006868           -1.293760
# Lymphoid_TT_Tumor                     0.831665           -1.308534
# Mesothelium_TT_Normal                 0.967913            1.125523
# Myeloid_HT_Normal                     0.907835            1.161648
# Myeloid_HT_Tumor                     -0.872785           -1.094149
# Myeloid_TT_Normal                    -0.909141            1.180021
# Myeloid_TT_Tumor                      0.797491           -1.081795
# Smooth muscle_HT_Normal               0.895169            0.991533
# Smooth muscle_TT_Normal               0.813241           -1.113607
# Unknown_HT_Normal                     1.119732            1.475504
# Unknown_HT_Tumor                     -0.766397           -1.362311
# Unknown_TT_Normal                     1.071994            1.162238
# Unknown_TT_Tumor                      1.100703            0.963013
#
# hallmark                       TNFA_SIGNALING_VIA_NFKB  \
# cell_type
# Airway epithelium_HT_Normal                   1.071573
# Airway epithelium_HT_Tumor                   -1.314795
# Airway epithelium_TT_Normal                   0.896372
# Airway epithelium_TT_Tumor                   -1.000000
# Alveolar epithelium_HT_Normal                 1.372478
# Alveolar epithelium_HT_Tumor                 -1.116106
# Alveolar epithelium_TT_Normal                 0.888667
# Alveolar epithelium_TT_Tumor                  0.827008
# Blood vessels_HT_Normal                       2.058374
# Blood vessels_TT_Normal                       0.896232
# Blood vessels_TT_Tumor                       -1.520834
# Fibroblast lineage_HT_Normal                  1.979191
# Fibroblast lineage_TT_Normal                  0.936042
# Fibroblast lineage_TT_Tumor                   0.763241
# Lymphatic EC_HT_Normal                        1.209881
# Lymphatic EC_TT_Normal                       -1.368794
# Lymphoid_HT_Normal                           -0.941121
# Lymphoid_TT_Normal                           -1.178466
# Lymphoid_TT_Tumor                            -1.484447
# Mesothelium_TT_Normal                         1.058850
# Myeloid_HT_Normal                             1.206225
# Myeloid_HT_Tumor                             -1.229968
# Myeloid_TT_Normal                             1.357997
# Myeloid_TT_Tumor                             -1.439639
# Smooth muscle_HT_Normal                       1.244059
# Smooth muscle_TT_Normal                      -1.680031
# Unknown_HT_Normal                             1.543260
# Unknown_HT_Tumor                             -1.315046
# Unknown_TT_Normal                             0.792862
# Unknown_TT_Tumor                             -1.000000
#
# hallmark                       UNFOLDED_PROTEIN_RESPONSE  UV_RESPONSE_DN  \
# cell_type
# Airway epithelium_HT_Normal                     0.942328        1.287445
# Airway epithelium_HT_Tumor                     -1.137482       -1.125771
# Airway epithelium_TT_Normal                     1.150596        1.167013
# Airway epithelium_TT_Tumor                      1.283576        0.907992
# Alveolar epithelium_HT_Normal                   0.835234        1.429474
# Alveolar epithelium_HT_Tumor                   -1.290547       -0.886186
# Alveolar epithelium_TT_Normal                   1.087026        1.291710
# Alveolar epithelium_TT_Tumor                    1.178843        1.150587
# Blood vessels_HT_Normal                        -1.300605        1.595552
# Blood vessels_TT_Normal                         0.982718        1.514129
# Blood vessels_TT_Tumor                         -1.283816        1.033248
# Fibroblast lineage_HT_Normal                   -0.923591        1.948071
# Fibroblast lineage_TT_Normal                    1.341867        1.508497
# Fibroblast lineage_TT_Tumor                     0.955652        1.061518
# Lymphatic EC_HT_Normal                          1.217925        1.470205
# Lymphatic EC_TT_Normal                          1.065594        1.332922
# Lymphoid_HT_Normal                             -1.199852       -1.156319
# Lymphoid_TT_Normal                             -1.178340       -1.218215
# Lymphoid_TT_Tumor                              -0.941230       -1.187189
# Mesothelium_TT_Normal                           1.100057        1.125647
# Myeloid_HT_Normal                               1.088331        0.964481
# Myeloid_HT_Tumor                               -1.279228       -1.115187
# Myeloid_TT_Normal                               1.124241        0.748247
# Myeloid_TT_Tumor                               -1.356527       -1.095767
# Smooth muscle_HT_Normal                        -1.131359        1.656591
# Smooth muscle_TT_Normal                        -1.346332        1.643648
# Unknown_HT_Normal                               0.867379        1.568090
# Unknown_HT_Tumor                               -1.209224       -1.080066
# Unknown_TT_Normal                               1.231720        1.206651
# Unknown_TT_Tumor                                1.263253        1.045001
#
# hallmark                       UV_RESPONSE_UP  WNT_BETA_CATENIN_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal          1.123843                    1.010628
# Airway epithelium_HT_Tumor          -1.107733                   -0.835058
# Airway epithelium_TT_Normal          1.124997                    0.956608
# Airway epithelium_TT_Tumor           0.993862                    0.930662
# Alveolar epithelium_HT_Normal        1.327716                    0.904720
# Alveolar epithelium_HT_Tumor        -1.209189                   -0.931285
# Alveolar epithelium_TT_Normal        1.127195                    0.910281
# Alveolar epithelium_TT_Tumor         1.016405                    1.025843
# Blood vessels_HT_Normal              1.361952                    0.800145
# Blood vessels_TT_Normal              1.033681                    1.299895
# Blood vessels_TT_Tumor              -1.447966                    1.239501
# Fibroblast lineage_HT_Normal         1.339414                    1.267692
# Fibroblast lineage_TT_Normal         0.932678                    1.139343
# Fibroblast lineage_TT_Tumor          0.981665                    0.899127
# Lymphatic EC_HT_Normal               1.226210                    0.993428
# Lymphatic EC_TT_Normal               0.953151                    1.123307
# Lymphoid_HT_Normal                  -1.220241                   -0.884343
# Lymphoid_TT_Normal                  -1.199697                   -0.899293
# Lymphoid_TT_Tumor                   -1.143477                   -0.709599
# Mesothelium_TT_Normal                1.013305                    1.057183
# Myeloid_HT_Normal                    1.142702                    0.959272
# Myeloid_HT_Tumor                    -1.199759                   -0.936422
# Myeloid_TT_Normal                    1.252593                   -0.726199
# Myeloid_TT_Tumor                    -1.322468                   -1.034583
# Smooth muscle_HT_Normal             -1.021878                    0.988572
# Smooth muscle_TT_Normal             -1.352995                   -0.682544
# Unknown_HT_Normal                    1.337918                    1.032948
# Unknown_HT_Tumor                    -1.260718                   -0.843570
# Unknown_TT_Normal                    1.085952                    1.082533
# Unknown_TT_Tumor                     1.029822                    0.992527
#
# hallmark                       XENOBIOTIC_METABOLISM
# cell_type
# Airway epithelium_HT_Normal                 1.114773
# Airway epithelium_HT_Tumor                 -1.162380
# Airway epithelium_TT_Normal                 1.235246
# Airway epithelium_TT_Tumor                  1.229529
# Alveolar epithelium_HT_Normal               1.360664
# Alveolar epithelium_HT_Tumor               -1.033184
# Alveolar epithelium_TT_Normal               1.245476
# Alveolar epithelium_TT_Tumor                1.219589
# Blood vessels_HT_Normal                     1.014600
# Blood vessels_TT_Normal                     0.992062
# Blood vessels_TT_Tumor                     -1.058762
# Fibroblast lineage_HT_Normal                1.523971
# Fibroblast lineage_TT_Normal                1.339633
# Fibroblast lineage_TT_Tumor                 1.028031
# Lymphatic EC_HT_Normal                      1.033258
# Lymphatic EC_TT_Normal                      0.992044
# Lymphoid_HT_Normal                         -1.496817
# Lymphoid_TT_Normal                         -1.357699
# Lymphoid_TT_Tumor                          -0.950678
# Mesothelium_TT_Normal                       1.048869
# Myeloid_HT_Normal                           1.248112
# Myeloid_HT_Tumor                           -1.018303
# Myeloid_TT_Normal                           1.459102
# Myeloid_TT_Tumor                            1.609161
# Smooth muscle_HT_Normal                    -0.999692
# Smooth muscle_TT_Normal                    -1.108739
# Unknown_HT_Normal                           1.287983
# Unknown_HT_Tumor                           -1.172366
# Unknown_TT_Normal                           1.228731
# Unknown_TT_Tumor                            1.263036
#
# [30 rows x 50 columns]

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Tumor']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df_tumor, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Normal']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()
