# %%
id_ = 'Zilionis_Klein_2019_NSCLC'
# id = 'Lambrechts_2018_LUAD_6149v1'
backup_dir = '/root/datos/maestria/netopaas/luca_explore/surgeries'
infercnv_dir = '/root/datos/maestria/netopaas/infercnv'
ikarus_dir = '/root/datos/maestria/netopaas/ikarus'
load_wilcoxon = True
load_gsea = True
load_gsea_heatmap = False
run_umap = False

# %%
# Parameters
id_ = "Lambrechts_2018_LUAD_6653"

# %% [markdown]
# # Cell Type Verification

# %% [markdown]
# ## Libraries and Data

# %% [markdown]
# We want to check our tumor vs normal classifier. For that we will explore the state of our cells by different methods.
#
# 1. Via UMAP, how the types of cell cluster vs the tumor and normal labels. Also, if it is normal adjacent or tumor. Sample labels to discard batch effects.
# 2. Marker genes plots for these comparisons per cell type: (**TypeNormalPred_HT** vs **REST**) (**TypeNormalPred_TT** vs **REST**) (**TypeNormalPred_HT** vs **TypeNormalPred_TT**)
#    (**TypeTumorPred_TT** vs **REST**) (**TypeTumorPred_TT** vs **TypeNormalPred_TT**)
# 3. Heatmaps With the above groups (**TumorPred_TT**, **NormalPred_TT**, **NormalPred_HT**) as  cell labels and hierarchical clustering in the genes. With genes chosen from the marker genes.
# 4. Prevalent gene ontologies for each of the groups above, considering also hallmark ontologies

# %%
import os
from pathlib import Path
import gdown

import sys
# This makes the working dir change apparently
sys.path.append("..")
import utils.functions as ut

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from scipy.sparse import csr_matrix

import anndata as ad
import scanpy as sc

# %%
# adata = sc.read_h5ad(f'{backup_dir}/combTumor_{id_}.h5ad')
adata = sc.read_h5ad(f'{backup_dir}/filtered_{id_}.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 26514 × 26359
#     obs: 'dataset', 'sample', 'patient', 'origin', 'condition', 'platform', 'age', 'sex', 'tissue', 'n_counts', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito'
#     var: 'n_counts', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# ### Types from infercnv dir

# %%
types = pd.read_csv(f'{infercnv_dir}/{id_}.csv')
types = types.rename(columns={'Unnamed: 0':'barcode_'})
types = types.rename(columns={'Level_2_transfered_label':'cell_type'})
types
# Out:
#                     barcode_          cell_type
# 0       AAACCTGCATTCTCAT-1_0           Lymphoid
# 1       AAACCTGGTGCGAAAC-1_0           Lymphoid
# 2       AAACCTGTCAGCGACC-1_0            Unknown
# 3       AAACGGGCAGTCACTA-1_0           Lymphoid
# 4       AAAGATGAGACTTTCG-1_0  Airway epithelium
# ...                      ...                ...
# 26509  TTTGTCAAGTGAACGC-1_11            Myeloid
# 26510  TTTGTCACAAAGCGGT-1_11            Myeloid
# 26511  TTTGTCACACCTCGTT-1_11           Lymphoid
# 26512  TTTGTCAGTAATAGCA-1_11           Lymphoid
# 26513  TTTGTCATCGCTGATA-1_11            Myeloid
#
# [26514 rows x 2 columns]

# %%
adata.obs['barcode_'] = adata.obs.index
adata.obs = pd.merge(adata.obs, types, on='barcode_',
                    how='left')
adata.obs.cell_type = adata.obs.cell_type.fillna('Unknown')
adata.obs.columns
# Out:
# Index(['dataset', 'sample', 'patient', 'origin', 'condition', 'platform',
#        'age', 'sex', 'tissue', 'n_counts', 'n_genes', 'n_genes_by_counts',
#        'total_counts', 'total_counts_mito', 'pct_counts_mito', 'barcode_',
#        'cell_type'],
#       dtype='object')

# %% [markdown]
# ### Tumor prediction from ikarus

# %%
preds = pd.read_csv(f'{ikarus_dir}/{id_}.csv')
preds
# Out:
#        Unnamed: 0 final_pred
# 0               0     Normal
# 1               1     Normal
# 2               2      Tumor
# 3               3     Normal
# 4               4     Normal
# ...           ...        ...
# 26509       26509     Normal
# 26510       26510     Normal
# 26511       26511     Normal
# 26512       26512     Normal
# 26513       26513     Normal
#
# [26514 rows x 2 columns]

# %%
adata.obs['final_pred'] = list(preds.iloc[:,1])

# %%
adata.obs['origin']
# Out:
# 0        tumor_primary
# 1        tumor_primary
# 2        tumor_primary
# 3        tumor_primary
# 4        tumor_primary
#              ...
# 26509    tumor_primary
# 26510    tumor_primary
# 26511    tumor_primary
# 26512    tumor_primary
# 26513    tumor_primary
# Name: origin, Length: 26514, dtype: category
# Categories (4, object): ['normal_adjacent', 'tumor_edge', 'tumor_middle', 'tumor_primary']

# %%
adata[np.logical_or(adata.obs['origin'].str.contains('normal'), adata.obs['origin']=='tumor_primary')].obs['origin'].value_counts()
# Out:
# origin
# normal_adjacent    9495
# tumor_primary      4877
# Name: count, dtype: int64

# %%
adata.layers['counts'] = adata.X

# %%
sc.pp.normalize_total(adata, target_sum=1e6)
sc.pp.log1p(adata)

# %% [markdown]
# ## UMAP Clusters

# %% [markdown]
# We see similarities between cell types in normal tisse and tumor tissue. And  also what cell types are tumoral.

# %%
#papermill_description=UMAP
if run_umap:
    sc.tl.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)

# %%
if run_umap:
    fig, axs = plt.subplots(2, 2, figsize=(15, 10))
    
    sc.pl.umap(
        adata,
        color="cell_type",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="final_pred",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="origin",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="sample",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    # Display the entire figure with all plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can see that for the 'Tumor' prediciton there are mostly cells from patient 41, although there are many more samples from primary tumor.
# This could be due to batch effects. So it is worthwile to run the prediction again with batch correction.

# %%
# adata.obs.groupby('leiden').count()
adata.obs.groupby('sample').count().iloc[:,0]
# Out:
# /tmp/ipykernel_27829/2910804369.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby('sample').count().iloc[:,0]
# sample
# BT1375            1311
# BT1376            1073
# BT1377             563
# BT1378            2471
# scrBT1425_hg19    2432
# scrBT1426_hg19    2907
# scrBT1427_hg19    2958
# scrBT1428_hg19    5091
# scrBT1429m        1933
# scrBT1430m        1748
# scrBT1431m        2893
# scrBT1432m        1134
# Name: dataset, dtype: int64

# %% [markdown]
# ## Marker Genes

# %% [markdown]
# Create a column that merges cell type, tissue and tumor pred

# %%
adata.obs['type_tissue'] = adata.obs.apply(lambda x: str(x['cell_type']) + '_' + 
                 ('HT' if 'normal' in x['origin'] else 'TT') + 
                 '_' + x['final_pred'], axis=1)
adata.obs['type_tissue'] = adata.obs['type_tissue'].astype('category')
adata.obs['type_tissue']
# Out:
# 0                 Lymphoid_TT_Normal
# 1                 Lymphoid_TT_Normal
# 2                   Unknown_TT_Tumor
# 3                 Lymphoid_TT_Normal
# 4        Airway epithelium_TT_Normal
#                     ...
# 26509              Myeloid_TT_Normal
# 26510              Myeloid_TT_Normal
# 26511             Lymphoid_TT_Normal
# 26512             Lymphoid_TT_Normal
# 26513              Myeloid_TT_Normal
# Name: type_tissue, Length: 26514, dtype: category
# Categories (29, object): ['Airway epithelium_HT_Normal', 'Airway epithelium_HT_Tumor', 'Airway epithelium_TT_Normal', 'Airway epithelium_TT_Tumor', ..., 'Unknown_HT_Normal', 'Unknown_HT_Tumor', 'Unknown_TT_Normal', 'Unknown_TT_Tumor']

# %%
# We dont get them with unique because it saves the NaN's
adata.obs.cell_type = adata.obs.cell_type.astype('category')
types = adata.obs.cell_type.cat.categories
num_types = len(types)
types
# Out:
# Index(['Airway epithelium', 'Alveolar epithelium', 'Blood vessels',
#        'Fibroblast lineage', 'Lymphatic EC', 'Lymphoid', 'Mesothelium',
#        'Myeloid', 'Smooth muscle', 'Unknown'],
#       dtype='object')

# %%
adata.obs['type_tissue'].value_counts()
# Out:
# type_tissue
# Lymphoid_TT_Normal               9370
# Myeloid_TT_Normal                5422
# Myeloid_HT_Normal                5197
# Lymphoid_HT_Normal               2618
# Alveolar epithelium_HT_Normal     664
# Blood vessels_HT_Normal           587
# Unknown_TT_Tumor                  478
# Alveolar epithelium_TT_Tumor      425
# Alveolar epithelium_TT_Normal     343
# Unknown_TT_Normal                 308
# Blood vessels_TT_Normal           203
# Airway epithelium_TT_Tumor        169
# Fibroblast lineage_HT_Normal      142
# Fibroblast lineage_TT_Normal      140
# Airway epithelium_HT_Normal       117
# Airway epithelium_TT_Normal       116
# Unknown_HT_Normal                 102
# Lymphatic EC_HT_Normal             50
# Lymphoid_TT_Tumor                  15
# Smooth muscle_TT_Normal            13
# Mesothelium_HT_Normal              10
# Lymphatic EC_TT_Normal              9
# Myeloid_TT_Tumor                    5
# Smooth muscle_HT_Normal             4
# Airway epithelium_HT_Tumor          2
# Blood vessels_TT_Tumor              2
# Lymphatic EC_TT_Tumor               1
# Myeloid_HT_Tumor                    1
# Unknown_HT_Tumor                    1
# Name: count, dtype: int64

# %%
#papermill_description=WILCOXON_DE
# Get the groups that have more than 2 cells associated with them
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)
w_folder = 'wilcoxon_DE'

# Load

all_path = f'{w_folder}/all_{id_}.npy'
key = "wilcoxon"

if load_wilcoxon:
    adata.uns[key] = np.load(all_path, allow_pickle='TRUE').item()
else:
    sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = key,
                       groups=valid_types)
    np.save(all_path, adata.uns[key])

for type in types:
    tumor_tumor = type + '_TT_Tumor'
    normal_tumor = type + '_TT_Normal'
    normal_healthy = type + '_HT_Normal'

    differ_key = f"w_pair_{type}_differ"
    normal_key = f"w_pair_{type}_normal"
    differ_path =  f'{w_folder}/{differ_key}.npy'
    normal_path = f'{w_folder}/{normal_key}.npy'
    if load_wilcoxon:
        # We check for existance  here and not up there because there some datasets with no normal tissue
        if os.path.exists(differ_path):
            adata.uns[differ_key] = np.load(differ_path, allow_pickle='TRUE').item()
        if os.path.exists(normal_path):
            adata.uns[normal_key] = np.load(normal_path, allow_pickle='TRUE').item()
    else:
        if set([tumor_tumor, normal_tumor]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = differ_key,
                                    groups=[tumor_tumor], reference=normal_tumor)
            np.save(differ_path, adata.uns[differ_key])
            
        if set([normal_tumor, normal_healthy]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = normal_key,
                                    groups=[normal_tumor], reference=normal_healthy)
            np.save(normal_path, adata.uns[normal_key])

# %%
def cond_plot(adata, cond_types, valid_types, ax=None,
              key='wilcoxon', fontsize=9, titlesize=14, **kwds):
    print(cond_types)
    if set(cond_types).issubset(valid_types):
        ut.rank_genes_group(adata, cond_types[0], n_genes=n_genes,
                            ax=ax, sharey=False, key=key, show=False,
                            fontsize=fontsize, titlesize=titlesize)
    else:
        # Draw an empty plot with a message
        ax.text(0.5, 0.5, f'Missing cells: {cond_types}', color='red', 
                       ha='center', va='center', transform=ax.transAxes)
        ax.axis('off')

# %%
valid_types
# Out:
# ['Lymphoid_TT_Normal',
#  'Myeloid_TT_Normal',
#  'Myeloid_HT_Normal',
#  'Lymphoid_HT_Normal',
#  'Alveolar epithelium_HT_Normal',
#  'Blood vessels_HT_Normal',
#  'Unknown_TT_Tumor',
#  'Alveolar epithelium_TT_Tumor',
#  'Alveolar epithelium_TT_Normal',
#  'Unknown_TT_Normal',
#  'Blood vessels_TT_Normal',
#  'Airway epithelium_TT_Tumor',
#  'Fibroblast lineage_HT_Normal',
#  'Fibroblast lineage_TT_Normal',
#  'Airway epithelium_HT_Normal',
#  'Airway epithelium_TT_Normal',
#  'Unknown_HT_Normal',
#  'Lymphatic EC_HT_Normal',
#  'Lymphoid_TT_Tumor',
#  'Smooth muscle_TT_Normal',
#  'Mesothelium_HT_Normal',
#  'Lymphatic EC_TT_Normal',
#  'Myeloid_TT_Tumor',
#  'Smooth muscle_HT_Normal']

# %%
if(adata.obs.origin.str.contains('tumor').any()):
    fig, axs = plt.subplots(num_types, 2, figsize=(12, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        tumor_tumor = type + '_TT_Tumor'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [tumor_tumor], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [tumor_tumor, normal_tumor], valid_types, n_genes=n_genes, ax= axs[i, 1],
                                key=f"w_pair_{type}_differ", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    from warnings import warn
    warn('NO TUMOR TISSUES!?!?!?!!?')
# Out:
# ['Airway epithelium_TT_Tumor']
# ['Airway epithelium_TT_Tumor', 'Airway epithelium_TT_Normal']
# ['Alveolar epithelium_TT_Tumor']
# ['Alveolar epithelium_TT_Tumor', 'Alveolar epithelium_TT_Normal']
# ['Blood vessels_TT_Tumor']
# ['Blood vessels_TT_Tumor', 'Blood vessels_TT_Normal']
# ['Fibroblast lineage_TT_Tumor']
# ['Fibroblast lineage_TT_Tumor', 'Fibroblast lineage_TT_Normal']
# ['Lymphatic EC_TT_Tumor']
# ['Lymphatic EC_TT_Tumor', 'Lymphatic EC_TT_Normal']
# ['Lymphoid_TT_Tumor']
# ['Lymphoid_TT_Tumor', 'Lymphoid_TT_Normal']
# ['Mesothelium_TT_Tumor']
# ['Mesothelium_TT_Tumor', 'Mesothelium_TT_Normal']
# ['Myeloid_TT_Tumor']
# ['Myeloid_TT_Tumor', 'Myeloid_TT_Normal']
# ['Smooth muscle_TT_Tumor']
# ['Smooth muscle_TT_Tumor', 'Smooth muscle_TT_Normal']
# ['Unknown_TT_Tumor']
# ['Unknown_TT_Tumor', 'Unknown_TT_Normal']

# %%
adata.obs.origin.str.contains('normal').any()
# Out:
# True

# %%
from warnings import warn

if(adata.obs.origin.str.contains('normal').any()):
    fig, axs = plt.subplots(num_types, 3, figsize=(17, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        normal_healthy = type + '_HT_Normal'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [normal_healthy], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [normal_tumor], valid_types, n_genes=n_genes,
                                ax= axs[i, 1], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        print(f"w_pair_{type}_normal")
        cond_plot(adata, [normal_tumor, normal_healthy], valid_types, n_genes=n_genes, ax= axs[i, 2],
                                key=f"w_pair_{type}_normal", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    warn('No healthy tissue!')
# Out:
# ['Airway epithelium_HT_Normal']
# ['Airway epithelium_TT_Normal']
# w_pair_Airway epithelium_normal
# ['Airway epithelium_TT_Normal', 'Airway epithelium_HT_Normal']
# ['Alveolar epithelium_HT_Normal']
# ['Alveolar epithelium_TT_Normal']
# w_pair_Alveolar epithelium_normal
# ['Alveolar epithelium_TT_Normal', 'Alveolar epithelium_HT_Normal']
# ['Blood vessels_HT_Normal']
# ['Blood vessels_TT_Normal']
# w_pair_Blood vessels_normal
# ['Blood vessels_TT_Normal', 'Blood vessels_HT_Normal']
# ['Fibroblast lineage_HT_Normal']
# ['Fibroblast lineage_TT_Normal']
# w_pair_Fibroblast lineage_normal
# ['Fibroblast lineage_TT_Normal', 'Fibroblast lineage_HT_Normal']
# ['Lymphatic EC_HT_Normal']
# ['Lymphatic EC_TT_Normal']
# w_pair_Lymphatic EC_normal
# ['Lymphatic EC_TT_Normal', 'Lymphatic EC_HT_Normal']
# ['Lymphoid_HT_Normal']
# ['Lymphoid_TT_Normal']
# w_pair_Lymphoid_normal
# ['Lymphoid_TT_Normal', 'Lymphoid_HT_Normal']
# ['Mesothelium_HT_Normal']
# ['Mesothelium_TT_Normal']
# w_pair_Mesothelium_normal
# ['Mesothelium_TT_Normal', 'Mesothelium_HT_Normal']
# ['Myeloid_HT_Normal']
# ['Myeloid_TT_Normal']
# w_pair_Myeloid_normal
# ['Myeloid_TT_Normal', 'Myeloid_HT_Normal']
# ['Smooth muscle_HT_Normal']
# ['Smooth muscle_TT_Normal']
# w_pair_Smooth muscle_normal
# ['Smooth muscle_TT_Normal', 'Smooth muscle_HT_Normal']
# ['Unknown_HT_Normal']
# ['Unknown_TT_Normal']
# w_pair_Unknown_normal
# ['Unknown_TT_Normal', 'Unknown_HT_Normal']

# %% [markdown]
# ## Heatmaps

# %%
sc.pl.rank_genes_groups_heatmap(adata, show_gene_labels=True, key='wilcoxon')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_type_tissue). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 26359 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /usr/local/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:1067: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if isinstance(groupby, str) and is_categorical_dtype(adata.obs[groupby]):
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:105: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(adata.obs[group]):
# /usr/local/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Airway epithelium_HT_Normal, Airway epithelium_HT_Tumor, Airway epithelium_TT_Normal, etc.
# var_group_labels: Lymphoid_TT_Normal, Myeloid_TT_Normal, Myeloid_HT_Normal, etc.
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:133: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = rep_df.groupby(level=0).mean()

# %% [markdown]
# ## GSEA

# %%
from gprofiler import GProfiler
import gseapy
import seaborn as sns
gp = GProfiler(return_dataframe=True, user_agent='INMEGEN')

# %%
# gen_list = adata.uns['wilcoxon']['names']['Airway epithelium_TT_Tumor'][100:]
# enrich = gp.profile(list(gen_list), sources=['GO:BP'], organism="hsapiens")
# enrich.iloc[:25,:]

# %%
#  Download Gene symbols
if not os.path.exists('h.all.v2023.2.Hs.symbols.gmt'):
    ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.symbols.gmt

#  Gene entrez
# if not os.path.exists('h.all.v2023.2.Hs.entrez.gmt'):
# ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.entrez.gmt

# %%
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)

# %%
from typing import List

def get_gseas_df(adata: ad.AnnData, valid_types: List[str], types: List[str], id_: str, load_gsea: bool = False) -> pd.DataFrame:
    """
    Generates a combined DataFrame from GSEA results for different cell types.

    Args:
    adata (ad.AnnData): An AnnData object containing the dataset.
    valid_types (List[str]): A list of valid cell types to filter the cell types.
    types (List[str]): A list of cell types to be considered for analysis.
    id_ (str): Identifier used in generating the GSEA path.
    load_gsea (bool, optional): Flag to load existing GSEA results. Defaults to False.

    Returns:
    pd.DataFrame: A combined DataFrame with GSEA results pivoted by cell type and hallmark.

    The function uses the provided 'types', intersects them with 'valid_types',
    and computes GSEA for each type. The final DataFrame is a pivot table with cell types as rows
    and GSEA hallmarks as columns.
    """
    # Intersect types with valid types
    types = set(types).intersection(valid_types)

    gsea_folder = 'gseapy_gsea'
    dfs = []

    for type in types:
        wilco = adata.uns['wilcoxon']
        gsea_path = f'{gsea_folder}/{type}_{id_}.npz'

        # Generate gene scores
        gene_scores = {gene: wilco['scores'][type][i] for i, gene in enumerate(wilco['names'][type])}
        gene_scores = pd.Series(gene_scores)

        # Run GSEA
        if load_gsea:
            gseas = np.load(gsea_path, allow_pickle='TRUE').item()
        else:
            pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
                                     processes=20, permutation_num=100, seed=6, no_plot=True)
            gseas = pre_res.res2d
            np.save(gsea_path, gseas)

        data1 = {'hallmark': list(gseas['Term'].str.slice(9)), 'score': list(gseas['NES'])}
        df_celltype1 = pd.DataFrame(data1)
        df_celltype1['cell_type'] = type
        dfs.append(df_celltype1)

    # Combine all DataFrames
    combined_df = pd.concat(dfs).reset_index(drop=True).pivot(index='cell_type', columns='hallmark', values='score')
    return combined_df

# %%
#papermill_description=GSEA
gsea_folder = 'gseapy_gsea'
gsea_path = f'{gsea_folder}/heatmap_{id_}.csv'

if load_gsea_heatmap:
    combined_df = pd.read_csv(gsea_path, index_col=0)
else:
    types = adata.obs.loc[:, 'type_tissue'].unique()
    combined_df = get_gseas_df(adata, valid_types, types, id_, load_gsea=False)
    combined_df.to_csv(gsea_path)
# Out:
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:47,342 [WARNING] Duplicated values found in preranked stats: 60.33% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:49,471 [WARNING] Duplicated values found in preranked stats: 50.11% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:51,689 [WARNING] Duplicated values found in preranked stats: 42.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:54,137 [WARNING] Duplicated values found in preranked stats: 31.69% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:56,669 [WARNING] Duplicated values found in preranked stats: 36.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:30:58,392 [WARNING] Duplicated values found in preranked stats: 30.20% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:00,619 [WARNING] Duplicated values found in preranked stats: 38.95% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:02,598 [WARNING] Duplicated values found in preranked stats: 30.41% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:04,225 [WARNING] Duplicated values found in preranked stats: 38.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:06,600 [WARNING] Duplicated values found in preranked stats: 21.56% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:08,020 [WARNING] Duplicated values found in preranked stats: 23.59% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:09,513 [WARNING] Duplicated values found in preranked stats: 32.44% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:10,994 [WARNING] Duplicated values found in preranked stats: 44.00% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:12,187 [WARNING] Duplicated values found in preranked stats: 68.18% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:13,769 [WARNING] Duplicated values found in preranked stats: 41.90% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:15,114 [WARNING] Duplicated values found in preranked stats: 61.74% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:16,575 [WARNING] Duplicated values found in preranked stats: 59.44% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:18,002 [WARNING] Duplicated values found in preranked stats: 20.55% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:19,502 [WARNING] Duplicated values found in preranked stats: 35.60% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:21,062 [WARNING] Duplicated values found in preranked stats: 33.07% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:22,365 [WARNING] Duplicated values found in preranked stats: 70.88% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:23,449 [WARNING] Duplicated values found in preranked stats: 57.71% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:25,197 [WARNING] Duplicated values found in preranked stats: 33.02% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27829/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:26,387 [WARNING] Duplicated values found in preranked stats: 37.52% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %%
combined_df
# Out:
# hallmark                       ADIPOGENESIS  ALLOGRAFT_REJECTION  \
# cell_type
# Airway epithelium_HT_Normal        1.146563            -1.000000
# Airway epithelium_TT_Normal        1.071634            -2.594438
# Airway epithelium_TT_Tumor         1.076653            -2.218286
# Alveolar epithelium_HT_Normal      1.353297            -2.065283
# Alveolar epithelium_TT_Normal      1.262605            -1.000000
# Alveolar epithelium_TT_Tumor       1.125107            -2.206250
# Blood vessels_HT_Normal           -0.963710            -1.315666
# Blood vessels_TT_Normal            1.032515            -1.702741
# Fibroblast lineage_HT_Normal       1.083624            -1.923784
# Fibroblast lineage_TT_Normal       1.075969            -1.000000
# Lymphatic EC_HT_Normal             1.196764            -2.054153
# Lymphatic EC_TT_Normal             1.010607            -1.904923
# Lymphoid_HT_Normal                -1.405996             1.000000
# Lymphoid_TT_Normal                -1.482692             1.000000
# Lymphoid_TT_Tumor                 -1.454448            -1.915302
# Mesothelium_HT_Normal              1.081054            -1.493177
# Myeloid_HT_Normal                  1.446998             0.793802
# Myeloid_TT_Normal                  1.322076             0.956162
# Myeloid_TT_Tumor                   1.207443            -1.792239
# Smooth muscle_HT_Normal           -0.950349            -1.625640
# Smooth muscle_TT_Normal            1.198445            -1.935069
# Unknown_HT_Normal                  1.309630            -2.062724
# Unknown_TT_Normal                  1.165470            -2.122680
# Unknown_TT_Tumor                   1.031059            -2.159313
#
# hallmark                       ANDROGEN_RESPONSE  ANGIOGENESIS  \
# cell_type
# Airway epithelium_HT_Normal             1.000546     -0.967196
# Airway epithelium_TT_Normal             1.063590     -1.183608
# Airway epithelium_TT_Tumor             -1.093903     -1.300393
# Alveolar epithelium_HT_Normal           1.330701     -1.097313
# Alveolar epithelium_TT_Normal           1.304696      0.650221
# Alveolar epithelium_TT_Tumor           -1.149447     -1.270793
# Blood vessels_HT_Normal                -0.814764      1.265666
# Blood vessels_TT_Normal                 1.159431      1.317655
# Fibroblast lineage_HT_Normal           -0.863554      1.614147
# Fibroblast lineage_TT_Normal            1.035964      1.430970
# Lymphatic EC_HT_Normal                  1.052418      1.260618
# Lymphatic EC_TT_Normal                  0.872486      0.981886
# Lymphoid_HT_Normal                     -1.070649     -1.308510
# Lymphoid_TT_Normal                     -1.234869     -1.440965
# Lymphoid_TT_Tumor                      -1.271074     -1.227911
# Mesothelium_HT_Normal                   1.184067      1.066853
# Myeloid_HT_Normal                       1.115074      1.256540
# Myeloid_TT_Normal                       1.192669      1.397717
# Myeloid_TT_Tumor                       -0.946694      0.783997
# Smooth muscle_HT_Normal                -1.060851      1.020192
# Smooth muscle_TT_Normal                 0.879799      1.509070
# Unknown_HT_Normal                       1.343935      1.261976
# Unknown_TT_Normal                       1.202756      0.943532
# Unknown_TT_Tumor                       -1.155938     -1.165133
#
# hallmark                       APICAL_JUNCTION  APICAL_SURFACE  APOPTOSIS  \
# cell_type
# Airway epithelium_HT_Normal           0.712218        0.820831   0.938689
# Airway epithelium_TT_Normal          -1.000000        0.713297   0.802862
# Airway epithelium_TT_Tumor            0.966378        1.016663  -1.385534
# Alveolar epithelium_HT_Normal         1.132800        0.827946   1.153281
# Alveolar epithelium_TT_Normal         0.968852        0.879379   0.940713
# Alveolar epithelium_TT_Tumor         -1.067872       -0.825951  -1.254569
# Blood vessels_HT_Normal               1.289009        0.934262   1.314466
# Blood vessels_TT_Normal               1.590283        1.230131   1.174150
# Fibroblast lineage_HT_Normal          1.311183        1.153406   1.576537
# Fibroblast lineage_TT_Normal          1.269572        1.083118   1.064828
# Lymphatic EC_HT_Normal                1.273549        1.282627   1.268221
# Lymphatic EC_TT_Normal                1.281870        1.319000   1.020724
# Lymphoid_HT_Normal                   -0.965672       -0.923127  -1.146362
# Lymphoid_TT_Normal                   -1.145054       -0.903210  -1.134674
# Lymphoid_TT_Tumor                    -1.236617        0.994742  -1.678393
# Mesothelium_HT_Normal                 1.046621        1.175219   1.226156
# Myeloid_HT_Normal                     1.062801        0.885034   1.118838
# Myeloid_TT_Normal                     1.131732        0.988802   1.101892
# Myeloid_TT_Tumor                      1.128626        1.102415  -1.096809
# Smooth muscle_HT_Normal               1.371435        0.772684   1.129419
# Smooth muscle_TT_Normal               1.270724        1.045775   1.069601
# Unknown_HT_Normal                     1.442870        0.894582   1.540600
# Unknown_TT_Normal                     1.029572        0.968809   0.966102
# Unknown_TT_Tumor                     -1.178220       -0.959256  -1.429862
#
# hallmark                       BILE_ACID_METABOLISM  CHOLESTEROL_HOMEOSTASIS  \
# cell_type
# Airway epithelium_HT_Normal                1.307062                 1.201899
# Airway epithelium_TT_Normal                1.265473                 1.072190
# Airway epithelium_TT_Tumor                 0.761346                 1.153786
# Alveolar epithelium_HT_Normal              1.512637                 1.699697
# Alveolar epithelium_TT_Normal              1.237834                 1.522426
# Alveolar epithelium_TT_Tumor               1.188641                 1.059698
# Blood vessels_HT_Normal                   -1.267313                -1.216784
# Blood vessels_TT_Normal                   -1.295792                -1.123713
# Fibroblast lineage_HT_Normal               1.062873                -0.951635
# Fibroblast lineage_TT_Normal               0.939216                 0.969301
# Lymphatic EC_HT_Normal                     0.695731                 0.917668
# Lymphatic EC_TT_Normal                     0.707994                -0.940328
# Lymphoid_HT_Normal                        -1.013486                -1.293985
# Lymphoid_TT_Normal                        -1.073892                -1.395219
# Lymphoid_TT_Tumor                         -0.972189                -1.354097
# Mesothelium_HT_Normal                      0.926151                 1.256490
# Myeloid_HT_Normal                          1.100598                 1.319992
# Myeloid_TT_Normal                          0.953294                 1.250851
# Myeloid_TT_Tumor                           1.091074                 1.367538
# Smooth muscle_HT_Normal                   -1.150161                -1.201944
# Smooth muscle_TT_Normal                    0.833241                -1.010965
# Unknown_HT_Normal                          1.416379                 1.724209
# Unknown_TT_Normal                          1.080039                 1.380298
# Unknown_TT_Tumor                           1.033917                 0.889881
#
# hallmark                       COAGULATION  ...  PROTEIN_SECRETION  \
# cell_type                                   ...
# Airway epithelium_HT_Normal       0.909098  ...           1.165225
# Airway epithelium_TT_Normal       0.963327  ...           1.199886
# Airway epithelium_TT_Tumor       -1.312200  ...           0.997047
# Alveolar epithelium_HT_Normal     1.337172  ...           1.221001
# Alveolar epithelium_TT_Normal     1.323680  ...           1.362275
# Alveolar epithelium_TT_Tumor     -1.145072  ...           0.826592
# Blood vessels_HT_Normal           1.566884  ...          -1.174667
# Blood vessels_TT_Normal           1.602859  ...           1.006566
# Fibroblast lineage_HT_Normal      1.966026  ...          -0.787880
# Fibroblast lineage_TT_Normal      1.477819  ...           1.301083
# Lymphatic EC_HT_Normal            1.557544  ...           1.356144
# Lymphatic EC_TT_Normal            1.344276  ...           1.004994
# Lymphoid_HT_Normal               -1.439328  ...          -1.516241
# Lymphoid_TT_Normal               -1.558091  ...          -1.493086
# Lymphoid_TT_Tumor                -1.335528  ...          -1.110432
# Mesothelium_HT_Normal             1.498917  ...           1.112526
# Myeloid_HT_Normal                 1.382029  ...           1.369222
# Myeloid_TT_Normal                 1.344331  ...           1.349108
# Myeloid_TT_Tumor                  1.301942  ...          -1.045642
# Smooth muscle_HT_Normal           1.320699  ...          -0.939204
# Smooth muscle_TT_Normal           1.521037  ...           0.898225
# Unknown_HT_Normal                 1.885006  ...           1.170508
# Unknown_TT_Normal                 1.321909  ...           1.458755
# Unknown_TT_Tumor                 -1.319543  ...           0.950396
#
# hallmark                       REACTIVE_OXYGEN_SPECIES_PATHWAY  \
# cell_type
# Airway epithelium_HT_Normal                           1.104142
# Airway epithelium_TT_Normal                           0.903788
# Airway epithelium_TT_Tumor                            1.287175
# Alveolar epithelium_HT_Normal                         1.083202
# Alveolar epithelium_TT_Normal                         1.020892
# Alveolar epithelium_TT_Tumor                          1.351041
# Blood vessels_HT_Normal                              -1.074987
# Blood vessels_TT_Normal                              -1.078708
# Fibroblast lineage_HT_Normal                         -0.926290
# Fibroblast lineage_TT_Normal                          0.813441
# Lymphatic EC_HT_Normal                               -0.938934
# Lymphatic EC_TT_Normal                               -1.004088
# Lymphoid_HT_Normal                                   -1.266245
# Lymphoid_TT_Normal                                   -1.374802
# Lymphoid_TT_Tumor                                    -1.193400
# Mesothelium_HT_Normal                                 1.114958
# Myeloid_HT_Normal                                     1.351158
# Myeloid_TT_Normal                                     1.219120
# Myeloid_TT_Tumor                                      1.178662
# Smooth muscle_HT_Normal                               0.837739
# Smooth muscle_TT_Normal                               0.901286
# Unknown_HT_Normal                                     1.172518
# Unknown_TT_Normal                                     1.002473
# Unknown_TT_Tumor                                      1.148912
#
# hallmark                       SPERMATOGENESIS  TGF_BETA_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal           1.322129            0.824762
# Airway epithelium_TT_Normal           1.324686           -0.944671
# Airway epithelium_TT_Tumor            1.420850           -1.205783
# Alveolar epithelium_HT_Normal         0.801504            0.978291
# Alveolar epithelium_TT_Normal         1.082209            0.952853
# Alveolar epithelium_TT_Tumor          1.249547           -1.338844
# Blood vessels_HT_Normal              -0.785559            1.302149
# Blood vessels_TT_Normal               0.917225            1.594482
# Fibroblast lineage_HT_Normal         -0.713585            0.911265
# Fibroblast lineage_TT_Normal          1.003261            1.229549
# Lymphatic EC_HT_Normal                0.939646            1.261594
# Lymphatic EC_TT_Normal                0.983153            1.237287
# Lymphoid_HT_Normal                   -0.998748           -1.094299
# Lymphoid_TT_Normal                   -0.958404           -1.201396
# Lymphoid_TT_Tumor                     1.404172           -1.253928
# Mesothelium_HT_Normal                 0.973576            1.141308
# Myeloid_HT_Normal                     0.998350            1.168785
# Myeloid_TT_Normal                     0.909520            1.156747
# Myeloid_TT_Tumor                      1.083708           -1.146573
# Smooth muscle_HT_Normal              -0.817169           -0.978637
# Smooth muscle_TT_Normal               0.900798           -0.947584
# Unknown_HT_Normal                     0.872394            1.375773
# Unknown_TT_Normal                     1.111592            0.943458
# Unknown_TT_Tumor                      1.391894           -1.344896
#
# hallmark                       TNFA_SIGNALING_VIA_NFKB  \
# cell_type
# Airway epithelium_HT_Normal                  -1.000000
# Airway epithelium_TT_Normal                  -1.000000
# Airway epithelium_TT_Tumor                   -1.829583
# Alveolar epithelium_HT_Normal                 1.202743
# Alveolar epithelium_TT_Normal                -1.000000
# Alveolar epithelium_TT_Tumor                 -1.920410
# Blood vessels_HT_Normal                       1.146941
# Blood vessels_TT_Normal                      -1.188879
# Fibroblast lineage_HT_Normal                  1.405328
# Fibroblast lineage_TT_Normal                  0.823868
# Lymphatic EC_HT_Normal                        1.001364
# Lymphatic EC_TT_Normal                       -1.357279
# Lymphoid_HT_Normal                           -1.105509
# Lymphoid_TT_Normal                           -1.039097
# Lymphoid_TT_Tumor                            -1.725916
# Mesothelium_HT_Normal                         1.443256
# Myeloid_HT_Normal                             1.078933
# Myeloid_TT_Normal                             1.174708
# Myeloid_TT_Tumor                             -1.475107
# Smooth muscle_HT_Normal                      -1.023141
# Smooth muscle_TT_Normal                      -1.460035
# Unknown_HT_Normal                             1.470272
# Unknown_TT_Normal                            -1.496858
# Unknown_TT_Tumor                             -1.893004
#
# hallmark                       UNFOLDED_PROTEIN_RESPONSE  UV_RESPONSE_DN  \
# cell_type
# Airway epithelium_HT_Normal                     0.721319        1.184826
# Airway epithelium_TT_Normal                     0.914231        1.167184
# Airway epithelium_TT_Tumor                      1.154955       -1.079513
# Alveolar epithelium_HT_Normal                  -1.156564        1.543956
# Alveolar epithelium_TT_Normal                   1.174175        1.269912
# Alveolar epithelium_TT_Tumor                    0.914030       -0.942613
# Blood vessels_HT_Normal                        -1.285903        1.530450
# Blood vessels_TT_Normal                         0.874852        1.634224
# Fibroblast lineage_HT_Normal                   -1.277352        2.008189
# Fibroblast lineage_TT_Normal                    1.339074        1.454316
# Lymphatic EC_HT_Normal                         -0.951917        1.530672
# Lymphatic EC_TT_Normal                          0.839509        1.261734
# Lymphoid_HT_Normal                             -1.205699       -1.111603
# Lymphoid_TT_Normal                             -0.956222       -1.148561
# Lymphoid_TT_Tumor                              -1.023217       -1.067065
# Mesothelium_HT_Normal                           1.286372        1.312841
# Myeloid_HT_Normal                               0.899342        0.969441
# Myeloid_TT_Normal                               1.134177        0.977424
# Myeloid_TT_Tumor                               -1.184000        1.011239
# Smooth muscle_HT_Normal                        -1.168842        1.520571
# Smooth muscle_TT_Normal                        -0.994090        1.557146
# Unknown_HT_Normal                              -1.516074        1.843789
# Unknown_TT_Normal                               1.263276        1.304074
# Unknown_TT_Tumor                                1.043098       -0.990564
#
# hallmark                       UV_RESPONSE_UP  WNT_BETA_CATENIN_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal          0.837078                    0.871591
# Airway epithelium_TT_Normal          0.744115                    0.922821
# Airway epithelium_TT_Tumor          -1.200530                    0.903752
# Alveolar epithelium_HT_Normal        1.208816                    0.832935
# Alveolar epithelium_TT_Normal        1.045590                    0.914070
# Alveolar epithelium_TT_Tumor        -1.440495                   -1.102770
# Blood vessels_HT_Normal             -0.780450                    1.149128
# Blood vessels_TT_Normal             -1.031582                    1.431672
# Fibroblast lineage_HT_Normal        -0.911367                    1.185182
# Fibroblast lineage_TT_Normal         0.879902                    1.279498
# Lymphatic EC_HT_Normal               1.163383                    1.151365
# Lymphatic EC_TT_Normal               0.879549                    0.809703
# Lymphoid_HT_Normal                  -1.177508                   -1.047610
# Lymphoid_TT_Normal                  -1.085024                   -0.933589
# Lymphoid_TT_Tumor                   -1.286652                    0.820243
# Mesothelium_HT_Normal                1.211668                    1.105513
# Myeloid_HT_Normal                    1.122541                    0.991458
# Myeloid_TT_Normal                    1.135529                    1.014874
# Myeloid_TT_Tumor                    -1.079799                   -1.320161
# Smooth muscle_HT_Normal             -0.909569                    0.902458
# Smooth muscle_TT_Normal             -1.287330                    0.932023
# Unknown_HT_Normal                    1.066874                    1.263642
# Unknown_TT_Normal                    0.862868                    1.110473
# Unknown_TT_Tumor                    -1.393286                   -0.761805
#
# hallmark                       XENOBIOTIC_METABOLISM
# cell_type
# Airway epithelium_HT_Normal                 1.133875
# Airway epithelium_TT_Normal                 1.088458
# Airway epithelium_TT_Tumor                  1.220694
# Alveolar epithelium_HT_Normal               1.310919
# Alveolar epithelium_TT_Normal               1.209442
# Alveolar epithelium_TT_Tumor                1.194470
# Blood vessels_HT_Normal                    -0.930885
# Blood vessels_TT_Normal                    -1.057767
# Fibroblast lineage_HT_Normal                1.397159
# Fibroblast lineage_TT_Normal                1.195329
# Lymphatic EC_HT_Normal                      1.061034
# Lymphatic EC_TT_Normal                      0.838068
# Lymphoid_HT_Normal                         -1.395666
# Lymphoid_TT_Normal                         -1.501225
# Lymphoid_TT_Tumor                          -1.263596
# Mesothelium_HT_Normal                       1.189810
# Myeloid_HT_Normal                           1.400988
# Myeloid_TT_Normal                           1.331231
# Myeloid_TT_Tumor                            1.015705
# Smooth muscle_HT_Normal                    -1.136318
# Smooth muscle_TT_Normal                     0.848687
# Unknown_HT_Normal                           1.455679
# Unknown_TT_Normal                           1.237437
# Unknown_TT_Tumor                            1.188421
#
# [24 rows x 50 columns]

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Tumor']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df_tumor, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Normal']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()
