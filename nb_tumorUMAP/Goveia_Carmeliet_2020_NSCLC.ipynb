# %%
id_ = 'Zilionis_Klein_2019_NSCLC'
# id = 'Lambrechts_2018_LUAD_6149v1'
backup_dir = '/root/datos/maestria/netopaas/luca_explore/surgeries'
infercnv_dir = '/root/datos/maestria/netopaas/infercnv'
ikarus_dir = '/root/datos/maestria/netopaas/ikarus'
load_wilcoxon = True
load_gsea = True
load_gsea_heatmap = False
run_umap = False

# %%
# Parameters
id_ = "Goveia_Carmeliet_2020_NSCLC"

# %% [markdown]
# # Cell Type Verification

# %% [markdown]
# ## Libraries and Data

# %% [markdown]
# We want to check our tumor vs normal classifier. For that we will explore the state of our cells by different methods.
#
# 1. Via UMAP, how the types of cell cluster vs the tumor and normal labels. Also, if it is normal adjacent or tumor. Sample labels to discard batch effects.
# 2. Marker genes plots for these comparisons per cell type: (**TypeNormalPred_HT** vs **REST**) (**TypeNormalPred_TT** vs **REST**) (**TypeNormalPred_HT** vs **TypeNormalPred_TT**)
#    (**TypeTumorPred_TT** vs **REST**) (**TypeTumorPred_TT** vs **TypeNormalPred_TT**)
# 3. Heatmaps With the above groups (**TumorPred_TT**, **NormalPred_TT**, **NormalPred_HT**) as  cell labels and hierarchical clustering in the genes. With genes chosen from the marker genes.
# 4. Prevalent gene ontologies for each of the groups above, considering also hallmark ontologies

# %%
import os
from pathlib import Path
import gdown

import sys
# This makes the working dir change apparently
sys.path.append("..")
import utils.functions as ut

import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
from scipy.sparse import csr_matrix

import anndata as ad
import scanpy as sc

# %%
# adata = sc.read_h5ad(f'{backup_dir}/combTumor_{id_}.h5ad')
adata = sc.read_h5ad(f'{backup_dir}/filtered_{id_}.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 56281 × 18450
#     obs: 'patient', 'condition', 'origin', 'Endothelial cell', 'Cluster', 'tissue', 'sample', 'n_counts', 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mito', 'pct_counts_mito'
#     var: 'n_counts', 'mito', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'

# %% [markdown]
# ### Types from infercnv dir

# %%
types = pd.read_csv(f'{infercnv_dir}/{id_}.csv')
types = types.rename(columns={'Unnamed: 0':'barcode_'})
types = types.rename(columns={'Level_2_transfered_label':'cell_type'})
types
# Out:
#                      barcode_      cell_type
# 0      AAACCTGAGAGCTATA.2.NEC        Myeloid
# 1      AAACCTGAGCTAAGAT.2.NEC        Myeloid
# 2      AAACCTGAGGACCACA.2.NEC        Myeloid
# 3      AAACCTGAGGCCGAAT.2.NEC       Lymphoid
# 4      AAACCTGAGGTGACCA.2.NEC        Myeloid
# ...                       ...            ...
# 51942  TTTGGTTTCTTGTACT.9.TEC  Blood vessels
# 51943  TTTGTCAAGTAGATGT.9.TEC  Blood vessels
# 51944  TTTGTCACAGGAATGC.9.TEC        Myeloid
# 51945  TTTGTCAGTAATCACC.9.TEC   Lymphatic EC
# 51946  TTTGTCATCTTATCTG.9.TEC  Blood vessels
#
# [51947 rows x 2 columns]

# %%
adata.obs['barcode_'] = adata.obs.index
adata.obs = pd.merge(adata.obs, types, on='barcode_',
                    how='left')
adata.obs.cell_type = adata.obs.cell_type.fillna('Unknown')
adata.obs.columns
# Out:
# Index(['patient', 'condition', 'origin', 'Endothelial cell', 'Cluster',
#        'tissue', 'sample', 'n_counts', 'n_genes', 'n_genes_by_counts',
#        'total_counts', 'total_counts_mito', 'pct_counts_mito', 'barcode_',
#        'cell_type'],
#       dtype='object')

# %% [markdown]
# ### Tumor prediction from ikarus

# %%
preds = pd.read_csv(f'{ikarus_dir}/{id_}.csv')
preds
# Out:
#        Unnamed: 0 final_pred
# 0               0     Normal
# 1               1     Normal
# 2               2     Normal
# 3               3     Normal
# 4               4     Normal
# ...           ...        ...
# 56276       56276     Normal
# 56277       56277     Normal
# 56278       56278     Normal
# 56279       56279     Normal
# 56280       56280     Normal
#
# [56281 rows x 2 columns]

# %%
adata.obs['final_pred'] = list(preds.iloc[:,1])

# %%
adata.obs['origin']
# Out:
# 0        normal_adjacent
# 1        normal_adjacent
# 2        normal_adjacent
# 3        normal_adjacent
# 4        normal_adjacent
#               ...
# 56276    normal_adjacent
# 56277    normal_adjacent
# 56278    normal_adjacent
# 56279    normal_adjacent
# 56280    normal_adjacent
# Name: origin, Length: 56281, dtype: category
# Categories (2, object): ['normal_adjacent', 'tumor_primary']

# %%
adata[np.logical_or(adata.obs['origin'].str.contains('normal'), adata.obs['origin']=='tumor_primary')].obs['origin'].value_counts()
# Out:
# origin
# tumor_primary      35609
# normal_adjacent    20672
# Name: count, dtype: int64

# %%
adata.layers['counts'] = adata.X

# %%
sc.pp.normalize_total(adata, target_sum=1e6)
sc.pp.log1p(adata)

# %% [markdown]
# ## UMAP Clusters

# %% [markdown]
# We see similarities between cell types in normal tisse and tumor tissue. And  also what cell types are tumoral.

# %%
#papermill_description=UMAP
if run_umap:
    sc.tl.pca(adata)
    sc.pp.neighbors(adata)
    sc.tl.umap(adata)

# %%
if run_umap:
    fig, axs = plt.subplots(2, 2, figsize=(15, 10))
    
    sc.pl.umap(
        adata,
        color="cell_type",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="final_pred",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[0, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="origin",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 0],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    sc.pl.umap(
        adata,
        color="sample",
        # legend_loc="on data",
        legend_fontoutline=2,
        ax=axs[1, 1],  # Specifies the subplot
        show=False  # Prevents showing the plot immediately
    )
    
    # Display the entire figure with all plots
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We can see that for the 'Tumor' prediciton there are mostly cells from patient 41, although there are many more samples from primary tumor.
# This could be due to batch effects. So it is worthwile to run the prediction again with batch correction.

# %%
# adata.obs.groupby('leiden').count()
adata.obs.groupby('sample').count().iloc[:,0]
# Out:
# /tmp/ipykernel_27775/2910804369.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs.groupby('sample').count().iloc[:,0]
# sample
# patient_32_tumor_primary      4830
# patient_40_normal_adjacent    5023
# patient_40_tumor_primary      5064
# patient_41_normal_adjacent    2108
# patient_41_tumor_primary      7483
# patient_42_normal_adjacent    3487
# patient_42_tumor_primary      2215
# patient_43_normal_adjacent    1486
# patient_43_tumor_primary      2848
# patient_45_normal_adjacent    1720
# patient_45_tumor_primary      5387
# patient_46_normal_adjacent    3877
# patient_46_tumor_primary      4401
# patient_50_normal_adjacent    2971
# patient_50_tumor_primary      3381
# Name: patient, dtype: int64

# %% [markdown]
# ## Marker Genes

# %% [markdown]
# Create a column that merges cell type, tissue and tumor pred

# %%
adata.obs['type_tissue'] = adata.obs.apply(lambda x: str(x['cell_type']) + '_' + 
                 ('HT' if 'normal' in x['origin'] else 'TT') + 
                 '_' + x['final_pred'], axis=1)
adata.obs['type_tissue'] = adata.obs['type_tissue'].astype('category')
adata.obs['type_tissue']
# Out:
# 0              Myeloid_HT_Normal
# 1              Myeloid_HT_Normal
# 2              Myeloid_HT_Normal
# 3             Lymphoid_HT_Normal
# 4              Myeloid_HT_Normal
#                   ...
# 56276    Blood vessels_HT_Normal
# 56277    Blood vessels_HT_Normal
# 56278          Myeloid_HT_Normal
# 56279     Lymphatic EC_HT_Normal
# 56280    Blood vessels_HT_Normal
# Name: type_tissue, Length: 56281, dtype: category
# Categories (28, object): ['Airway epithelium_HT_Normal', 'Airway epithelium_HT_Tumor', 'Airway epithelium_TT_Normal', 'Airway epithelium_TT_Tumor', ..., 'Smooth muscle_TT_Normal', 'Unknown_HT_Normal', 'Unknown_TT_Normal', 'Unknown_TT_Tumor']

# %%
# We dont get them with unique because it saves the NaN's
adata.obs.cell_type = adata.obs.cell_type.astype('category')
types = adata.obs.cell_type.cat.categories
num_types = len(types)
types
# Out:
# Index(['Airway epithelium', 'Alveolar epithelium', 'Blood vessels',
#        'Fibroblast lineage', 'Lymphatic EC', 'Lymphoid', 'Mesothelium',
#        'Myeloid', 'Smooth muscle', 'Unknown'],
#       dtype='object')

# %%
adata.obs['type_tissue'].value_counts()
# Out:
# type_tissue
# Blood vessels_TT_Normal          15510
# Myeloid_HT_Normal                10826
# Unknown_TT_Normal                 6535
# Blood vessels_HT_Normal           4939
# Myeloid_TT_Normal                 3942
# Lymphoid_TT_Normal                2257
# Unknown_HT_Normal                 1962
# Lymphatic EC_TT_Normal            1811
# Alveolar epithelium_TT_Normal     1785
# Lymphatic EC_HT_Normal            1355
# Airway epithelium_TT_Normal       1309
# Airway epithelium_TT_Tumor        1304
# Lymphoid_HT_Normal                 986
# Fibroblast lineage_TT_Normal       533
# Alveolar epithelium_HT_Normal      475
# Unknown_TT_Tumor                   289
# Blood vessels_TT_Tumor             189
# Smooth muscle_TT_Normal             84
# Airway epithelium_HT_Normal         60
# Fibroblast lineage_HT_Normal        52
# Alveolar epithelium_TT_Tumor        39
# Lymphoid_TT_Tumor                   14
# Smooth muscle_HT_Normal              9
# Mesothelium_HT_Normal                5
# Myeloid_TT_Tumor                     5
# Airway epithelium_HT_Tumor           3
# Mesothelium_TT_Normal                2
# Fibroblast lineage_TT_Tumor          1
# Name: count, dtype: int64

# %%
#papermill_description=WILCOXON_DE
# Get the groups that have more than 2 cells associated with them
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)
w_folder = 'wilcoxon_DE'

# Load

all_path = f'{w_folder}/all_{id_}.npy'
key = "wilcoxon"

if load_wilcoxon:
    adata.uns[key] = np.load(all_path, allow_pickle='TRUE').item()
else:
    sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = key,
                       groups=valid_types)
    np.save(all_path, adata.uns[key])

for type in types:
    tumor_tumor = type + '_TT_Tumor'
    normal_tumor = type + '_TT_Normal'
    normal_healthy = type + '_HT_Normal'

    differ_key = f"w_pair_{type}_differ"
    normal_key = f"w_pair_{type}_normal"
    differ_path =  f'{w_folder}/{differ_key}.npy'
    normal_path = f'{w_folder}/{normal_key}.npy'
    if load_wilcoxon:
        # We check for existance  here and not up there because there some datasets with no normal tissue
        if os.path.exists(differ_path):
            adata.uns[differ_key] = np.load(differ_path, allow_pickle='TRUE').item()
        if os.path.exists(normal_path):
            adata.uns[normal_key] = np.load(normal_path, allow_pickle='TRUE').item()
    else:
        if set([tumor_tumor, normal_tumor]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = differ_key,
                                    groups=[tumor_tumor], reference=normal_tumor)
            np.save(differ_path, adata.uns[differ_key])
            
        if set([normal_tumor, normal_healthy]).issubset(valid_types):
            sc.tl.rank_genes_groups(adata, 'type_tissue', method='wilcoxon', key_added = normal_key,
                                    groups=[normal_tumor], reference=normal_healthy)
            np.save(normal_path, adata.uns[normal_key])

# %%
def cond_plot(adata, cond_types, valid_types, ax=None,
              key='wilcoxon', fontsize=9, titlesize=14, **kwds):
    print(cond_types)
    if set(cond_types).issubset(valid_types):
        ut.rank_genes_group(adata, cond_types[0], n_genes=n_genes,
                            ax=ax, sharey=False, key=key, show=False,
                            fontsize=fontsize, titlesize=titlesize)
    else:
        # Draw an empty plot with a message
        ax.text(0.5, 0.5, f'Missing cells: {cond_types}', color='red', 
                       ha='center', va='center', transform=ax.transAxes)
        ax.axis('off')

# %%
valid_types
# Out:
# ['Blood vessels_TT_Normal',
#  'Myeloid_HT_Normal',
#  'Unknown_TT_Normal',
#  'Blood vessels_HT_Normal',
#  'Myeloid_TT_Normal',
#  'Lymphoid_TT_Normal',
#  'Unknown_HT_Normal',
#  'Lymphatic EC_TT_Normal',
#  'Alveolar epithelium_TT_Normal',
#  'Lymphatic EC_HT_Normal',
#  'Airway epithelium_TT_Normal',
#  'Airway epithelium_TT_Tumor',
#  'Lymphoid_HT_Normal',
#  'Fibroblast lineage_TT_Normal',
#  'Alveolar epithelium_HT_Normal',
#  'Unknown_TT_Tumor',
#  'Blood vessels_TT_Tumor',
#  'Smooth muscle_TT_Normal',
#  'Airway epithelium_HT_Normal',
#  'Fibroblast lineage_HT_Normal',
#  'Alveolar epithelium_TT_Tumor',
#  'Lymphoid_TT_Tumor',
#  'Smooth muscle_HT_Normal',
#  'Mesothelium_HT_Normal',
#  'Myeloid_TT_Tumor',
#  'Airway epithelium_HT_Tumor']

# %%
if(adata.obs.origin.str.contains('tumor').any()):
    fig, axs = plt.subplots(num_types, 2, figsize=(12, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        tumor_tumor = type + '_TT_Tumor'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [tumor_tumor], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [tumor_tumor, normal_tumor], valid_types, n_genes=n_genes, ax= axs[i, 1],
                                key=f"w_pair_{type}_differ", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    from warnings import warn
    warn('NO TUMOR TISSUES!?!?!?!!?')
# Out:
# ['Airway epithelium_TT_Tumor']
# ['Airway epithelium_TT_Tumor', 'Airway epithelium_TT_Normal']
# ['Alveolar epithelium_TT_Tumor']
# ['Alveolar epithelium_TT_Tumor', 'Alveolar epithelium_TT_Normal']
# ['Blood vessels_TT_Tumor']
# ['Blood vessels_TT_Tumor', 'Blood vessels_TT_Normal']
# ['Fibroblast lineage_TT_Tumor']
# ['Fibroblast lineage_TT_Tumor', 'Fibroblast lineage_TT_Normal']
# ['Lymphatic EC_TT_Tumor']
# ['Lymphatic EC_TT_Tumor', 'Lymphatic EC_TT_Normal']
# ['Lymphoid_TT_Tumor']
# ['Lymphoid_TT_Tumor', 'Lymphoid_TT_Normal']
# ['Mesothelium_TT_Tumor']
# ['Mesothelium_TT_Tumor', 'Mesothelium_TT_Normal']
# ['Myeloid_TT_Tumor']
# ['Myeloid_TT_Tumor', 'Myeloid_TT_Normal']
# ['Smooth muscle_TT_Tumor']
# ['Smooth muscle_TT_Tumor', 'Smooth muscle_TT_Normal']
# ['Unknown_TT_Tumor']
# ['Unknown_TT_Tumor', 'Unknown_TT_Normal']

# %%
adata.obs.origin.str.contains('normal').any()
# Out:
# True

# %%
from warnings import warn

if(adata.obs.origin.str.contains('normal').any()):
    fig, axs = plt.subplots(num_types, 3, figsize=(17, 4.5*num_types))
    n_genes = 20
    for i, type in enumerate(types):
        normal_healthy = type + '_HT_Normal'
        normal_tumor = type + '_TT_Normal'
        titlesize = 9
        fontsize = 6
    
        
        cond_plot(adata, [normal_healthy], valid_types, n_genes=n_genes,
                         ax= axs[i, 0], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        cond_plot(adata, [normal_tumor], valid_types, n_genes=n_genes,
                                ax= axs[i, 1], sharey=False, key="wilcoxon", show=False,
                         fontsize=fontsize, titlesize=titlesize)
        print(f"w_pair_{type}_normal")
        cond_plot(adata, [normal_tumor, normal_healthy], valid_types, n_genes=n_genes, ax= axs[i, 2],
                                key=f"w_pair_{type}_normal", show=False,
                         fontsize=fontsize, titlesize=titlesize)
    
    # Display the entire figure with all plots
    plt.show()
else:
    warn('No healthy tissue!')
# Out:
# ['Airway epithelium_HT_Normal']
# ['Airway epithelium_TT_Normal']
# w_pair_Airway epithelium_normal
# ['Airway epithelium_TT_Normal', 'Airway epithelium_HT_Normal']
# ['Alveolar epithelium_HT_Normal']
# ['Alveolar epithelium_TT_Normal']
# w_pair_Alveolar epithelium_normal
# ['Alveolar epithelium_TT_Normal', 'Alveolar epithelium_HT_Normal']
# ['Blood vessels_HT_Normal']
# ['Blood vessels_TT_Normal']
# w_pair_Blood vessels_normal
# ['Blood vessels_TT_Normal', 'Blood vessels_HT_Normal']
# ['Fibroblast lineage_HT_Normal']
# ['Fibroblast lineage_TT_Normal']
# w_pair_Fibroblast lineage_normal
# ['Fibroblast lineage_TT_Normal', 'Fibroblast lineage_HT_Normal']
# ['Lymphatic EC_HT_Normal']
# ['Lymphatic EC_TT_Normal']
# w_pair_Lymphatic EC_normal
# ['Lymphatic EC_TT_Normal', 'Lymphatic EC_HT_Normal']
# ['Lymphoid_HT_Normal']
# ['Lymphoid_TT_Normal']
# w_pair_Lymphoid_normal
# ['Lymphoid_TT_Normal', 'Lymphoid_HT_Normal']
# ['Mesothelium_HT_Normal']
# ['Mesothelium_TT_Normal']
# w_pair_Mesothelium_normal
# ['Mesothelium_TT_Normal', 'Mesothelium_HT_Normal']
# ['Myeloid_HT_Normal']
# ['Myeloid_TT_Normal']
# w_pair_Myeloid_normal
# ['Myeloid_TT_Normal', 'Myeloid_HT_Normal']
# ['Smooth muscle_HT_Normal']
# ['Smooth muscle_TT_Normal']
# w_pair_Smooth muscle_normal
# ['Smooth muscle_TT_Normal', 'Smooth muscle_HT_Normal']
# ['Unknown_HT_Normal']
# ['Unknown_TT_Normal']
# w_pair_Unknown_normal
# ['Unknown_TT_Normal', 'Unknown_HT_Normal']

# %% [markdown]
# ## Heatmaps

# %%
sc.pl.rank_genes_groups_heatmap(adata, show_gene_labels=True, key='wilcoxon')
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_type_tissue). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
# WARNING: You’re trying to run this on 18450 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.
# /usr/local/lib/python3.11/site-packages/scanpy/plotting/_anndata.py:1067: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if isinstance(groupby, str) and is_categorical_dtype(adata.obs[groupby]):
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:105: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(adata.obs[group]):
# /usr/local/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# WARNING: Groups are not reordered because the `groupby` categories and the `var_group_labels` are different.
# categories: Airway epithelium_HT_Normal, Airway epithelium_HT_Tumor, Airway epithelium_TT_Normal, etc.
# var_group_labels: Blood vessels_TT_Normal, Myeloid_HT_Normal, Unknown_TT_Normal, etc.
# /usr/local/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:133: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_df = rep_df.groupby(level=0).mean()

# %% [markdown]
# ## GSEA

# %%
from gprofiler import GProfiler
import gseapy
import seaborn as sns
gp = GProfiler(return_dataframe=True, user_agent='INMEGEN')

# %%
# gen_list = adata.uns['wilcoxon']['names']['Airway epithelium_TT_Tumor'][100:]
# enrich = gp.profile(list(gen_list), sources=['GO:BP'], organism="hsapiens")
# enrich.iloc[:25,:]

# %%
#  Download Gene symbols
if not os.path.exists('h.all.v2023.2.Hs.symbols.gmt'):
    ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.symbols.gmt

#  Gene entrez
# if not os.path.exists('h.all.v2023.2.Hs.entrez.gmt'):
# ! wget https://data.broadinstitute.org/gsea-msigdb/msigdb/release/2023.2.Hs/h.all.v2023.2.Hs.entrez.gmt

# %%
valid_types = list(adata.obs['type_tissue'].value_counts().loc[lambda x: x > 2].index)

# %%
from typing import List

def get_gseas_df(adata: ad.AnnData, valid_types: List[str], types: List[str], id_: str, load_gsea: bool = False) -> pd.DataFrame:
    """
    Generates a combined DataFrame from GSEA results for different cell types.

    Args:
    adata (ad.AnnData): An AnnData object containing the dataset.
    valid_types (List[str]): A list of valid cell types to filter the cell types.
    types (List[str]): A list of cell types to be considered for analysis.
    id_ (str): Identifier used in generating the GSEA path.
    load_gsea (bool, optional): Flag to load existing GSEA results. Defaults to False.

    Returns:
    pd.DataFrame: A combined DataFrame with GSEA results pivoted by cell type and hallmark.

    The function uses the provided 'types', intersects them with 'valid_types',
    and computes GSEA for each type. The final DataFrame is a pivot table with cell types as rows
    and GSEA hallmarks as columns.
    """
    # Intersect types with valid types
    types = set(types).intersection(valid_types)

    gsea_folder = 'gseapy_gsea'
    dfs = []

    for type in types:
        wilco = adata.uns['wilcoxon']
        gsea_path = f'{gsea_folder}/{type}_{id_}.npz'

        # Generate gene scores
        gene_scores = {gene: wilco['scores'][type][i] for i, gene in enumerate(wilco['names'][type])}
        gene_scores = pd.Series(gene_scores)

        # Run GSEA
        if load_gsea:
            gseas = np.load(gsea_path, allow_pickle='TRUE').item()
        else:
            pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
                                     processes=20, permutation_num=100, seed=6, no_plot=True)
            gseas = pre_res.res2d
            np.save(gsea_path, gseas)

        data1 = {'hallmark': list(gseas['Term'].str.slice(9)), 'score': list(gseas['NES'])}
        df_celltype1 = pd.DataFrame(data1)
        df_celltype1['cell_type'] = type
        dfs.append(df_celltype1)

    # Combine all DataFrames
    combined_df = pd.concat(dfs).reset_index(drop=True).pivot(index='cell_type', columns='hallmark', values='score')
    return combined_df

# %%
#papermill_description=GSEA
gsea_folder = 'gseapy_gsea'
gsea_path = f'{gsea_folder}/heatmap_{id_}.csv'

if load_gsea_heatmap:
    combined_df = pd.read_csv(gsea_path, index_col=0)
else:
    types = adata.obs.loc[:, 'type_tissue'].unique()
    combined_df = get_gseas_df(adata, valid_types, types, id_, load_gsea=False)
    combined_df.to_csv(gsea_path)
# Out:
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:41,698 [WARNING] Duplicated values found in preranked stats: 2.67% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:42,500 [WARNING] Duplicated values found in preranked stats: 51.23% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:43,330 [WARNING] Duplicated values found in preranked stats: 12.23% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:44,415 [WARNING] Duplicated values found in preranked stats: 6.11% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:45,540 [WARNING] Duplicated values found in preranked stats: 1.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:46,401 [WARNING] Duplicated values found in preranked stats: 0.64% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:47,143 [WARNING] Duplicated values found in preranked stats: 1.62% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:48,082 [WARNING] Duplicated values found in preranked stats: 43.54% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:49,285 [WARNING] Duplicated values found in preranked stats: 5.40% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:50,370 [WARNING] Duplicated values found in preranked stats: 13.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:51,627 [WARNING] Duplicated values found in preranked stats: 2.16% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:52,439 [WARNING] Duplicated values found in preranked stats: 45.53% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:53,346 [WARNING] Duplicated values found in preranked stats: 34.24% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:54,422 [WARNING] Duplicated values found in preranked stats: 5.90% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:55,415 [WARNING] Duplicated values found in preranked stats: 46.40% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:56,222 [WARNING] Duplicated values found in preranked stats: 21.94% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:57,089 [WARNING] Duplicated values found in preranked stats: 28.01% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:57,931 [WARNING] Duplicated values found in preranked stats: 5.61% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:31:58,944 [WARNING] Duplicated values found in preranked stats: 42.76% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:00,014 [WARNING] Duplicated values found in preranked stats: 24.93% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:00,807 [WARNING] Duplicated values found in preranked stats: 8.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:01,772 [WARNING] Duplicated values found in preranked stats: 20.51% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:02,868 [WARNING] Duplicated values found in preranked stats: 8.21% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:03,659 [WARNING] Duplicated values found in preranked stats: 13.50% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:04,594 [WARNING] Duplicated values found in preranked stats: 5.22% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# /tmp/ipykernel_27775/760898386.py:39: DeprecationWarning: processes is deprecated; use threads
#   pre_res = gseapy.prerank(rnk=gene_scores, gene_sets='h.all.v2023.2.Hs.symbols.gmt',
# 2024-02-21 15:32:05,419 [WARNING] Duplicated values found in preranked stats: 5.95% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.

# %%
combined_df
# Out:
# hallmark                       ADIPOGENESIS  ALLOGRAFT_REJECTION  \
# cell_type
# Airway epithelium_HT_Normal       -1.180176            -2.508167
# Airway epithelium_HT_Tumor        -1.325914            -1.500070
# Airway epithelium_TT_Normal       -1.459157            -1.530554
# Airway epithelium_TT_Tumor        -1.457479            -1.724251
# Alveolar epithelium_HT_Normal      1.124198            -1.912063
# Alveolar epithelium_TT_Normal      1.008336            -1.000000
# Alveolar epithelium_TT_Tumor      -1.558392            -1.379314
# Blood vessels_HT_Normal           -1.214102            -1.009573
# Blood vessels_TT_Normal           -1.409689            -1.530847
# Blood vessels_TT_Tumor            -1.490670            -1.227018
# Fibroblast lineage_HT_Normal       1.193813            -1.942591
# Fibroblast lineage_TT_Normal       0.725944            -1.756884
# Lymphatic EC_HT_Normal             1.003009            -1.546883
# Lymphatic EC_TT_Normal            -1.297857            -1.761751
# Lymphoid_HT_Normal                -1.621144             2.130313
# Lymphoid_TT_Normal                -1.466996             1.000000
# Lymphoid_TT_Tumor                 -1.574565            -1.400576
# Mesothelium_HT_Normal              0.965603             0.908371
# Myeloid_HT_Normal                  1.323088             1.285196
# Myeloid_TT_Normal                  1.368707             1.523102
# Myeloid_TT_Tumor                   1.019345             1.025059
# Smooth muscle_HT_Normal            1.429174            -1.773399
# Smooth muscle_TT_Normal           -1.376889            -1.625154
# Unknown_HT_Normal                 -1.248564            -1.068636
# Unknown_TT_Normal                 -1.500170            -1.247588
# Unknown_TT_Tumor                  -1.588824            -1.689723
#
# hallmark                       ANDROGEN_RESPONSE  ANGIOGENESIS  \
# cell_type
# Airway epithelium_HT_Normal             0.971568     -1.701454
# Airway epithelium_HT_Tumor             -1.229193     -1.112635
# Airway epithelium_TT_Normal            -1.093861     -1.270288
# Airway epithelium_TT_Tumor              0.980190     -1.524294
# Alveolar epithelium_HT_Normal           1.442178     -1.377411
# Alveolar epithelium_TT_Normal           1.253578     -1.327354
# Alveolar epithelium_TT_Tumor           -1.242064     -1.441001
# Blood vessels_HT_Normal                -1.069320      0.862131
# Blood vessels_TT_Normal                -1.080729      1.197104
# Blood vessels_TT_Tumor                 -1.253199     -1.385186
# Fibroblast lineage_HT_Normal           -1.049504      1.685894
# Fibroblast lineage_TT_Normal            0.961409      1.597632
# Lymphatic EC_HT_Normal                  1.056428      1.196642
# Lymphatic EC_TT_Normal                  0.873841      0.967644
# Lymphoid_HT_Normal                     -1.278704     -1.357229
# Lymphoid_TT_Normal                     -1.333352     -1.348581
# Lymphoid_TT_Tumor                      -1.117204     -1.203622
# Mesothelium_HT_Normal                   1.113792      0.972001
# Myeloid_HT_Normal                       1.099529      1.026459
# Myeloid_TT_Normal                       1.039950      1.086714
# Myeloid_TT_Tumor                        0.939112     -1.255880
# Smooth muscle_HT_Normal                 1.142930      1.246582
# Smooth muscle_TT_Normal                -1.315608      1.674574
# Unknown_HT_Normal                      -0.888414     -0.908715
# Unknown_TT_Normal                      -1.140452     -1.338340
# Unknown_TT_Tumor                       -1.121892     -1.626235
#
# hallmark                       APICAL_JUNCTION  APICAL_SURFACE  APOPTOSIS  \
# cell_type
# Airway epithelium_HT_Normal          -1.488623       -1.287574   0.935193
# Airway epithelium_HT_Tumor           -1.135533       -1.053286  -1.314021
# Airway epithelium_TT_Normal          -1.436156       -1.056075  -1.318346
# Airway epithelium_TT_Tumor           -1.203727        1.103379  -1.603526
# Alveolar epithelium_HT_Normal        -1.347543       -1.307537  -1.318231
# Alveolar epithelium_TT_Normal        -1.300541        0.727085   0.945610
# Alveolar epithelium_TT_Tumor         -1.385381       -0.988409  -1.600291
# Blood vessels_HT_Normal              -0.728938       -0.880316  -0.773315
# Blood vessels_TT_Normal               1.663735        1.198060  -1.068045
# Blood vessels_TT_Tumor               -1.173231       -0.818895  -1.474095
# Fibroblast lineage_HT_Normal          1.281969        1.261663   1.628381
# Fibroblast lineage_TT_Normal          1.387052        1.063460   1.271333
# Lymphatic EC_HT_Normal                1.103503        1.404722   1.193550
# Lymphatic EC_TT_Normal                1.301174        1.529206  -1.068590
# Lymphoid_HT_Normal                   -1.194437       -0.990060  -1.296958
# Lymphoid_TT_Normal                   -1.273967       -1.090239  -1.316346
# Lymphoid_TT_Tumor                    -1.246845        0.968708  -1.547532
# Mesothelium_HT_Normal                 0.825925        1.184763   1.298053
# Myeloid_HT_Normal                     0.911595        0.851173   1.069954
# Myeloid_TT_Normal                    -1.216923        0.840484   1.113640
# Myeloid_TT_Tumor                     -1.277711        1.328931  -1.307388
# Smooth muscle_HT_Normal               1.402294        0.888966   1.183647
# Smooth muscle_TT_Normal               1.431311        1.015192  -1.124489
# Unknown_HT_Normal                    -1.148897       -0.935388   1.000000
# Unknown_TT_Normal                    -1.359421       -0.967118  -1.293852
# Unknown_TT_Tumor                     -1.266453        1.008433  -1.734615
#
# hallmark                       BILE_ACID_METABOLISM  CHOLESTEROL_HOMEOSTASIS  \
# cell_type
# Airway epithelium_HT_Normal                1.506929                 1.397664
# Airway epithelium_HT_Tumor                 1.130314                -0.984923
# Airway epithelium_TT_Normal               -0.817884                -1.242956
# Airway epithelium_TT_Tumor                -0.985654                 1.054437
# Alveolar epithelium_HT_Normal              1.662381                 1.678449
# Alveolar epithelium_TT_Normal              1.322829                 1.352548
# Alveolar epithelium_TT_Tumor              -1.152622                -1.173719
# Blood vessels_HT_Normal                   -1.162709                -1.231551
# Blood vessels_TT_Normal                   -1.381148                -1.459595
# Blood vessels_TT_Tumor                    -1.180012                -1.139387
# Fibroblast lineage_HT_Normal               1.332815                -0.991153
# Fibroblast lineage_TT_Normal               0.757835                -1.316010
# Lymphatic EC_HT_Normal                     0.781225                 1.001211
# Lymphatic EC_TT_Normal                     0.786268                -1.084078
# Lymphoid_HT_Normal                        -1.025826                -1.461811
# Lymphoid_TT_Normal                        -1.058902                -1.388137
# Lymphoid_TT_Tumor                         -1.101376                -1.198621
# Mesothelium_HT_Normal                      1.222731                 1.322555
# Myeloid_HT_Normal                          1.152699                 1.354185
# Myeloid_TT_Normal                          1.311945                 1.373060
# Myeloid_TT_Tumor                           0.779837                 1.305245
# Smooth muscle_HT_Normal                    0.770605                -1.008778
# Smooth muscle_TT_Normal                   -1.468686                -1.465241
# Unknown_HT_Normal                         -1.154739                -0.791614
# Unknown_TT_Normal                         -1.011183                -1.495229
# Unknown_TT_Tumor                          -1.274765                -1.028661
#
# hallmark                       COAGULATION  ...  PROTEIN_SECRETION  \
# cell_type                                   ...
# Airway epithelium_HT_Normal      -1.574020  ...           0.942549
# Airway epithelium_HT_Tumor       -1.271140  ...          -1.118742
# Airway epithelium_TT_Normal      -1.396086  ...          -1.209270
# Airway epithelium_TT_Tumor       -1.981576  ...          -0.883943
# Alveolar epithelium_HT_Normal    -1.269970  ...           0.861867
# Alveolar epithelium_TT_Normal     0.922097  ...           1.151123
# Alveolar epithelium_TT_Tumor     -1.608244  ...          -1.567636
# Blood vessels_HT_Normal           1.000000  ...          -1.372673
# Blood vessels_TT_Normal           1.219902  ...          -1.429611
# Blood vessels_TT_Tumor           -1.450188  ...          -1.481119
# Fibroblast lineage_HT_Normal      2.014337  ...           0.949960
# Fibroblast lineage_TT_Normal      1.481730  ...           1.189027
# Lymphatic EC_HT_Normal            1.250623  ...           1.217800
# Lymphatic EC_TT_Normal            1.098577  ...           1.190429
# Lymphoid_HT_Normal               -1.682882  ...          -1.638036
# Lymphoid_TT_Normal               -1.622092  ...          -1.495658
# Lymphoid_TT_Tumor                -1.693694  ...          -1.487499
# Mesothelium_HT_Normal             1.555159  ...           0.940887
# Myeloid_HT_Normal                 1.156123  ...           1.280371
# Myeloid_TT_Normal                 1.042793  ...           1.378772
# Myeloid_TT_Tumor                 -1.240264  ...           1.098246
# Smooth muscle_HT_Normal           1.101994  ...          -1.181135
# Smooth muscle_TT_Normal          -1.137562  ...          -1.193902
# Unknown_HT_Normal                -0.812717  ...          -1.402353
# Unknown_TT_Normal                -1.521632  ...          -1.302147
# Unknown_TT_Tumor                 -1.839928  ...          -1.294041
#
# hallmark                       REACTIVE_OXYGEN_SPECIES_PATHWAY  \
# cell_type
# Airway epithelium_HT_Normal                           1.089438
# Airway epithelium_HT_Tumor                            1.258489
# Airway epithelium_TT_Normal                          -1.418407
# Airway epithelium_TT_Tumor                            0.941927
# Alveolar epithelium_HT_Normal                         1.012782
# Alveolar epithelium_TT_Normal                         0.900620
# Alveolar epithelium_TT_Tumor                         -1.211975
# Blood vessels_HT_Normal                              -1.255134
# Blood vessels_TT_Normal                              -1.443880
# Blood vessels_TT_Tumor                               -1.251074
# Fibroblast lineage_HT_Normal                          0.958485
# Fibroblast lineage_TT_Normal                         -1.172376
# Lymphatic EC_HT_Normal                                0.920807
# Lymphatic EC_TT_Normal                               -1.215424
# Lymphoid_HT_Normal                                   -1.290374
# Lymphoid_TT_Normal                                   -1.433729
# Lymphoid_TT_Tumor                                    -1.347922
# Mesothelium_HT_Normal                                 0.949692
# Myeloid_HT_Normal                                     1.396546
# Myeloid_TT_Normal                                     1.317560
# Myeloid_TT_Tumor                                      1.377647
# Smooth muscle_HT_Normal                               1.019161
# Smooth muscle_TT_Normal                              -1.362597
# Unknown_HT_Normal                                    -1.291366
# Unknown_TT_Normal                                    -1.356558
# Unknown_TT_Tumor                                     -1.197529
#
# hallmark                       SPERMATOGENESIS  TGF_BETA_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal           1.582857           -1.451109
# Airway epithelium_HT_Tumor            0.884995           -1.406454
# Airway epithelium_TT_Normal          -0.670597           -1.527019
# Airway epithelium_TT_Tumor            1.202466           -1.534935
# Alveolar epithelium_HT_Normal         0.742820           -1.396106
# Alveolar epithelium_TT_Normal         1.000610           -1.288009
# Alveolar epithelium_TT_Tumor         -0.743098           -1.522961
# Blood vessels_HT_Normal              -0.746196           -0.781229
# Blood vessels_TT_Normal              -0.756557            1.475950
# Blood vessels_TT_Tumor               -0.806254           -1.475020
# Fibroblast lineage_HT_Normal         -0.848271           -1.113490
# Fibroblast lineage_TT_Normal          0.629178            1.212472
# Lymphatic EC_HT_Normal                1.038346            0.996747
# Lymphatic EC_TT_Normal                1.072704            1.222249
# Lymphoid_HT_Normal                   -0.968194           -1.187133
# Lymphoid_TT_Normal                   -0.814102           -1.270821
# Lymphoid_TT_Tumor                    -0.945154           -1.635341
# Mesothelium_HT_Normal                 0.836056            0.883915
# Myeloid_HT_Normal                     0.832800            0.910748
# Myeloid_TT_Normal                     0.793631           -1.384426
# Myeloid_TT_Tumor                      1.457147           -1.866772
# Smooth muscle_HT_Normal               0.924183           -1.321814
# Smooth muscle_TT_Normal              -0.935110           -1.387617
# Unknown_HT_Normal                    -0.773928           -0.966361
# Unknown_TT_Normal                    -0.900759           -1.505317
# Unknown_TT_Tumor                      0.903801           -1.698649
#
# hallmark                       TNFA_SIGNALING_VIA_NFKB  \
# cell_type
# Airway epithelium_HT_Normal                   1.087612
# Airway epithelium_HT_Tumor                   -1.399302
# Airway epithelium_TT_Normal                  -1.507333
# Airway epithelium_TT_Tumor                   -1.854630
# Alveolar epithelium_HT_Normal                 1.377215
# Alveolar epithelium_TT_Normal                 1.055046
# Alveolar epithelium_TT_Tumor                 -1.629197
# Blood vessels_HT_Normal                      -1.037153
# Blood vessels_TT_Normal                      -1.337761
# Blood vessels_TT_Tumor                       -1.461437
# Fibroblast lineage_HT_Normal                  1.008956
# Fibroblast lineage_TT_Normal                  1.059887
# Lymphatic EC_HT_Normal                        1.050121
# Lymphatic EC_TT_Normal                       -1.765115
# Lymphoid_HT_Normal                            1.216355
# Lymphoid_TT_Normal                           -0.846446
# Lymphoid_TT_Tumor                            -1.591768
# Mesothelium_HT_Normal                         1.423309
# Myeloid_HT_Normal                             1.137483
# Myeloid_TT_Normal                             1.524167
# Myeloid_TT_Tumor                              0.992221
# Smooth muscle_HT_Normal                       0.993134
# Smooth muscle_TT_Normal                      -1.671521
# Unknown_HT_Normal                             1.000000
# Unknown_TT_Normal                            -1.308368
# Unknown_TT_Tumor                             -1.893155
#
# hallmark                       UNFOLDED_PROTEIN_RESPONSE  UV_RESPONSE_DN  \
# cell_type
# Airway epithelium_HT_Normal                     0.930132        1.171488
# Airway epithelium_HT_Tumor                     -1.500795        1.075879
# Airway epithelium_TT_Normal                    -1.418283       -1.093118
# Airway epithelium_TT_Tumor                      1.464031       -1.253689
# Alveolar epithelium_HT_Normal                  -1.105265        1.201934
# Alveolar epithelium_TT_Normal                   1.195896        0.957607
# Alveolar epithelium_TT_Tumor                   -1.273964       -1.396725
# Blood vessels_HT_Normal                        -1.447782       -0.706369
# Blood vessels_TT_Normal                        -1.275134        1.597413
# Blood vessels_TT_Tumor                         -1.291093       -1.215498
# Fibroblast lineage_HT_Normal                    0.920869        2.055245
# Fibroblast lineage_TT_Normal                    1.458476        1.646844
# Lymphatic EC_HT_Normal                          1.150566        1.458112
# Lymphatic EC_TT_Normal                          1.314432        1.351275
# Lymphoid_HT_Normal                             -0.841856       -1.357166
# Lymphoid_TT_Normal                             -1.016256       -1.256705
# Lymphoid_TT_Tumor                              -1.075675       -1.280619
# Mesothelium_HT_Normal                           1.102615        1.426961
# Myeloid_HT_Normal                               1.141024        0.685356
# Myeloid_TT_Normal                               1.276001       -1.307466
# Myeloid_TT_Tumor                                1.024378       -1.162878
# Smooth muscle_HT_Normal                         1.049892        1.546035
# Smooth muscle_TT_Normal                        -0.997473        1.646757
# Unknown_HT_Normal                              -1.260280        1.000000
# Unknown_TT_Normal                              -1.100617       -1.231302
# Unknown_TT_Tumor                                1.254937       -1.410675
#
# hallmark                       UV_RESPONSE_UP  WNT_BETA_CATENIN_SIGNALING  \
# cell_type
# Airway epithelium_HT_Normal          0.855976                    0.780641
# Airway epithelium_HT_Tumor          -1.582649                   -1.186689
# Airway epithelium_TT_Normal         -1.347286                   -1.234052
# Airway epithelium_TT_Tumor          -1.361425                    1.076536
# Alveolar epithelium_HT_Normal        1.303464                   -1.257341
# Alveolar epithelium_TT_Normal        1.265744                   -0.723481
# Alveolar epithelium_TT_Tumor        -1.528088                   -1.070615
# Blood vessels_HT_Normal             -1.148052                   -0.818540
# Blood vessels_TT_Normal             -1.331403                    1.398759
# Blood vessels_TT_Tumor              -1.411934                   -0.934590
# Fibroblast lineage_HT_Normal        -1.189449                   -0.961110
# Fibroblast lineage_TT_Normal         0.891406                    1.212236
# Lymphatic EC_HT_Normal               1.045060                   -0.801092
# Lymphatic EC_TT_Normal              -1.163301                    0.621834
# Lymphoid_HT_Normal                  -1.147605                   -1.286735
# Lymphoid_TT_Normal                  -1.155845                   -1.126775
# Lymphoid_TT_Tumor                   -1.367168                   -1.061910
# Mesothelium_HT_Normal                1.181770                    0.919943
# Myeloid_HT_Normal                    1.198609                    0.864843
# Myeloid_TT_Normal                    1.376052                   -1.056969
# Myeloid_TT_Tumor                    -1.101918                    0.742413
# Smooth muscle_HT_Normal              1.213048                   -0.900191
# Smooth muscle_TT_Normal             -1.489513                   -0.770184
# Unknown_HT_Normal                   -0.809848                   -0.906088
# Unknown_TT_Normal                   -1.245660                   -1.253150
# Unknown_TT_Tumor                    -1.550757                    0.725686
#
# hallmark                       XENOBIOTIC_METABOLISM
# cell_type
# Airway epithelium_HT_Normal                 1.068911
# Airway epithelium_HT_Tumor                 -0.944259
# Airway epithelium_TT_Normal                -1.296242
# Airway epithelium_TT_Tumor                  1.091938
# Alveolar epithelium_HT_Normal               1.280812
# Alveolar epithelium_TT_Normal               1.123778
# Alveolar epithelium_TT_Tumor               -1.273484
# Blood vessels_HT_Normal                    -1.094985
# Blood vessels_TT_Normal                    -1.427095
# Blood vessels_TT_Tumor                     -1.262971
# Fibroblast lineage_HT_Normal                1.433435
# Fibroblast lineage_TT_Normal                0.948425
# Lymphatic EC_HT_Normal                      0.830771
# Lymphatic EC_TT_Normal                     -1.535204
# Lymphoid_HT_Normal                         -1.568913
# Lymphoid_TT_Normal                         -1.373723
# Lymphoid_TT_Tumor                          -1.177606
# Mesothelium_HT_Normal                       1.222206
# Myeloid_HT_Normal                           1.244722
# Myeloid_TT_Normal                           1.398466
# Myeloid_TT_Tumor                            1.355738
# Smooth muscle_HT_Normal                     0.877912
# Smooth muscle_TT_Normal                    -1.683135
# Unknown_HT_Normal                          -1.171098
# Unknown_TT_Normal                          -1.470485
# Unknown_TT_Tumor                           -1.234005
#
# [26 rows x 50 columns]

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Tumor']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df_tumor, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()

# %%
# Plotting the heatmap
combined_df_tumor = combined_df.loc[combined_df.index.str.split('_').str[-1] == 'Normal']

plt.figure(figsize=(15, 8))
sns.heatmap(combined_df, cmap='viridis')
plt.title('Heatmap of Gene Set Hallmarks Scores by Cell Type')
plt.xlabel('Hallmarks')
plt.ylabel('Cell Types')
plt.show()
